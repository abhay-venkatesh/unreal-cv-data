# %%
from __future__ import division, absolute_import, print_function
import os, sys, time, re, json
import numpy as np
import random
import matplotlib.pyplot as plt
from PIL import Image
import StringIO
import json
import cv2

imread = plt.imread
def imread8(im_file):
    ''' Read image as a 8-bit numpy array '''
    im = np.asarray(Image.open(im_file))
    return im

def read_png(res):
    img = Image.open(StringIO.StringIO(res))
    return np.array(img)

def read_npy(res):
    return np.load(res)

# Matches a color from the object_mask and then returns that region color
def match_color(object_mask, target_color, tolerance=3):
    match_region = np.ones(object_mask.shape[0:2], dtype=bool)
    for c in range(3): # r,g,b
        min_val = target_color[c] - tolerance
        max_val = target_color[c] + tolerance
        channel_region = (object_mask[:,:,c] >= min_val) & (object_mask[:,:,c] <= max_val)
        match_region &= channel_region

    if match_region.sum() != 0:
        return match_region
    else:
        return None
    
# Swap colors method
def swap_color(imgarray, source, dest):
    matched_color = match_color(imgarray, [source.R, source.G, source.B])
    imgarray[:,:,:3][matched_color] = [dest.R, dest.G, dest.B]
    return np.array(imgarray)

# %% [markdown]
# Connect to the game
# ===================
# Load unrealcv python client, do :code:`pip install unrealcv` first.

# %%
from unrealcv import client
client.connect()
if not client.isconnected():
    print('UnrealCV server is not running. Run the game downloaded from http://unrealcv.github.io first.')
    sys.exit(-1)

# %%
# Make sure the connection works well

res = client.request('vget /unrealcv/status')
# The image resolution and port is configured in the config file.
print(res)
# Out:
# Is Listening
# Client Connected
# 9000
# Configuration
# Config file: C:/Program Files/Epic Games/UE_4.18/Engine/Binaries/Win64/unrealcv.ini
# Port: 9000
# Width: 640
# Height: 480
# FOV: 90.000000
# EnableInput: true
# EnableRightEye: false

# %% [markdown]
# Get objects
# ======================
# Write a json file with the object and their corresponding classes.

# %%
scene_objects = client.request('vget /objects').split(' ')
print('Number of objects in this scene:', len(scene_objects))

# Creates a JSON file that maps each objects ID to a class
# We use this to group stuff together
obj_id_to_class = {}
for obj_id in scene_objects:
    obj_id_parts = obj_id.split('_')
    if len(obj_id_parts) > 1:
        class_name = obj_id_parts[1]
    else:
        class_name = obj_id_parts[0]
    obj_id_to_class[obj_id] = class_name

# Write JSON file
with open('../data/neighborhood_deux_object_ids.json', 'w') as outfile:
    json.dump(obj_id_to_class, outfile)
# Out:
# Number of objects in this scene: 3618

# %% [markdown]
# Get object colors
# ======================

# %%
# First we create the color object class
class Color(object):
    ''' A utility class to parse color value '''
    regexp = re.compile('\(R=(.*),G=(.*),B=(.*),A=(.*)\)')
    def __init__(self, color_str):
        self.color_str = color_str
        match = self.regexp.match(color_str)
        (self.R, self.G, self.B, self.A) = [int(match.group(i)) for i in range(1,5)]

    def __repr__(self):
        return self.color_str

# %%
# Then, we either load from json if we have collected the mappings between object ids and colors
if os.path.exists('../data/id2color_deux.json'):
    id2color = {}
    with open('../data/id2color_deux.json') as data_file:
        data = json.load(data_file)

    for obj_id in data.keys():
        color_map = data[obj_id]
        color_str = '(R=' + str(color_map['R']) + ',G=' + \
                    str(color_map['G']) + ',B=' + str(color_map['B']) + \
                    ',A=' + str(color_map['A']) + ')'
        color = Color(color_str)
        id2color[obj_id] = color
else: 
    # or we load from the scene if we have not collected the json file.
    id2color = {} # Map from object id to the labeling color
    for i, obj_id in enumerate(scene_objects):
        color = Color(client.request('vget /object/%s/color' % obj_id))
        id2color[obj_id] = color
        print('%d. %s : %s' % (i, obj_id, str(color)))
    
    # Write to JSON if loaded from scene
    # Convert to serializable json dictionary
    serializable_map = {}
    for color_id in id2color.keys():
        curr_color = id2color[color_id]
        color_map = {}
        color_map['R'] = curr_color.R
        color_map['G'] = curr_color.G
        color_map['B'] = curr_color.B
        color_map['A'] = curr_color.A
        serializable_map[color_id] = color_map

    # Write to JSON
    with open('../data/id2color_deux.json', 'w') as outfile:
        json.dump(serializable_map, outfile)

# %%
# Map classes to lists of objects
classes = {}

for obj_id in obj_id_to_class.keys():
    
    curr_class = obj_id_to_class[obj_id]
    if curr_class not in classes:
        classes[curr_class] = []
    
    classes[curr_class].append(obj_id)

# Write classes to json
with open('../data/neighborhood_deux_classes.json', 'w') as outfile:
    json.dump(classes, outfile)

# %%
# Normalize using built in API
counter = 0
for curr_class in classes.keys():
    
    
    object_list = classes[curr_class]
    curr_color = id2color[object_list[0]]
    
    for obj_id in object_list:
        
        client.request('vset /object/' + obj_id + '/color ' + \
                       str(curr_color.R) + ' ' + str(curr_color.G) + \
                       ' ' + str(curr_color.B))
        
        print(str(counter) + '. vset /object/' + obj_id + '/color ' + \
                       str(curr_color.R) + ' ' + str(curr_color.G) + \
                       ' ' + str(curr_color.B))
    
        counter += 1
# Out:
# 0. vset /object/SM_Flower_Hanging_02_7/color 63 111 175
# 1. vset /object/SM_Flower_Hanging_03_10/color 63 111 175
# 2. vset /object/SM_Flower_Box_02_4/color 63 111 175
# 3. vset /object/SM_Flower_Box_18/color 63 111 175
# 4. vset /object/SM_Flower_Box_19/color 63 111 175
# 5. vset /object/SM_Flower_Box_15/color 63 111 175
# 6. vset /object/SM_Flower_Box_16/color 63 111 175
# 7. vset /object/SM_Flower_Box_17/color 63 111 175
# 8. vset /object/SM_Flower_Box_10/color 63 111 175
# 9. vset /object/SM_Flower_Box_11/color 63 111 175
# 10. vset /object/SM_Flower_Box_12/color 63 111 175
# 11. vset /object/SM_Flower_Box_13/color 63 111 175
# 12. vset /object/SM_Flower_Hanging_16/color 63 111 175
# 13. vset /object/SM_Flower_Hanging_10/color 63 111 175
# 14. vset /object/SM_Flower_Hanging_7/color 63 111 175
# 15. vset /object/SM_Flower_Pot_01_72/color 63 111 175
# 16. vset /object/SM_Flower_Hanging_2/color 63 111 175
# 17. vset /object/SM_Flower_Hanging_9/color 63 111 175
# 18. vset /object/SM_Flower_Hanging_8/color 63 111 175
# 19. vset /object/SM_Flower_Pot_4/color 63 111 175
# 20. vset /object/SM_Flower_Pot_5/color 63 111 175
# 21. vset /object/SM_Flower_Pot_6/color 63 111 175
# 22. vset /object/SM_Flower_Pot_7/color 63 111 175
# 23. vset /object/SM_Flower_Pot_3/color 63 111 175
# 24. vset /object/SM_Flower_Hanging_01_13/color 63 111 175
# 25. vset /object/SM_Flower_Box_03_152/color 63 111 175
# 26. vset /object/SM_Flower_Box_3/color 63 111 175
# 27. vset /object/SM_Flower_Box_5/color 63 111 175
# 28. vset /object/SM_Flower_Hanging_11/color 63 111 175
# 29. vset /object/SM_Flower_Box_14/color 63 111 175
# 30. vset /object/SM_Flower_Hanging_5/color 63 111 175
# 31. vset /object/SM_Flower_Hanging_4/color 63 111 175
# 32. vset /object/SM_Flower_Box_01_21/color 63 111 175
# 33. vset /object/SM_Flower_Pot_02_170/color 63 111 175
# 34. vset /object/SM_Flower_Hanging_3/color 63 111 175
# 35. vset /object/SM_Flower_Box_8/color 63 111 175
# 36. vset /object/SM_Flower_Box_9/color 63 111 175
# 37. vset /object/SM_Flower_Box_2/color 63 111 175
# 38. vset /object/SM_Flower_Box_6/color 63 111 175
# 39. vset /object/SM_Flower_Box_7/color 63 111 175
# 40. vset /object/SM_Flower_Box_4/color 63 111 175
# 41. vset /object/SM_Flower_Hanging_13/color 63 111 175
# 42. vset /object/SM_Flower_Hanging_12/color 63 111 175
# 43. vset /object/SM_Flower_Hanging_15/color 63 111 175
# 44. vset /object/SM_Flower_Hanging_14/color 63 111 175
# 45. vset /object/SM_Flower_Hanging_17/color 63 111 175
# 46. vset /object/SM_Flower_Hanging_6/color 63 111 175
# 47. vset /object/SM_Log_Storage_01_351/color 255 111 79
# 48. vset /object/SM_Log_Storage_2/color 255 111 79
# 49. vset /object/SM_Floor_Quart_261/color 143 127 191
# 50. vset /object/SM_Floor_S_Quart_03_36/color 143 127 191
# 51. vset /object/SM_Floor_8th_31/color 143 127 191
# 52. vset /object/SM_Floor_8th_30/color 143 127 191
# 53. vset /object/SM_Floor_8th_9/color 143 127 191
# 54. vset /object/SM_Floor_8th_8/color 143 127 191
# 55. vset /object/SM_Floor_8th_3/color 143 127 191
# 56. vset /object/SM_Floor_8th_2/color 143 127 191
# 57. vset /object/SM_Floor_8th_5/color 143 127 191
# 58. vset /object/SM_Floor_8th_4/color 143 127 191
# 59. vset /object/SM_Floor_8th_7/color 143 127 191
# 60. vset /object/SM_Floor_8th_6/color 143 127 191
# 61. vset /object/SM_Floor_Quart_288/color 143 127 191
# 62. vset /object/SM_Floor_Quart_57/color 143 127 191
# 63. vset /object/SM_Floor_Quart_50/color 143 127 191
# 64. vset /object/SM_Floor_Quart_53/color 143 127 191
# 65. vset /object/SM_Floor_Quart_178/color 143 127 191
# 66. vset /object/SM_Floor_Quart_179/color 143 127 191
# 67. vset /object/SM_Floor_Quart_170/color 143 127 191
# 68. vset /object/SM_Floor_Quart_171/color 143 127 191
# 69. vset /object/SM_Floor_Quart_172/color 143 127 191
# 70. vset /object/SM_Floor_Quart_173/color 143 127 191
# 71. vset /object/SM_Floor_Quart_174/color 143 127 191
# 72. vset /object/SM_Floor_Quart_175/color 143 127 191
# 73. vset /object/SM_Floor_Quart_176/color 143 127 191
# 74. vset /object/SM_Floor_Quart_177/color 143 127 191
# 75. vset /object/SM_Floor_Half_114/color 143 127 191
# 76. vset /object/SM_Floor_Half_113/color 143 127 191
# 77. vset /object/SM_Floor_Half_112/color 143 127 191
# 78. vset /object/SM_Floor_Quart_289/color 143 127 191
# 79. vset /object/SM_Floor_Half_110/color 143 127 191
# 80. vset /object/SM_Floor_Quart_192/color 143 127 191
# 81. vset /object/SM_Floor_Quart_193/color 143 127 191
# 82. vset /object/SM_Floor_Quart_190/color 143 127 191
# 83. vset /object/SM_Floor_Quart_191/color 143 127 191
# 84. vset /object/SM_Floor_Quart_195/color 143 127 191
# 85. vset /object/SM_Floor_Quart_224/color 143 127 191
# 86. vset /object/SM_Floor_Quart_225/color 143 127 191
# 87. vset /object/SM_Floor_Quart_220/color 143 127 191
# 88. vset /object/SM_Floor_Quart_221/color 143 127 191
# 89. vset /object/SM_Floor_Quart_222/color 143 127 191
# 90. vset /object/SM_Floor_Quart_223/color 143 127 191
# 91. vset /object/SM_Floor_Half_125/color 143 127 191
# 92. vset /object/SM_Floor_Half_117/color 143 127 191
# 93. vset /object/SM_Floor_Half_116/color 143 127 191
# 94. vset /object/SM_Floor_Quart_284/color 143 127 191
# 95. vset /object/SM_Floor_Half_119/color 143 127 191
# 96. vset /object/SM_Floor_Quart_285/color 143 127 191
# 97. vset /object/SM_Floor_Half_118/color 143 127 191
# 98. vset /object/SM_Floor_Quart_205/color 143 127 191
# 99. vset /object/SM_Floor_S_Quart_01_30/color 143 127 191
# 100. vset /object/SM_Floor_Half_115/color 143 127 191
# 101. vset /object/SM_Floor_Quart_277/color 143 127 191
# 102. vset /object/SM_Floor_Quart_276/color 143 127 191
# 103. vset /object/SM_Floor_Quart_169/color 143 127 191
# 104. vset /object/SM_Floor_Quart_168/color 143 127 191
# 105. vset /object/SM_Floor_Quart_167/color 143 127 191
# 106. vset /object/SM_Floor_Quart_166/color 143 127 191
# 107. vset /object/SM_Floor_Quart_165/color 143 127 191
# 108. vset /object/SM_Floor_Quart_164/color 143 127 191
# 109. vset /object/SM_Floor_Quart_163/color 143 127 191
# 110. vset /object/SM_Floor_Quart_162/color 143 127 191
# 111. vset /object/SM_Floor_Quart_161/color 143 127 191
# 112. vset /object/SM_Floor_Quart_160/color 143 127 191
# 113. vset /object/SM_Floor_Quart_275/color 143 127 191
# 114. vset /object/SM_Floor_Quart_273/color 143 127 191
# 115. vset /object/SM_Floor_Quart_272/color 143 127 191
# 116. vset /object/SM_Floor_Quart_271/color 143 127 191
# 117. vset /object/SM_Floor_Quart_181/color 143 127 191
# 118. vset /object/SM_Floor_Quart_180/color 143 127 191
# 119. vset /object/SM_Floor_Quart_183/color 143 127 191
# 120. vset /object/SM_Floor_Quart_182/color 143 127 191
# 121. vset /object/SM_Floor_Quart_185/color 143 127 191
# 122. vset /object/SM_Floor_Quart_184/color 143 127 191
# 123. vset /object/SM_Floor_Quart_187/color 143 127 191
# 124. vset /object/SM_Floor_Quart_186/color 143 127 191
# 125. vset /object/SM_Floor_Quart_189/color 143 127 191
# 126. vset /object/SM_Floor_Quart_188/color 143 127 191
# 127. vset /object/SM_Floor_Quart_02_173/color 143 127 191
# 128. vset /object/SM_Floor_Quart_270/color 143 127 191
# 129. vset /object/SM_Floor_Quart_239/color 143 127 191
# 130. vset /object/SM_Floor_Quart_238/color 143 127 191
# 131. vset /object/SM_Floor_Half_17/color 143 127 191
# 132. vset /object/SM_Floor_Half_15/color 143 127 191
# 133. vset /object/SM_Floor_Half_14/color 143 127 191
# 134. vset /object/SM_Floor_Half_19/color 143 127 191
# 135. vset /object/SM_Floor_Half_18/color 143 127 191
# 136. vset /object/SM_Floor_Half_111/color 143 127 191
# 137. vset /object/SM_Floor_Quart_320/color 143 127 191
# 138. vset /object/SM_Floor_Half_99/color 143 127 191
# 139. vset /object/SM_Floor_Half_98/color 143 127 191
# 140. vset /object/SM_Floor_Quart_247/color 143 127 191
# 141. vset /object/SM_Floor_Quart_260/color 143 127 191
# 142. vset /object/SM_Floor_Quart_244/color 143 127 191
# 143. vset /object/SM_Floor_Quart_245/color 143 127 191
# 144. vset /object/SM_Floor_Quart_242/color 143 127 191
# 145. vset /object/SM_Floor_Quart_243/color 143 127 191
# 146. vset /object/SM_Floor_Half_95/color 143 127 191
# 147. vset /object/SM_Floor_Half_94/color 143 127 191
# 148. vset /object/SM_Floor_Quart_21/color 143 127 191
# 149. vset /object/SM_Floor_Quart_20/color 143 127 191
# 150. vset /object/SM_Floor_Quart_23/color 143 127 191
# 151. vset /object/SM_Floor_Quart_22/color 143 127 191
# 152. vset /object/SM_Floor_Quart_25/color 143 127 191
# 153. vset /object/SM_Floor_Quart_24/color 143 127 191
# 154. vset /object/SM_Floor_Quart_27/color 143 127 191
# 155. vset /object/SM_Floor_Quart_26/color 143 127 191
# 156. vset /object/SM_Floor_Quart_29/color 143 127 191
# 157. vset /object/SM_Floor_Quart_28/color 143 127 191
# 158. vset /object/SM_Floor_Quart_1005/color 143 127 191
# 159. vset /object/SM_Floor_Half_132/color 143 127 191
# 160. vset /object/SM_Floor_Quart_248/color 143 127 191
# 161. vset /object/SM_Floor_Quart_249/color 143 127 191
# 162. vset /object/SM_Floor_Quart_241/color 143 127 191
# 163. vset /object/SM_Floor_Half_26/color 143 127 191
# 164. vset /object/SM_Floor_Half_27/color 143 127 191
# 165. vset /object/SM_Floor_Half_24/color 143 127 191
# 166. vset /object/SM_Floor_Half_25/color 143 127 191
# 167. vset /object/SM_Floor_Half_22/color 143 127 191
# 168. vset /object/SM_Floor_Half_23/color 143 127 191
# 169. vset /object/SM_Floor_Half_20/color 143 127 191
# 170. vset /object/SM_Floor_Half_21/color 143 127 191
# 171. vset /object/SM_Floor_Half_28/color 143 127 191
# 172. vset /object/SM_Floor_Half_29/color 143 127 191
# 173. vset /object/SM_Floor_Quart_230/color 143 127 191
# 174. vset /object/SM_Floor_Quart_51/color 143 127 191
# 175. vset /object/SM_Floor_Quart_291/color 143 127 191
# 176. vset /object/SM_Floor_Quart_290/color 143 127 191
# 177. vset /object/SM_Floor_Quart_293/color 143 127 191
# 178. vset /object/SM_Floor_Quart_292/color 143 127 191
# 179. vset /object/SM_Floor_Quart_295/color 143 127 191
# 180. vset /object/SM_Floor_Quart_294/color 143 127 191
# 181. vset /object/SM_Floor_Quart_297/color 143 127 191
# 182. vset /object/SM_Floor_Quart_296/color 143 127 191
# 183. vset /object/SM_Floor_Quart_32/color 143 127 191
# 184. vset /object/SM_Floor_Quart_33/color 143 127 191
# 185. vset /object/SM_Floor_Quart_30/color 143 127 191
# 186. vset /object/SM_Floor_Quart_31/color 143 127 191
# 187. vset /object/SM_Floor_Quart_36/color 143 127 191
# 188. vset /object/SM_Floor_Quart_37/color 143 127 191
# 189. vset /object/SM_Floor_Quart_34/color 143 127 191
# 190. vset /object/SM_Floor_Quart_35/color 143 127 191
# 191. vset /object/SM_Floor_Quart_38/color 143 127 191
# 192. vset /object/SM_Floor_Quart_39/color 143 127 191
# 193. vset /object/SM_Floor_Half_01_160/color 143 127 191
# 194. vset /object/SM_Floor_8th_01_490/color 143 127 191
# 195. vset /object/SM_Floor_8th_44/color 143 127 191
# 196. vset /object/SM_Floor_8th_42/color 143 127 191
# 197. vset /object/SM_Floor_8th_40/color 143 127 191
# 198. vset /object/SM_Floor_8th_41/color 143 127 191
# 199. vset /object/SM_Floor_Quart_255/color 143 127 191
# 200. vset /object/SM_Floor_Quart_254/color 143 127 191
# 201. vset /object/SM_Floor_Quart_257/color 143 127 191
# 202. vset /object/SM_Floor_Quart_251/color 143 127 191
# 203. vset /object/SM_Floor_Quart_250/color 143 127 191
# 204. vset /object/SM_Floor_Quart_253/color 143 127 191
# 205. vset /object/SM_Floor_Quart_252/color 143 127 191
# 206. vset /object/SM_Floor_Half_39/color 143 127 191
# 207. vset /object/SM_Floor_Half_38/color 143 127 191
# 208. vset /object/SM_Floor_Half_31/color 143 127 191
# 209. vset /object/SM_Floor_Half_30/color 143 127 191
# 210. vset /object/SM_Floor_Half_33/color 143 127 191
# 211. vset /object/SM_Floor_Half_32/color 143 127 191
# 212. vset /object/SM_Floor_Half_35/color 143 127 191
# 213. vset /object/SM_Floor_Half_34/color 143 127 191
# 214. vset /object/SM_Floor_Half_37/color 143 127 191
# 215. vset /object/SM_Floor_Half_36/color 143 127 191
# 216. vset /object/SM_Floor_S_16th_3/color 143 127 191
# 217. vset /object/SM_Floor_Quart_194/color 143 127 191
# 218. vset /object/SM_Floor_Quart_198/color 143 127 191
# 219. vset /object/SM_Floor_Quart_199/color 143 127 191
# 220. vset /object/SM_Floor_Quart_88/color 143 127 191
# 221. vset /object/SM_Floor_Quart_274/color 143 127 191
# 222. vset /object/SM_Floor_S_Half_6/color 143 127 191
# 223. vset /object/SM_Floor_S_Half_5/color 143 127 191
# 224. vset /object/SM_Floor_S_Half_4/color 143 127 191
# 225. vset /object/SM_Floor_S_Half_3/color 143 127 191
# 226. vset /object/SM_Floor_S_Half_2/color 143 127 191
# 227. vset /object/SM_Floor_Quart_226/color 143 127 191
# 228. vset /object/SM_Floor_Quart_227/color 143 127 191
# 229. vset /object/SM_Floor_Quart_228/color 143 127 191
# 230. vset /object/SM_Floor_Quart_229/color 143 127 191
# 231. vset /object/SM_Floor_Quart_15/color 143 127 191
# 232. vset /object/SM_Floor_S_Half_01_137/color 143 127 191
# 233. vset /object/SM_Floor_Quart_17/color 143 127 191
# 234. vset /object/SM_Floor_8th_33/color 143 127 191
# 235. vset /object/SM_Floor_8th_32/color 143 127 191
# 236. vset /object/SM_Floor_8th_37/color 143 127 191
# 237. vset /object/SM_Floor_8th_36/color 143 127 191
# 238. vset /object/SM_Floor_8th_35/color 143 127 191
# 239. vset /object/SM_Floor_8th_34/color 143 127 191
# 240. vset /object/SM_Floor_8th_39/color 143 127 191
# 241. vset /object/SM_Floor_8th_38/color 143 127 191
# 242. vset /object/SM_Floor_Half_48/color 143 127 191
# 243. vset /object/SM_Floor_Half_49/color 143 127 191
# 244. vset /object/SM_Floor_Half_44/color 143 127 191
# 245. vset /object/SM_Floor_Half_45/color 143 127 191
# 246. vset /object/SM_Floor_Half_46/color 143 127 191
# 247. vset /object/SM_Floor_Half_47/color 143 127 191
# 248. vset /object/SM_Floor_Half_40/color 143 127 191
# 249. vset /object/SM_Floor_Half_41/color 143 127 191
# 250. vset /object/SM_Floor_Half_42/color 143 127 191
# 251. vset /object/SM_Floor_Half_43/color 143 127 191
# 252. vset /object/SM_Floor_Quart_2/color 143 127 191
# 253. vset /object/SM_Floor_Quart_3/color 143 127 191
# 254. vset /object/SM_Floor_Quart_6/color 143 127 191
# 255. vset /object/SM_Floor_Quart_4/color 143 127 191
# 256. vset /object/SM_Floor_Quart_5/color 143 127 191
# 257. vset /object/SM_Floor_S_16th_02_54/color 143 127 191
# 258. vset /object/SM_Floor_Quart_18/color 143 127 191
# 259. vset /object/SM_Floor_Quart_19/color 143 127 191
# 260. vset /object/SM_Floor_Quart_10/color 143 127 191
# 261. vset /object/SM_Floor_Quart_11/color 143 127 191
# 262. vset /object/SM_Floor_Quart_12/color 143 127 191
# 263. vset /object/SM_Floor_Quart_13/color 143 127 191
# 264. vset /object/SM_Floor_Quart_14/color 143 127 191
# 265. vset /object/SM_Floor_Quart_16/color 143 127 191
# 266. vset /object/SM_Floor_Quart_8/color 143 127 191
# 267. vset /object/SM_Floor_Quart_9/color 143 127 191
# 268. vset /object/SM_Floor_Half_127/color 143 127 191
# 269. vset /object/SM_Floor_Quart_279/color 143 127 191
# 270. vset /object/SM_Floor_Quart_278/color 143 127 191
# 271. vset /object/SM_Floor_8th_20/color 143 127 191
# 272. vset /object/SM_Floor_8th_21/color 143 127 191
# 273. vset /object/SM_Floor_8th_22/color 143 127 191
# 274. vset /object/SM_Floor_8th_23/color 143 127 191
# 275. vset /object/SM_Floor_8th_25/color 143 127 191
# 276. vset /object/SM_Floor_8th_26/color 143 127 191
# 277. vset /object/SM_Floor_8th_27/color 143 127 191
# 278. vset /object/SM_Floor_8th_28/color 143 127 191
# 279. vset /object/SM_Floor_8th_29/color 143 127 191
# 280. vset /object/SM_Floor_Half_59/color 143 127 191
# 281. vset /object/SM_Floor_Half_58/color 143 127 191
# 282. vset /object/SM_Floor_Half_55/color 143 127 191
# 283. vset /object/SM_Floor_Half_54/color 143 127 191
# 284. vset /object/SM_Floor_Half_52/color 143 127 191
# 285. vset /object/SM_Floor_8th_24/color 143 127 191
# 286. vset /object/SM_Floor_Quart_259/color 143 127 191
# 287. vset /object/SM_Floor_Quart_258/color 143 127 191
# 288. vset /object/SM_Floor_Quart_69/color 143 127 191
# 289. vset /object/SM_Floor_Quart_68/color 143 127 191
# 290. vset /object/SM_Floor_Quart_65/color 143 127 191
# 291. vset /object/SM_Floor_Quart_64/color 143 127 191
# 292. vset /object/SM_Floor_Quart_67/color 143 127 191
# 293. vset /object/SM_Floor_Quart_66/color 143 127 191
# 294. vset /object/SM_Floor_Quart_61/color 143 127 191
# 295. vset /object/SM_Floor_Quart_60/color 143 127 191
# 296. vset /object/SM_Floor_Quart_63/color 143 127 191
# 297. vset /object/SM_Floor_Quart_62/color 143 127 191
# 298. vset /object/SM_Floor_Half_57/color 143 127 191
# 299. vset /object/SM_Floor_Half_56/color 143 127 191
# 300. vset /object/SM_Floor_Quart_282/color 143 127 191
# 301. vset /object/SM_Floor_Half_53/color 143 127 191
# 302. vset /object/SM_Floor_Quart_280/color 143 127 191
# 303. vset /object/SM_Floor_Quart_281/color 143 127 191
# 304. vset /object/SM_Floor_Quart_286/color 143 127 191
# 305. vset /object/SM_Floor_Quart_287/color 143 127 191
# 306. vset /object/SM_Floor_Half_51/color 143 127 191
# 307. vset /object/SM_Floor_Half_50/color 143 127 191
# 308. vset /object/SM_Floor_Quart_202/color 143 127 191
# 309. vset /object/SM_Floor_8th_19/color 143 127 191
# 310. vset /object/SM_Floor_8th_18/color 143 127 191
# 311. vset /object/SM_Floor_Quart_203/color 143 127 191
# 312. vset /object/SM_Floor_8th_15/color 143 127 191
# 313. vset /object/SM_Floor_8th_14/color 143 127 191
# 314. vset /object/SM_Floor_8th_17/color 143 127 191
# 315. vset /object/SM_Floor_8th_16/color 143 127 191
# 316. vset /object/SM_Floor_8th_11/color 143 127 191
# 317. vset /object/SM_Floor_8th_10/color 143 127 191
# 318. vset /object/SM_Floor_8th_13/color 143 127 191
# 319. vset /object/SM_Floor_Quart_201/color 143 127 191
# 320. vset /object/SM_Floor_Quart_206/color 143 127 191
# 321. vset /object/SM_Floor_Quart_207/color 143 127 191
# 322. vset /object/SM_Floor_Half_62/color 143 127 191
# 323. vset /object/SM_Floor_Half_63/color 143 127 191
# 324. vset /object/SM_Floor_Half_60/color 143 127 191
# 325. vset /object/SM_Floor_Half_61/color 143 127 191
# 326. vset /object/SM_Floor_Half_66/color 143 127 191
# 327. vset /object/SM_Floor_Half_67/color 143 127 191
# 328. vset /object/SM_Floor_Half_64/color 143 127 191
# 329. vset /object/SM_Floor_Half_65/color 143 127 191
# 330. vset /object/SM_Floor_Half_68/color 143 127 191
# 331. vset /object/SM_Floor_Half_69/color 143 127 191
# 332. vset /object/SM_Floor_Quart_246/color 143 127 191
# 333. vset /object/SM_Floor_Quart_78/color 143 127 191
# 334. vset /object/SM_Floor_Quart_79/color 143 127 191
# 335. vset /object/SM_Floor_Quart_76/color 143 127 191
# 336. vset /object/SM_Floor_Quart_77/color 143 127 191
# 337. vset /object/SM_Floor_Quart_74/color 143 127 191
# 338. vset /object/SM_Floor_Quart_75/color 143 127 191
# 339. vset /object/SM_Floor_Quart_72/color 143 127 191
# 340. vset /object/SM_Floor_Quart_73/color 143 127 191
# 341. vset /object/SM_Floor_Quart_70/color 143 127 191
# 342. vset /object/SM_Floor_Quart_71/color 143 127 191
# 343. vset /object/SM_Floor_Quart_299/color 143 127 191
# 344. vset /object/SM_Floor_Quart_298/color 143 127 191
# 345. vset /object/SM_Floor_Quart_240/color 143 127 191
# 346. vset /object/SM_Floor_Half_75/color 143 127 191
# 347. vset /object/SM_Floor_Half_74/color 143 127 191
# 348. vset /object/SM_Floor_Half_77/color 143 127 191
# 349. vset /object/SM_Floor_Half_76/color 143 127 191
# 350. vset /object/SM_Floor_Half_71/color 143 127 191
# 351. vset /object/SM_Floor_Half_70/color 143 127 191
# 352. vset /object/SM_Floor_Half_73/color 143 127 191
# 353. vset /object/SM_Floor_Half_72/color 143 127 191
# 354. vset /object/SM_Floor_Half_79/color 143 127 191
# 355. vset /object/SM_Floor_Half_78/color 143 127 191
# 356. vset /object/SM_Floor_Quart_263/color 143 127 191
# 357. vset /object/SM_Floor_Quart_7/color 143 127 191
# 358. vset /object/SM_Floor_Quart_256/color 143 127 191
# 359. vset /object/SM_Floor_Quart_43/color 143 127 191
# 360. vset /object/SM_Floor_Quart_42/color 143 127 191
# 361. vset /object/SM_Floor_Quart_41/color 143 127 191
# 362. vset /object/SM_Floor_Quart_40/color 143 127 191
# 363. vset /object/SM_Floor_Quart_46/color 143 127 191
# 364. vset /object/SM_Floor_Quart_45/color 143 127 191
# 365. vset /object/SM_Floor_Quart_44/color 143 127 191
# 366. vset /object/SM_Floor_Quart_47/color 143 127 191
# 367. vset /object/SM_Floor_Quart_49/color 143 127 191
# 368. vset /object/SM_Floor_Quart_118/color 143 127 191
# 369. vset /object/SM_Floor_Quart_119/color 143 127 191
# 370. vset /object/SM_Floor_Quart_112/color 143 127 191
# 371. vset /object/SM_Floor_Quart_113/color 143 127 191
# 372. vset /object/SM_Floor_Quart_110/color 143 127 191
# 373. vset /object/SM_Floor_Quart_111/color 143 127 191
# 374. vset /object/SM_Floor_Quart_116/color 143 127 191
# 375. vset /object/SM_Floor_Quart_117/color 143 127 191
# 376. vset /object/SM_Floor_Quart_114/color 143 127 191
# 377. vset /object/SM_Floor_Quart_115/color 143 127 191
# 378. vset /object/SM_Floor_Quart_48/color 143 127 191
# 379. vset /object/SM_Floor_Quart_231/color 143 127 191
# 380. vset /object/SM_Floor_Quart_236/color 143 127 191
# 381. vset /object/SM_Floor_Half_80/color 143 127 191
# 382. vset /object/SM_Floor_Half_81/color 143 127 191
# 383. vset /object/SM_Floor_Half_82/color 143 127 191
# 384. vset /object/SM_Floor_Half_83/color 143 127 191
# 385. vset /object/SM_Floor_Half_85/color 143 127 191
# 386. vset /object/SM_Floor_Half_86/color 143 127 191
# 387. vset /object/SM_Floor_Half_87/color 143 127 191
# 388. vset /object/SM_Floor_16th_3/color 143 127 191
# 389. vset /object/SM_Floor_16th_2/color 143 127 191
# 390. vset /object/SM_Floor_Half_135/color 143 127 191
# 391. vset /object/SM_Floor_8th_02_483/color 143 127 191
# 392. vset /object/SM_Floor_Quart_300/color 143 127 191
# 393. vset /object/SM_Floor_S_Quart_6/color 143 127 191
# 394. vset /object/SM_Floor_S_Quart_7/color 143 127 191
# 395. vset /object/SM_Floor_S_Quart_4/color 143 127 191
# 396. vset /object/SM_Floor_S_Quart_5/color 143 127 191
# 397. vset /object/SM_Floor_Half_134/color 143 127 191
# 398. vset /object/SM_Floor_Half_84/color 143 127 191
# 399. vset /object/SM_Floor_Quart_54/color 143 127 191
# 400. vset /object/SM_Floor_Quart_55/color 143 127 191
# 401. vset /object/SM_Floor_Quart_56/color 143 127 191
# 402. vset /object/SM_Floor_Quart_52/color 143 127 191
# 403. vset /object/SM_Floor_Quart_58/color 143 127 191
# 404. vset /object/SM_Floor_Quart_59/color 143 127 191
# 405. vset /object/SM_Floor_Quart_109/color 143 127 191
# 406. vset /object/SM_Floor_Quart_108/color 143 127 191
# 407. vset /object/SM_Floor_Quart_101/color 143 127 191
# 408. vset /object/SM_Floor_Quart_100/color 143 127 191
# 409. vset /object/SM_Floor_Quart_103/color 143 127 191
# 410. vset /object/SM_Floor_Quart_102/color 143 127 191
# 411. vset /object/SM_Floor_Quart_105/color 143 127 191
# 412. vset /object/SM_Floor_Quart_104/color 143 127 191
# 413. vset /object/SM_Floor_Quart_107/color 143 127 191
# 414. vset /object/SM_Floor_Quart_106/color 143 127 191
# 415. vset /object/SM_Floor_Half_93/color 143 127 191
# 416. vset /object/SM_Floor_Half_92/color 143 127 191
# 417. vset /object/SM_Floor_Half_91/color 143 127 191
# 418. vset /object/SM_Floor_Half_90/color 143 127 191
# 419. vset /object/SM_Floor_Half_97/color 143 127 191
# 420. vset /object/SM_Floor_Half_96/color 143 127 191
# 421. vset /object/SM_Floor_S_01_386/color 143 127 191
# 422. vset /object/SM_Floor_Quart_03_157/color 143 127 191
# 423. vset /object/SM_Floor_Half_02_165/color 143 127 191
# 424. vset /object/SM_Floor_Half_88/color 143 127 191
# 425. vset /object/SM_Floor_Half_89/color 143 127 191
# 426. vset /object/SM_Floor_Quart_214/color 143 127 191
# 427. vset /object/SM_Floor_Quart_138/color 143 127 191
# 428. vset /object/SM_Floor_Quart_139/color 143 127 191
# 429. vset /object/SM_Floor_Quart_134/color 143 127 191
# 430. vset /object/SM_Floor_Quart_135/color 143 127 191
# 431. vset /object/SM_Floor_Quart_136/color 143 127 191
# 432. vset /object/SM_Floor_Quart_137/color 143 127 191
# 433. vset /object/SM_Floor_Quart_130/color 143 127 191
# 434. vset /object/SM_Floor_Quart_131/color 143 127 191
# 435. vset /object/SM_Floor_Quart_132/color 143 127 191
# 436. vset /object/SM_Floor_Quart_133/color 143 127 191
# 437. vset /object/SM_Floor_Quart_233/color 143 127 191
# 438. vset /object/SM_Floor_Quart_232/color 143 127 191
# 439. vset /object/SM_Floor_Quart_237/color 143 127 191
# 440. vset /object/SM_Floor_Quart_235/color 143 127 191
# 441. vset /object/SM_Floor_Quart_234/color 143 127 191
# 442. vset /object/SM_Floor_16th_5/color 143 127 191
# 443. vset /object/SM_Floor_Quart_314/color 143 127 191
# 444. vset /object/SM_Floor_Quart_315/color 143 127 191
# 445. vset /object/SM_Floor_Quart_316/color 143 127 191
# 446. vset /object/SM_Floor_Quart_317/color 143 127 191
# 447. vset /object/SM_Floor_Quart_310/color 143 127 191
# 448. vset /object/SM_Floor_Quart_311/color 143 127 191
# 449. vset /object/SM_Floor_Quart_312/color 143 127 191
# 450. vset /object/SM_Floor_Quart_313/color 143 127 191
# 451. vset /object/SM_Floor_Quart_318/color 143 127 191
# 452. vset /object/SM_Floor_Quart_319/color 143 127 191
# 453. vset /object/SM_Floor_Half_131/color 143 127 191
# 454. vset /object/SM_Floor_Half_130/color 143 127 191
# 455. vset /object/SM_Floor_Half_133/color 143 127 191
# 456. vset /object/SM_Floor_Half_136/color 143 127 191
# 457. vset /object/SM_Floor_Half_13/color 143 127 191
# 458. vset /object/SM_Floor_Half_12/color 143 127 191
# 459. vset /object/SM_Floor_Half_11/color 143 127 191
# 460. vset /object/SM_Floor_Half_10/color 143 127 191
# 461. vset /object/SM_Floor_Half_16/color 143 127 191
# 462. vset /object/SM_Floor_Half_109/color 143 127 191
# 463. vset /object/SM_Floor_Quart_200/color 143 127 191
# 464. vset /object/SM_Floor_Quart_123/color 143 127 191
# 465. vset /object/SM_Floor_Quart_122/color 143 127 191
# 466. vset /object/SM_Floor_Quart_121/color 143 127 191
# 467. vset /object/SM_Floor_Quart_120/color 143 127 191
# 468. vset /object/SM_Floor_Quart_127/color 143 127 191
# 469. vset /object/SM_Floor_Quart_126/color 143 127 191
# 470. vset /object/SM_Floor_Quart_125/color 143 127 191
# 471. vset /object/SM_Floor_Quart_124/color 143 127 191
# 472. vset /object/SM_Floor_Quart_129/color 143 127 191
# 473. vset /object/SM_Floor_Quart_128/color 143 127 191
# 474. vset /object/SM_Floor_Quart_283/color 143 127 191
# 475. vset /object/SM_Floor_Quart_204/color 143 127 191
# 476. vset /object/SM_Floor_Quart_309/color 143 127 191
# 477. vset /object/SM_Floor_Quart_308/color 143 127 191
# 478. vset /object/SM_Floor_Quart_303/color 143 127 191
# 479. vset /object/SM_Floor_Quart_302/color 143 127 191
# 480. vset /object/SM_Floor_Quart_301/color 143 127 191
# 481. vset /object/SM_Floor_Quart_307/color 143 127 191
# 482. vset /object/SM_Floor_Quart_306/color 143 127 191
# 483. vset /object/SM_Floor_Quart_305/color 143 127 191
# 484. vset /object/SM_Floor_Quart_304/color 143 127 191
# 485. vset /object/SM_Floor_Half_122/color 143 127 191
# 486. vset /object/SM_Floor_Half_123/color 143 127 191
# 487. vset /object/SM_Floor_Half_120/color 143 127 191
# 488. vset /object/SM_Floor_Half_121/color 143 127 191
# 489. vset /object/SM_Floor_Half_126/color 143 127 191
# 490. vset /object/SM_Floor_Half_124/color 143 127 191
# 491. vset /object/SM_Floor_Half_128/color 143 127 191
# 492. vset /object/SM_Floor_Half_129/color 143 127 191
# 493. vset /object/SM_Floor_8th_12/color 143 127 191
# 494. vset /object/SM_Floor_Half_9/color 143 127 191
# 495. vset /object/SM_Floor_Half_8/color 143 127 191
# 496. vset /object/SM_Floor_Half_7/color 143 127 191
# 497. vset /object/SM_Floor_Half_6/color 143 127 191
# 498. vset /object/SM_Floor_Half_5/color 143 127 191
# 499. vset /object/SM_Floor_Half_4/color 143 127 191
# 500. vset /object/SM_Floor_Half_3/color 143 127 191
# 501. vset /object/SM_Floor_Half_2/color 143 127 191
# 502. vset /object/SM_Floor_Quart_89/color 143 127 191
# 503. vset /object/SM_Floor_Quart_87/color 143 127 191
# 504. vset /object/SM_Floor_Quart_86/color 143 127 191
# 505. vset /object/SM_Floor_Quart_85/color 143 127 191
# 506. vset /object/SM_Floor_Quart_84/color 143 127 191
# 507. vset /object/SM_Floor_Quart_83/color 143 127 191
# 508. vset /object/SM_Floor_Quart_82/color 143 127 191
# 509. vset /object/SM_Floor_Quart_81/color 143 127 191
# 510. vset /object/SM_Floor_Quart_80/color 143 127 191
# 511. vset /object/SM_Floor_Quart_156/color 143 127 191
# 512. vset /object/SM_Floor_Quart_157/color 143 127 191
# 513. vset /object/SM_Floor_Quart_154/color 143 127 191
# 514. vset /object/SM_Floor_Quart_155/color 143 127 191
# 515. vset /object/SM_Floor_Quart_152/color 143 127 191
# 516. vset /object/SM_Floor_Quart_153/color 143 127 191
# 517. vset /object/SM_Floor_Quart_150/color 143 127 191
# 518. vset /object/SM_Floor_Quart_151/color 143 127 191
# 519. vset /object/SM_Floor_Quart_158/color 143 127 191
# 520. vset /object/SM_Floor_Quart_159/color 143 127 191
# 521. vset /object/SM_Floor_Quart_219/color 143 127 191
# 522. vset /object/SM_Floor_S_Half_7/color 143 127 191
# 523. vset /object/SM_Floor_Quart_218/color 143 127 191
# 524. vset /object/SM_Floor_S_Half_02_141/color 143 127 191
# 525. vset /object/SM_Floor_Quart_208/color 143 127 191
# 526. vset /object/SM_Floor_Quart_209/color 143 127 191
# 527. vset /object/SM_Floor_16th_01_521/color 143 127 191
# 528. vset /object/SM_Floor_Quart_196/color 143 127 191
# 529. vset /object/SM_Floor_S_Quart_02_33/color 143 127 191
# 530. vset /object/SM_Floor_Quart_197/color 143 127 191
# 531. vset /object/SM_Floor_Half_108/color 143 127 191
# 532. vset /object/SM_Floor_Quart_90/color 143 127 191
# 533. vset /object/SM_Floor_Quart_91/color 143 127 191
# 534. vset /object/SM_Floor_Quart_92/color 143 127 191
# 535. vset /object/SM_Floor_Quart_93/color 143 127 191
# 536. vset /object/SM_Floor_Quart_94/color 143 127 191
# 537. vset /object/SM_Floor_Quart_95/color 143 127 191
# 538. vset /object/SM_Floor_Quart_96/color 143 127 191
# 539. vset /object/SM_Floor_Quart_97/color 143 127 191
# 540. vset /object/SM_Floor_Quart_98/color 143 127 191
# 541. vset /object/SM_Floor_Quart_99/color 143 127 191
# 542. vset /object/SM_Floor_Quart_145/color 143 127 191
# 543. vset /object/SM_Floor_Quart_144/color 143 127 191
# 544. vset /object/SM_Floor_Quart_147/color 143 127 191
# 545. vset /object/SM_Floor_Quart_146/color 143 127 191
# 546. vset /object/SM_Floor_Quart_141/color 143 127 191
# 547. vset /object/SM_Floor_Quart_140/color 143 127 191
# 548. vset /object/SM_Floor_Quart_143/color 143 127 191
# 549. vset /object/SM_Floor_Quart_142/color 143 127 191
# 550. vset /object/SM_Floor_Quart_149/color 143 127 191
# 551. vset /object/SM_Floor_Quart_148/color 143 127 191
# 552. vset /object/SM_Floor_8th_43/color 143 127 191
# 553. vset /object/SM_Floor_Quart_262/color 143 127 191
# 554. vset /object/SM_Floor_Quart_264/color 143 127 191
# 555. vset /object/SM_Floor_Quart_265/color 143 127 191
# 556. vset /object/SM_Floor_Quart_266/color 143 127 191
# 557. vset /object/SM_Floor_Quart_267/color 143 127 191
# 558. vset /object/SM_Floor_Quart_268/color 143 127 191
# 559. vset /object/SM_Floor_Quart_269/color 143 127 191
# 560. vset /object/SM_Floor_Quart_211/color 143 127 191
# 561. vset /object/SM_Floor_Quart_210/color 143 127 191
# 562. vset /object/SM_Floor_Quart_213/color 143 127 191
# 563. vset /object/SM_Floor_Quart_212/color 143 127 191
# 564. vset /object/SM_Floor_Quart_215/color 143 127 191
# 565. vset /object/SM_Floor_Quart_217/color 143 127 191
# 566. vset /object/SM_Floor_Quart_216/color 143 127 191
# 567. vset /object/SM_Floor_Half_100/color 143 127 191
# 568. vset /object/SM_Floor_Half_101/color 143 127 191
# 569. vset /object/SM_Floor_Half_102/color 143 127 191
# 570. vset /object/SM_Floor_Half_103/color 143 127 191
# 571. vset /object/SM_Floor_Half_104/color 143 127 191
# 572. vset /object/SM_Floor_Half_105/color 143 127 191
# 573. vset /object/SM_Floor_Half_106/color 143 127 191
# 574. vset /object/SM_Floor_Half_107/color 143 127 191
# 575. vset /object/SM_Support_Wood_57/color 175 223 223
# 576. vset /object/SM_Support_Wood_38/color 175 223 223
# 577. vset /object/SM_Support_Wood_39/color 175 223 223
# 578. vset /object/SM_Support_Wood_34/color 175 223 223
# 579. vset /object/SM_Support_Wood_35/color 175 223 223
# 580. vset /object/SM_Support_Wood_23/color 175 223 223
# 581. vset /object/SM_Support_Wood_22/color 175 223 223
# 582. vset /object/SM_Support_Wood_21/color 175 223 223
# 583. vset /object/SM_Support_Wood_20/color 175 223 223
# 584. vset /object/SM_Support_Wood_27/color 175 223 223
# 585. vset /object/SM_Support_Wood_26/color 175 223 223
# 586. vset /object/SM_Support_Wood_25/color 175 223 223
# 587. vset /object/SM_Support_Wood_24/color 175 223 223
# 588. vset /object/SM_Support_Wood_29/color 175 223 223
# 589. vset /object/SM_Support_Wood_28/color 175 223 223
# 590. vset /object/SM_Support_Wood_32/color 175 223 223
# 591. vset /object/SM_Support_Wood_33/color 175 223 223
# 592. vset /object/SM_Support_Wood_45/color 175 223 223
# 593. vset /object/SM_Support_Wood_44/color 175 223 223
# 594. vset /object/SM_Support_Wood_47/color 175 223 223
# 595. vset /object/SM_Support_Wood_46/color 175 223 223
# 596. vset /object/SM_Support_Wood_41/color 175 223 223
# 597. vset /object/SM_Support_Wood_40/color 175 223 223
# 598. vset /object/SM_Support_Wood_43/color 175 223 223
# 599. vset /object/SM_Support_Wood_42/color 175 223 223
# 600. vset /object/SM_Support_Wood_49/color 175 223 223
# 601. vset /object/SM_Support_Wood_48/color 175 223 223
# 602. vset /object/SM_Support_Wood_2/color 175 223 223
# 603. vset /object/SM_Support_Wood_54/color 175 223 223
# 604. vset /object/SM_Support_Wood_55/color 175 223 223
# 605. vset /object/SM_Support_Wood_8/color 175 223 223
# 606. vset /object/SM_Support_Wood_9/color 175 223 223
# 607. vset /object/SM_Support_Wood_3/color 175 223 223
# 608. vset /object/SM_Support_Wood_4/color 175 223 223
# 609. vset /object/SM_Support_Wood_5/color 175 223 223
# 610. vset /object/SM_Support_Wood_6/color 175 223 223
# 611. vset /object/SM_Support_Wood_7/color 175 223 223
# 612. vset /object/SM_Support_Wood_52/color 175 223 223
# 613. vset /object/SM_Support_Wood_53/color 175 223 223
# 614. vset /object/SM_Support_Wood_50/color 175 223 223
# 615. vset /object/SM_Support_Wood_51/color 175 223 223
# 616. vset /object/SM_Support_Wood_01_118/color 175 223 223
# 617. vset /object/SM_Support_Wood_56/color 175 223 223
# 618. vset /object/SM_Support_Wood_36/color 175 223 223
# 619. vset /object/SM_Support_Wood_37/color 175 223 223
# 620. vset /object/SM_Support_Wood_30/color 175 223 223
# 621. vset /object/SM_Support_Wood_31/color 175 223 223
# 622. vset /object/SM_Support_Wood_18/color 175 223 223
# 623. vset /object/SM_Support_Wood_19/color 175 223 223
# 624. vset /object/SM_Support_Wood_12/color 175 223 223
# 625. vset /object/SM_Support_Wood_13/color 175 223 223
# 626. vset /object/SM_Support_Wood_10/color 175 223 223
# 627. vset /object/SM_Support_Wood_11/color 175 223 223
# 628. vset /object/SM_Support_Wood_16/color 175 223 223
# 629. vset /object/SM_Support_Wood_17/color 175 223 223
# 630. vset /object/SM_Support_Wood_14/color 175 223 223
# 631. vset /object/SM_Support_Wood_15/color 175 223 223
# 632. vset /object/SM_Trellis_01_110/color 255 127 111
# 633. vset /object/SM_Trellis_9/color 255 127 111
# 634. vset /object/SM_Trellis_8/color 255 127 111
# 635. vset /object/SM_Trellis_3/color 255 127 111
# 636. vset /object/SM_Trellis_2/color 255 127 111
# 637. vset /object/SM_Trellis_7/color 255 127 111
# 638. vset /object/SM_Trellis_6/color 255 127 111
# 639. vset /object/SM_Trellis_5/color 255 127 111
# 640. vset /object/SM_Trellis_4/color 255 127 111
# 641. vset /object/SM_Trellis_10/color 255 127 111
# 642. vset /object/SM_Trellis_11/color 255 127 111
# 643. vset /object/SM_Bush_Small_01_78/color 191 175 127
# 644. vset /object/SM_Bush_Small_2/color 191 175 127
# 645. vset /object/SM_Bush_Large_01_82/color 191 175 127
# 646. vset /object/SM_Bush_Large_3/color 191 175 127
# 647. vset /object/SM_Bush_Large_2/color 191 175 127
# 648. vset /object/SM_Basketball_Hoop_01_63/color 63 175 79
# 649. vset /object/SM_Basketball_Hoop_4/color 63 175 79
# 650. vset /object/SM_Basketball_Hoop_6/color 63 175 79
# 651. vset /object/SM_Basketball_Hoop_7/color 63 175 79
# 652. vset /object/SM_Basketball_Hoop_5/color 63 175 79
# 653. vset /object/SM_Basketball_Hoop_2/color 63 175 79
# 654. vset /object/SM_Basketball_Hoop_8/color 63 175 79
# 655. vset /object/SM_Basketball_Hoop_9/color 63 175 79
# 656. vset /object/BP_LightStudio1_557/color 47 15 207
# 657. vset /object/SM_Trash_Bag_7/color 175 79 63
# 658. vset /object/SM_Trash_Bag_5/color 175 79 63
# 659. vset /object/SM_Trash_Bag_3/color 175 79 63
# 660. vset /object/SM_Trash_Bag_2/color 175 79 63
# 661. vset /object/SM_Trash_Bag_8/color 175 79 63
# 662. vset /object/SM_Trash_Bag_6/color 175 79 63
# 663. vset /object/SM_Trash_Bag_01_44/color 175 79 63
# 664. vset /object/SM_Trash_Bag_17/color 175 79 63
# 665. vset /object/SM_Trash_Bag_16/color 175 79 63
# 666. vset /object/SM_Trash_Bag_14/color 175 79 63
# 667. vset /object/SM_Trash_Bag_19/color 175 79 63
# 668. vset /object/SM_Trash_Bag_18/color 175 79 63
# 669. vset /object/SM_Trash_Bag_26/color 175 79 63
# 670. vset /object/SM_Trash_Bag_27/color 175 79 63
# 671. vset /object/SM_Trash_Bag_24/color 175 79 63
# 672. vset /object/SM_Trash_Bag_25/color 175 79 63
# 673. vset /object/SM_Trash_Bag_22/color 175 79 63
# 674. vset /object/SM_Trash_Bag_23/color 175 79 63
# 675. vset /object/SM_Trash_Bag_20/color 175 79 63
# 676. vset /object/SM_Trash_Bag_21/color 175 79 63
# 677. vset /object/SM_Trash_Bag_4/color 175 79 63
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-43b3e07fea7a> in <module>()
#       5
#       6     object_list = classes[curr_class]
# ----> 7     curr_color = id2color[object_list[0]]
#       8
#       9     for obj_id in object_list:
#
# KeyError: u'257'

# %% [markdown]
# Begin Data Collection
# ======

# %%
for batch in range(1,1001):

    # Get random location
    z = 200
    x = random.randint(-10, 10)
    y = random.randint(-10, 10)
    
    # Get random yaw
    yaw = random.randint(0,360)

    # Coordinates x, y, z
    client.request('vset /camera/0/location ' + str(x) + ' ' + str(y) + \
                   ' ' + str(z)) 

    # Get 10 shots in a series
    angles = []
    a = 0
    while len(angles) < 20:
        angles.append(a)
        a -= 3

    # Increment height sequentially
    heights = []
    height = 300
    while len(heights) < 20:
        heights.append(height)
        height += 50

    for i,angle in enumerate(angles):
        
        if batch % 100 == 0:
            print("Round: " + str(batch) + " , Image: " + str(i))
            print('D:/UnrealEngineSource/batch15/round' + str(batch) + '/seg' + \
                             str(i) + '.png')
        
        # x, y, z
        client.request('vset /camera/0/location ' + str(x) + ' ' + str(y) + \
                       ' ' + str(heights[i])) 

        # Pitch, yaw, roll
        client.request('vset /camera/0/rotation ' + str(angle) + ' ' + str(yaw) + ' 0')

        # Get Ground Truth
        res = client.request('vget /camera/0/object_mask png')
        object_mask = read_png(res)
        segmentation_image = Image.fromarray(object_mask)
        
        directory = 'D:/UnrealEngineSource/batch15/round' + str(batch) + '/'
        if not os.path.exists(directory):
            os.makedirs(directory)
                    
        segmentation_image.save('D:/UnrealEngineSource/batch15/round' + str(batch) + '/seg' + \
                            str(i) + '.png')
        
        res = client.request('vget /camera/0/lit png')
        normal = read_png(res)
        normal = Image.fromarray(normal)
        
       
        normal.save('D:/UnrealEngineSource/batch15/round' + str(batch) + '/pic' + \
                            str(i) + '.png')
    
        
        # print("Images written. ")
# Out:
# ERROR:__init__:336:Can not receive a response from server, timeout after 5.00 seconds
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-16dd5ed370a2> in <module>()
#      50
#      51         res = client.request('vget /camera/0/lit png')
# ---> 52         normal = read_png(res)
#      53         normal = Image.fromarray(normal)
#      54
#
# <ipython-input-11-c630952580ec> in read_png(res)
#      16
#      17 def read_png(res):
# ---> 18     img = Image.open(StringIO.StringIO(res))
#      19     return np.array(img)
#      20
#
# c:\users\abhay\anaconda3\envs\unrealcv\lib\site-packages\PIL\Image.pyc in open(fp, mode)
#    2583         fp.close()
#    2584     raise IOError("cannot identify image file %r"
# -> 2585                   % (filename if filename else fp))
#    2586
#    2587 #
#
# IOError: cannot identify image file <StringIO.StringIO instance at 0x0000000019956288>
