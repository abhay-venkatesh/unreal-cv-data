# %%
from __future__ import division, absolute_import, print_function
import os, sys, time, re, json
import numpy as np
import random
import matplotlib.pyplot as plt
from PIL import Image
import StringIO
import json

imread = plt.imread
def imread8(im_file):
    ''' Read image as a 8-bit numpy array '''
    im = np.asarray(Image.open(im_file))
    return im

def read_png(res):
    img = Image.open(StringIO.StringIO(res))
    return np.array(img)

def read_npy(res):
    return np.load(res)

# Matches a color from the object_mask and then returns that region color
def match_color(object_mask, target_color, tolerance=3):
    match_region = np.ones(object_mask.shape[0:2], dtype=bool)
    for c in range(3): # r,g,b
        min_val = target_color[c] - tolerance
        max_val = target_color[c] + tolerance
        channel_region = (object_mask[:,:,c] >= min_val) & (object_mask[:,:,c] <= max_val)
        match_region &= channel_region

    if match_region.sum() != 0:
        return match_region
    else:
        return None
    
# Swap colors method
def swap_color(imgarray, source, dest):
    matched_color = match_color(imgarray, [source.R, source.G, source.B])
    imgarray[:,:,:3][matched_color] = [dest.R, dest.G, dest.B]
    return np.array(imgarray)

# %% [markdown]
# Connect to the game
# ===================
# Load unrealcv python client, do :code:`pip install unrealcv` first.

# %%
from unrealcv import client
client.connect()
if not client.isconnected():
    print('UnrealCV server is not running. Run the game downloaded from http://unrealcv.github.io first.')
    sys.exit(-1)
# Out:
# INFO:__init__:204:Got connection confirm: 'connected to NeighborhoodCV'

# %%
# Make sure the connection works well

res = client.request('vget /unrealcv/status')
# The image resolution and port is configured in the config file.
print(res)
# Out:
# Is Listening
# Client Connected
# 9000
# Configuration
# Config file: C:/Program Files/Epic Games/UE_4.13/Engine/Binaries/Win64/unrealcv.ini
# Port: 9000
# Width: 1440
# Height: 900

# %% [markdown]
# Get objects
# ======================
# Write a json file with the object and their corresponding classes.

# %%
scene_objects = client.request('vget /objects').split(' ')
print('Number of objects in this scene:', len(scene_objects))

if '257' in scene_objects:
    scene_objects.remove('257')

obj_id_to_class = {}
for obj_id in scene_objects:
    obj_id_parts = obj_id.split('_')
    class_name = obj_id_parts[0]    
    obj_id_to_class[obj_id] = class_name

# Write JSON file
with open('neighborhood_object_ids.json', 'w') as outfile:
    json.dump(obj_id_to_class, outfile)
# Out:
# Number of objects in this scene: 3762

# %% [markdown]
# Get object colors
# ======================
# First we create the color object class

# %%
class Color(object):
    ''' A utility class to parse color value '''
    regexp = re.compile('\(R=(.*),G=(.*),B=(.*),A=(.*)\)')
    def __init__(self, color_str):
        self.color_str = color_str
        match = self.regexp.match(color_str)
        (self.R, self.G, self.B, self.A) = [int(match.group(i)) for i in range(1,5)]

    def __repr__(self):
        return self.color_str

# %% [markdown]
# Then, we either load from json

# %%
id2color = {}
with open('id2color.json') as data_file:
    data = json.load(data_file)

for obj_id in data.keys():
    color_map = data[obj_id]
    color_str = '(R=' + str(color_map['R']) + ',G=' + \
                str(color_map['G']) + ',B=' + str(color_map['B']) + \
                ',A=' + str(color_map['A']) + ')'
    color = Color(color_str)
    id2color[obj_id] = color

# %% [markdown]
# or We load from the scene

# %%
id2color = {} # Map from object id to the labeling color
for i, obj_id in enumerate(scene_objects):
    color = Color(client.request('vget /object/%s/color' % obj_id))
    id2color[obj_id] = color
    print('%d. %s : %s' % (i, obj_id, str(color)))
# Out:
# 0. WorldSettings_1 : (R=0,G=0,B=0,A=255)
# 1. InstancedFoliageActor_0 : (R=0,G=0,B=255,A=255)
# 2. SkySphere : (R=0,G=255,B=0,A=255)
# 3. Landscape_0 : (R=0,G=255,B=255,A=255)
# 4. Road_2 : (R=255,G=0,B=0,A=255)
# 5. Road_3 : (R=255,G=0,B=255,A=255)
# 6. Road_5 : (R=255,G=255,B=0,A=255)
# 7. Road_7 : (R=255,G=255,B=255,A=255)
# 8. Road_9 : (R=0,G=0,B=127,A=255)
# 9. Road_10 : (R=0,G=255,B=127,A=255)
# 10. Road_11 : (R=255,G=0,B=127,A=255)
# 11. Road_12 : (R=255,G=255,B=127,A=255)
# 12. Road_13 : (R=0,G=127,B=0,A=255)
# 13. Road_14 : (R=0,G=127,B=255,A=255)
# 14. Road_15 : (R=255,G=127,B=0,A=255)
# 15. Road_17 : (R=255,G=127,B=255,A=255)
# 16. Road_18 : (R=0,G=127,B=127,A=255)
# 17. Road_19 : (R=255,G=127,B=127,A=255)
# 18. Road_20 : (R=127,G=0,B=0,A=255)
# 19. Road_21 : (R=127,G=0,B=255,A=255)
# 20. Road_22 : (R=127,G=255,B=0,A=255)
# 21. Road_23 : (R=127,G=255,B=255,A=255)
# 22. Road_24 : (R=127,G=0,B=127,A=255)
# 23. Road_25 : (R=127,G=255,B=127,A=255)
# 24. Road_26 : (R=127,G=127,B=0,A=255)
# 25. Road_27 : (R=127,G=127,B=255,A=255)
# 26. Road_28 : (R=127,G=127,B=127,A=255)
# 27. Road_29 : (R=0,G=0,B=63,A=255)
# 28. Road_30 : (R=0,G=255,B=63,A=255)
# 29. Road_31 : (R=0,G=127,B=63,A=255)
# 30. Road_32 : (R=255,G=0,B=63,A=255)
# 31. Road_33 : (R=255,G=255,B=63,A=255)
# 32. Road_34 : (R=255,G=127,B=63,A=255)
# 33. Road_35 : (R=127,G=0,B=63,A=255)
# 34. Road_36 : (R=127,G=255,B=63,A=255)
# 35. Road_37 : (R=127,G=127,B=63,A=255)
# 36. Road_38 : (R=0,G=63,B=0,A=255)
# 37. Road_39 : (R=0,G=63,B=255,A=255)
# 38. Road_40 : (R=0,G=63,B=127,A=255)
# 39. Road_41 : (R=255,G=63,B=0,A=255)
# 40. Road_42 : (R=255,G=63,B=255,A=255)
# 41. Road_43 : (R=255,G=63,B=127,A=255)
# 42. Road_44 : (R=127,G=63,B=0,A=255)
# 43. Road_45 : (R=127,G=63,B=255,A=255)
# 44. Road_46 : (R=127,G=63,B=127,A=255)
# 45. Road_47 : (R=0,G=63,B=63,A=255)
# 46. Road_49 : (R=255,G=63,B=63,A=255)
# 47. Road_50 : (R=127,G=63,B=63,A=255)
# 48. Road_51 : (R=63,G=0,B=0,A=255)
# 49. Road_52 : (R=63,G=0,B=255,A=255)
# 50. Road_53 : (R=63,G=0,B=127,A=255)
# 51. Road_54 : (R=63,G=255,B=0,A=255)
# 52. Road_55 : (R=63,G=255,B=255,A=255)
# 53. Road_56 : (R=63,G=255,B=127,A=255)
# 54. Road_57 : (R=63,G=127,B=0,A=255)
# 55. Road_58 : (R=63,G=127,B=255,A=255)
# 56. Road_59 : (R=63,G=127,B=127,A=255)
# 57. Road_60 : (R=63,G=0,B=63,A=255)
# 58. Road_61 : (R=63,G=255,B=63,A=255)
# 59. Road_62 : (R=63,G=127,B=63,A=255)
# 60. Road_63 : (R=63,G=63,B=0,A=255)
# 61. Road_65 : (R=63,G=63,B=255,A=255)
# 62. Road_86 : (R=63,G=63,B=127,A=255)
# 63. Road_87 : (R=63,G=63,B=63,A=255)
# 64. Road_66 : (R=0,G=0,B=191,A=255)
# 65. Road_67 : (R=0,G=255,B=191,A=255)
# 66. Road_68 : (R=0,G=127,B=191,A=255)
# 67. Road_69 : (R=0,G=63,B=191,A=255)
# 68. Road_70 : (R=255,G=0,B=191,A=255)
# 69. Road_71 : (R=255,G=255,B=191,A=255)
# 70. Road_72 : (R=255,G=127,B=191,A=255)
# 71. Road_73 : (R=255,G=63,B=191,A=255)
# 72. Road_74 : (R=127,G=0,B=191,A=255)
# 73. Road_75 : (R=127,G=255,B=191,A=255)
# 74. Road_76 : (R=127,G=127,B=191,A=255)
# 75. Road_77 : (R=127,G=63,B=191,A=255)
# 76. Road_78 : (R=63,G=0,B=191,A=255)
# 77. Road_79 : (R=63,G=255,B=191,A=255)
# 78. Road_80 : (R=63,G=127,B=191,A=255)
# 79. Road_82 : (R=63,G=63,B=191,A=255)
# 80. Road_83 : (R=0,G=191,B=0,A=255)
# 81. Road_84 : (R=0,G=191,B=255,A=255)
# 82. Road_85 : (R=0,G=191,B=127,A=255)
# 83. Road_105 : (R=0,G=191,B=63,A=255)
# 84. Road_106 : (R=255,G=191,B=0,A=255)
# 85. Road_88 : (R=255,G=191,B=255,A=255)
# 86. Road_89 : (R=255,G=191,B=127,A=255)
# 87. Road_90 : (R=255,G=191,B=63,A=255)
# 88. Road_91 : (R=127,G=191,B=0,A=255)
# 89. Road_93 : (R=127,G=191,B=255,A=255)
# 90. Road_94 : (R=127,G=191,B=127,A=255)
# 91. Road_95 : (R=127,G=191,B=63,A=255)
# 92. Road_96 : (R=63,G=191,B=0,A=255)
# 93. Floor_01_Basic_109 : (R=63,G=191,B=255,A=255)
# 94. Floor_01_Basic2 : (R=63,G=191,B=127,A=255)
# 95. Floor_01_Basic3 : (R=63,G=191,B=63,A=255)
# 96. Floor_01_Basic4 : (R=0,G=191,B=191,A=255)
# 97. Floor_01_Basic5 : (R=255,G=191,B=191,A=255)
# 98. Floor_01_Basic6 : (R=127,G=191,B=191,A=255)
# 99. Floor_01_Basic7 : (R=63,G=191,B=191,A=255)
# 100. Floor_01_Basic8 : (R=191,G=0,B=0,A=255)
# 101. Floor_01_Basic9 : (R=191,G=0,B=255,A=255)
# 102. Floor_01_Basic10 : (R=191,G=0,B=127,A=255)
# 103. Floor_01_Basic11 : (R=191,G=0,B=63,A=255)
# 104. Floor_01_Basic12 : (R=191,G=255,B=0,A=255)
# 105. Floor_01_Basic13 : (R=191,G=255,B=255,A=255)
# 106. Floor_01_Basic25 : (R=191,G=255,B=127,A=255)
# 107. Floor_01_Basic27 : (R=191,G=255,B=63,A=255)
# 108. Outer_Wall_Half_Win_01_8 : (R=191,G=127,B=0,A=255)
# 109. Outer_Wall_Half_Win_2 : (R=191,G=127,B=255,A=255)
# 110. Outer_Wall_Half_Win_3 : (R=191,G=127,B=127,A=255)
# 111. Outer_Wall_Half_Win_4 : (R=191,G=127,B=63,A=255)
# 112. Outer_Wall_Half_Win_5 : (R=191,G=63,B=0,A=255)
# 113. Outer_Wall_Half_Win_6 : (R=191,G=63,B=255,A=255)
# 114. Outer_Wall_Half_01_16 : (R=191,G=63,B=127,A=255)
# 115. Outer_Wall_Half_Win_7 : (R=191,G=63,B=63,A=255)
# 116. Outer_Wall_Half_Win_8 : (R=191,G=0,B=191,A=255)
# 117. Inner_Wall_Half_Door_01_21 : (R=191,G=255,B=191,A=255)
# 118. Inner_Wall_Half_Arch_01_24 : (R=191,G=127,B=191,A=255)
# 119. Floor_01_Basic28 : (R=191,G=63,B=191,A=255)
# 120. Floor_01_Basic29 : (R=191,G=191,B=0,A=255)
# 121. Outer_Wall_Half_Win_9 : (R=191,G=191,B=255,A=255)
# 122. Outer_Wall_Half_Win_10 : (R=191,G=191,B=127,A=255)
# 123. Outer_Wall_Half_Win_11 : (R=191,G=191,B=63,A=255)
# 124. Outer_Wall_Half_Win_12 : (R=191,G=191,B=191,A=255)
# 125. Outer_Wall_Half_Win_13 : (R=0,G=0,B=31,A=255)
# 126. Outer_Wall_Half_2 : (R=0,G=255,B=31,A=255)
# 127. Outer_Wall_Half_Win_14 : (R=0,G=127,B=31,A=255)
# 128. Outer_Wall_Half_Win_15 : (R=0,G=63,B=31,A=255)
# 129. Roof_Apex_2 : (R=0,G=191,B=31,A=255)
# 130. Roof_Corner_01_56 : (R=255,G=0,B=31,A=255)
# 131. Floor_01_Basic31 : (R=255,G=255,B=31,A=255)
# 132. Outer_Wall_Half_3 : (R=255,G=127,B=31,A=255)
# 133. Outer_Wall_Half_4 : (R=255,G=63,B=31,A=255)
# 134. Outer_Wall_Quart_01_68 : (R=255,G=191,B=31,A=255)
# 135. Roof_Half_01_71 : (R=127,G=0,B=31,A=255)
# 136. Driveway_Edge_3 : (R=127,G=255,B=31,A=255)
# 137. Driveway_Edge_4 : (R=127,G=127,B=31,A=255)
# 138. Driveway_Edge_5 : (R=127,G=63,B=31,A=255)
# 139. Driveway_Edge_6 : (R=127,G=191,B=31,A=255)
# 140. Driveway_Edge_89 : (R=63,G=0,B=31,A=255)
# 141. Driveway_Edge_8 : (R=63,G=255,B=31,A=255)
# 142. Driveway_Edge_9 : (R=63,G=127,B=31,A=255)
# 143. Floor_01_Basic33_99 : (R=63,G=63,B=31,A=255)
# 144. Inner_Wall_Half_Door_103 : (R=63,G=191,B=31,A=255)
# 145. Inner_Wall_Half_Door_3 : (R=191,G=0,B=31,A=255)
# 146. Floor_01_Basic35 : (R=191,G=255,B=31,A=255)
# 147. Floor_01_Basic36 : (R=191,G=127,B=31,A=255)
# 148. Floor_01_Basic37 : (R=191,G=63,B=31,A=255)
# 149. Outer_Wall_Half_Win_114 : (R=191,G=191,B=31,A=255)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2ced0b9f1757> in <module>()
#       1 id2color = {} # Map from object id to the labeling color
#       2 for i, obj_id in enumerate(scene_objects):
# ----> 3     color = Color(client.request('vget /object/%s/color' % obj_id))
#       4     id2color[obj_id] = color
#       5     print('%d. %s : %s' % (i, obj_id, str(color)))
#
# D:\Anaconda3\envs\unrealcv\lib\site-packages\unrealcv\__init__.pyc in request(self, message, timeout)
#     308         # see: https://bugs.python.org/issue8844
#     309         self.wait_response.clear() # This is important
# --> 310         isset = self.wait_response.wait(timeout)
#     311         self.message_id += 1 # Increment it only after the request/response cycle finished
#     312
#
# D:\Anaconda3\envs\unrealcv\lib\threading.pyc in wait(self, timeout)
#     612         with self.__cond:
#     613             if not self.__flag:
# --> 614                 self.__cond.wait(timeout)
#     615             return self.__flag
#     616
#
# D:\Anaconda3\envs\unrealcv\lib\threading.pyc in wait(self, timeout)
#     357                         break
#     358                     delay = min(delay * 2, remaining, .05)
# --> 359                     _sleep(delay)
#     360                 if not gotit:
#     361                     if __debug__:
#
# KeyboardInterrupt:

# %% [markdown]
# Write to JSON if loaded from scene

# %%
# Convert to serializable json dictionary
serializable_map = {}
for color_id in id2color.keys():
    curr_color = id2color[color_id]
    color_map = {}
    color_map['R'] = curr_color.R
    color_map['G'] = curr_color.G
    color_map['B'] = curr_color.B
    color_map['A'] = curr_color.A
    serializable_map[color_id] = color_map

# Write to JSON
with open('id2color.json', 'w') as outfile:
    json.dump(serializable_map, outfile)

# %%
# Map classes to lists of objects
with open('neighborhood_object_ids.json') as data_file:
    obj_id_to_class = json.load(data_file)
    
classes = {}

for obj_id in obj_id_to_class.keys():
    
    curr_class = obj_id_to_class[obj_id]
    if curr_class not in classes:
        classes[curr_class] = []
    
    classes[curr_class].append(obj_id)

# Write classes to json
with open('neighborhood_classes.json', 'w') as outfile:
    json.dump(classes, outfile)

# %%
# Get top 20 classes from json file
with open('class2count.json') as data_file:
    class2count = json.load(data_file)

from operator import itemgetter
class2countlist = sorted(class2count.items(), key=itemgetter(1), reverse=True)

top20 = []
for cls in class2countlist[0:21]:
    top20.append(cls[0])
    
top20tocolor = {}
for cls in top20:
    top20tocolor[cls] = id2color[classes[cls][0]]

serializable_map = {}
for class_id in top20tocolor.keys():
    curr_color = id2color[classes[class_id][0]]
    color_map = {}
    color_map['R'] = curr_color.R
    color_map['G'] = curr_color.G
    color_map['B'] = curr_color.B
    color_map['A'] = curr_color.A
    serializable_map[class_id] = color_map
    
with open('top20tocolor.json', 'w') as outfile:
    json.dump(serializable_map, outfile)

# %%
# Normalize using built in API
counter = 0
for curr_class in classes.keys():
    
    
    object_list = classes[curr_class]
    curr_color = id2color[object_list[0]]
    
    for obj_id in object_list:
        
        if curr_class in top20:
            client.request('vset /object/' + obj_id + '/color ' + \
                       str(top20.index(curr_class)) + ' 0 0')
        
            print(str(counter) + '. vset /object/' + obj_id + '/color ' + \
                       str(top20.index(curr_class)) + ' 0 0')
        else:
            client.request('vset /object/' + obj_id + '/color 0 0 0')
            print(str(counter) + '. vset /object/' + obj_id + '/color 0 0 0')
    
        counter += 1
# Out:
# 0. vset /object/Fir_01_476/color 5 0 0
# 1. vset /object/Fir_19/color 5 0 0
# 2. vset /object/Fir_18/color 5 0 0
# 3. vset /object/Fir_17/color 5 0 0
# 4. vset /object/Fir_16/color 5 0 0
# 5. vset /object/Fir_15/color 5 0 0
# 6. vset /object/Fir_12/color 5 0 0
# 7. vset /object/Fir_11/color 5 0 0
# 8. vset /object/Fir_10/color 5 0 0
# 9. vset /object/Fir_139/color 5 0 0
# 10. vset /object/Fir_482/color 5 0 0
# 11. vset /object/Fir_226/color 5 0 0
# 12. vset /object/Fir_44/color 5 0 0
# 13. vset /object/Fir_45/color 5 0 0
# 14. vset /object/Fir_46/color 5 0 0
# 15. vset /object/Fir_47/color 5 0 0
# 16. vset /object/Fir_40/color 5 0 0
# 17. vset /object/Fir_41/color 5 0 0
# 18. vset /object/Fir_42/color 5 0 0
# 19. vset /object/Fir_43/color 5 0 0
# 20. vset /object/Fir_492/color 5 0 0
# 21. vset /object/Fir_223/color 5 0 0
# 22. vset /object/Fir_229/color 5 0 0
# 23. vset /object/Fir_183/color 5 0 0
# 24. vset /object/Fir_235/color 5 0 0
# 25. vset /object/Fir_232/color 5 0 0
# 26. vset /object/Fir_95/color 5 0 0
# 27. vset /object/Fir_93/color 5 0 0
# 28. vset /object/Fir_7/color 5 0 0
# 29. vset /object/Fir_6/color 5 0 0
# 30. vset /object/Fir_4/color 5 0 0
# 31. vset /object/Fir_3/color 5 0 0
# 32. vset /object/Fir_2/color 5 0 0
# 33. vset /object/Fir_9/color 5 0 0
# 34. vset /object/Fir_8/color 5 0 0
# 35. vset /object/Fir_146/color 5 0 0
# 36. vset /object/Fir_658/color 5 0 0
# 37. vset /object/Fir_26/color 5 0 0
# 38. vset /object/Fir_24/color 5 0 0
# 39. vset /object/Fir_25/color 5 0 0
# 40. vset /object/Fir_22/color 5 0 0
# 41. vset /object/Fir_23/color 5 0 0
# 42. vset /object/Fir_20/color 5 0 0
# 43. vset /object/Fir_21/color 5 0 0
# 44. vset /object/Fir_28/color 5 0 0
# 45. vset /object/Fir_29/color 5 0 0
# 46. vset /object/Fir_35/color 5 0 0
# 47. vset /object/Fir_34/color 5 0 0
# 48. vset /object/Fir_31/color 5 0 0
# 49. vset /object/Fir_30/color 5 0 0
# 50. vset /object/Fir_33/color 5 0 0
# 51. vset /object/Fir_32/color 5 0 0
# 52. vset /object/Fir_39/color 5 0 0
# 53. vset /object/extractor_5/color 0 0 0
# 54. vset /object/extractor_213/color 0 0 0
# 55. vset /object/extractor_209/color 0 0 0
# 56. vset /object/extractor_83/color 0 0 0
# 57. vset /object/extractor_01_55/color 0 0 0
# 58. vset /object/extractor_46/color 0 0 0
# 59. vset /object/Desktop_02_255/color 0 0 0
# 60. vset /object/BP_Fan_2/color 0 0 0
# 61. vset /object/BP_Fan_633/color 0 0 0
# 62. vset /object/BP_Fan_238/color 0 0 0
# 63. vset /object/BP_Fan_01_206/color 0 0 0
# 64. vset /object/Inner_Wall_Half_Door_96/color 0 0 0
# 65. vset /object/Inner_Door_Swing_888/color 0 0 0
# 66. vset /object/Inner_Wall_Half_Door_90/color 0 0 0
# 67. vset /object/Inner_Wall_Half_Door_142/color 0 0 0
# 68. vset /object/Inner_Door_Swing_01_C_29/color 0 0 0
# 263. vset /object/Banister_2/color 0 0 0
# 264. vset /object/Banister_7/color 0 0 0
# 265. vset /object/Banister_6/color 0 0 0
# 266. vset /object/Banister_4/color 0 0 0
# 267. vset /object/Banister_241/color 0 0 0
# 268. vset /object/Banister_298/color 0 0 0
# 269. vset /object/Banister_291/color 0 0 0
# 270. vset /object/Banister_19/color 0 0 0
# 271. vset /object/Banister_18/color 0 0 0
# 272. vset /object/Banister_12/color 0 0 0
# 273. vset /object/Banister_17/color 0 0 0
# 274. vset /object/Banister_16/color 0 0 0
# 275. vset /object/Banister_14/color 0 0 0
# 276. vset /object/Banister_288/color 0 0 0
# 277. vset /object/Banister_End_9/color 0 0 0
# 278. vset /object/Banister_End_13/color 0 0 0
# 279. vset /object/Banister_End_199/color 0 0 0
# 280. vset /object/Banister_31/color 0 0 0
# 281. vset /object/Banister_32/color 0 0 0
# 282. vset /object/Shelf_6/color 0 0 0
# 283. vset /object/Shelf_7/color 0 0 0
# 284. vset /object/Shelf_4/color 0 0 0
# 285. vset /object/Shelf_2/color 0 0 0
# 286. vset /object/Shelf_9/color 0 0 0
# 287. vset /object/Shelf_38/color 0 0 0
# 288. vset /object/Shelf_290/color 0 0 0
# 289. vset /object/Shelf_777/color 0 0 0
# 290. vset /object/Shelf_13/color 0 0 0
# 291. vset /object/Shelf_67/color 0 0 0
# 292. vset /object/Shelf_01_80/color 0 0 0
# 293. vset /object/Shelf_10/color 0 0 0
# 294. vset /object/Shelf_11/color 0 0 0
# 295. vset /object/Lcd_31/color 0 0 0
# 296. vset /object/Lcd_02_29/color 0 0 0
# 297. vset /object/Lcd_18/color 0 0 0
# 298. vset /object/Sink_57/color 0 0 0
# 299. vset /object/Sink_184/color 0 0 0
# 300. vset /object/Sink_01_127/color 0 0 0
# 301. vset /object/Sink_123/color 0 0 0
# 302. vset /object/8/color 0 0 0
# 303. vset /object/Hedge_559/color 1 0 0
# 304. vset /object/Hedge_555/color 1 0 0
# 305. vset /object/Hedge_554/color 1 0 0
# 306. vset /object/Hedge_556/color 1 0 0
# 307. vset /object/Hedge_551/color 1 0 0
# 308. vset /object/Hedge_550/color 1 0 0
# 309. vset /object/Hedge_552/color 1 0 0
# 310. vset /object/Hedge_399/color 1 0 0
# 311. vset /object/Hedge_398/color 1 0 0
# 312. vset /object/Hedge_393/color 1 0 0
# 313. vset /object/Hedge_392/color 1 0 0
# 314. vset /object/Hedge_390/color 1 0 0
# 315. vset /object/Hedge_397/color 1 0 0
# 316. vset /object/Hedge_396/color 1 0 0
# 317. vset /object/Hedge_395/color 1 0 0
# 318. vset /object/Hedge_394/color 1 0 0
# 319. vset /object/Hedge_496/color 1 0 0
# 320. vset /object/Hedge_19/color 1 0 0
# 321. vset /object/Hedge_18/color 1 0 0
# 322. vset /object/Hedge_15/color 1 0 0
# 323. vset /object/Hedge_14/color 1 0 0
# 324. vset /object/Hedge_17/color 1 0 0
# 325. vset /object/Hedge_16/color 1 0 0
# 326. vset /object/Hedge_11/color 1 0 0
# 327. vset /object/Hedge_10/color 1 0 0
# 328. vset /object/Hedge_12/color 1 0 0
# 329. vset /object/Hedge_492/color 1 0 0
# 330. vset /object/Hedge_498/color 1 0 0
# 331. vset /object/Hedge_499/color 1 0 0
# 332. vset /object/Hedge_252/color 1 0 0
# 333. vset /object/Hedge_338/color 1 0 0
# 334. vset /object/Hedge_629/color 1 0 0
# 335. vset /object/Hedge_253/color 1 0 0
# 336. vset /object/Hedge_628/color 1 0 0
# 337. vset /object/Hedge_627/color 1 0 0
# 338. vset /object/Hedge_251/color 1 0 0
# 339. vset /object/Hedge_626/color 1 0 0
# 340. vset /object/Hedge_87/color 1 0 0
# 341. vset /object/Hedge_255/color 1 0 0
# 342. vset /object/Hedge_609/color 1 0 0
# 343. vset /object/Hedge_608/color 1 0 0
# 344. vset /object/Hedge_274/color 1 0 0
# 345. vset /object/Hedge_601/color 1 0 0
# 346. vset /object/Hedge_600/color 1 0 0
# 347. vset /object/Hedge_603/color 1 0 0
# 348. vset /object/Hedge_258/color 1 0 0
# 349. vset /object/Hedge_607/color 1 0 0
# 350. vset /object/Hedge_606/color 1 0 0
# 351. vset /object/Hedge_275/color 1 0 0
# 352. vset /object/Hedge_133/color 1 0 0
# 353. vset /object/Hedge_179/color 1 0 0
# 354. vset /object/Hedge_178/color 1 0 0
# 355. vset /object/Hedge_177/color 1 0 0
# 356. vset /object/Hedge_176/color 1 0 0
# 357. vset /object/Hedge_174/color 1 0 0
# 358. vset /object/Hedge_173/color 1 0 0
# 359. vset /object/Hedge_172/color 1 0 0
# 360. vset /object/Hedge_171/color 1 0 0
# 361. vset /object/Hedge_170/color 1 0 0
# 362. vset /object/Hedge_549/color 1 0 0
# 363. vset /object/Hedge_546/color 1 0 0
# 364. vset /object/Hedge_540/color 1 0 0
# 365. vset /object/Hedge_541/color 1 0 0
# 366. vset /object/Hedge_389/color 1 0 0
# 367. vset /object/Hedge_384/color 1 0 0
# 368. vset /object/Hedge_385/color 1 0 0
# 369. vset /object/Hedge_386/color 1 0 0
# 370. vset /object/Hedge_380/color 1 0 0
# 371. vset /object/Hedge_381/color 1 0 0
# 372. vset /object/Hedge_382/color 1 0 0
# 373. vset /object/Hedge_536/color 1 0 0
# 374. vset /object/Hedge_13/color 1 0 0
# 375. vset /object/Hedge_534/color 1 0 0
# 376. vset /object/Hedge_768/color 1 0 0
# 377. vset /object/Hedge_769/color 1 0 0
# 378. vset /object/Hedge_619/color 1 0 0
# 379. vset /object/Hedge_612/color 1 0 0
# 380. vset /object/Hedge_613/color 1 0 0
# 381. vset /object/Hedge_610/color 1 0 0
# 382. vset /object/Hedge_611/color 1 0 0
# 383. vset /object/Hedge_616/color 1 0 0
# 384. vset /object/Hedge_169/color 1 0 0
# 385. vset /object/Hedge_222/color 1 0 0
# 386. vset /object/Hedge_220/color 1 0 0
# 387. vset /object/Hedge_227/color 1 0 0
# 388. vset /object/Hedge_162/color 1 0 0
# 389. vset /object/Hedge_163/color 1 0 0
# 390. vset /object/Hedge_164/color 1 0 0
# 391. vset /object/Hedge_166/color 1 0 0
# 392. vset /object/Hedge_167/color 1 0 0
# 393. vset /object/Hedge_346/color 1 0 0
# 394. vset /object/Hedge_347/color 1 0 0
# 395. vset /object/Hedge_472/color 1 0 0
# 396. vset /object/Hedge_476/color 1 0 0
# 397. vset /object/Hedge_262/color 1 0 0
# 398. vset /object/Hedge_573/color 1 0 0
# 399. vset /object/Hedge_572/color 1 0 0
# 400. vset /object/Hedge_571/color 1 0 0
# 401. vset /object/Hedge_570/color 1 0 0
# 402. vset /object/Hedge_577/color 1 0 0
# 403. vset /object/Hedge_576/color 1 0 0
# 404. vset /object/Hedge_575/color 1 0 0
# 405. vset /object/Hedge_574/color 1 0 0
# 406. vset /object/Hedge_579/color 1 0 0
# 407. vset /object/Hedge_578/color 1 0 0
# 408. vset /object/Hedge_371/color 1 0 0
# 409. vset /object/Hedge_370/color 1 0 0
# 410. vset /object/Hedge_373/color 1 0 0
# 411. vset /object/Hedge_372/color 1 0 0
# 412. vset /object/Hedge_375/color 1 0 0
# 413. vset /object/Hedge_374/color 1 0 0

# %% [markdown]
# Begin Data Collection (Without Normalization)
# ======

# %%
class2count = {}
for batch in range(1,101):

    # Get random location
    z = 300
    x = random.randint(-5500, 5500)
    y = random.randint(-5500, 5500)

    # Coordinates x, y, z
    client.request('vset /camera/0/location ' + str(x) + ' ' + str(y) + \
                   ' ' + str(z)) 

    # Get 10 shots in a series
    angles = []
    a = 0
    while len(angles) < 20:
        angles.append(a)
        a -= 3

    # Increment height sequentially
    heights = []
    height = 300
    while len(heights) < 20:
        heights.append(height)
        height += 50

    for i,angle in enumerate(angles[1:2]):
        
        print("Batch: " + str(batch) + " , Image: " + str(i))
        
        # x, y, z
        client.request('vset /camera/0/location ' + str(x) + ' ' + str(y) + \
                       ' ' + str(heights[i])) 

        # Pitch, yaw, roll
        client.request('vset /camera/0/rotation ' + str(angle) + ' 0 0')


        # Get Ground Truth
        res = client.request('vget /camera/0/object_mask png')
        object_mask = read_png(res)
        
        # Get all classes in image
        print("Getting all object_ids in image....")
        id2mask = {}
        for obj_id in scene_objects:
            color = id2color[obj_id]
            mask = match_color(object_mask, [color.R, color.G, color.B], tolerance = 3)
            if mask is not None:
                id2mask[obj_id] = mask
        
        # Update class frequency map
        for idmask in id2mask.keys():
            curr_class = obj_id_to_class[idmask]
            if curr_class not in class2count:
                class2count[curr_class] = 1
            else: 
                class2count[curr_class] += 1
               
        # Write to file
        normalized_img = Image.fromarray(object_mask)
        grayscale_img = normalized_img.convert('L')

        directory = './batch/round' + str(batch) + '/'
        if not os.path.exists(directory):
            os.makedirs(directory)
        
        grayscale_img.save('./batch/round' + str(batch) + '/seg' + \
                            str(i) + '.png')
        
        
        res = client.request('vget /camera/0/lit png')
        normal = read_png(res)
        normal = Image.fromarray(normal)
        
        normal.save('./batch/round' + str(batch) + '/pic' + \
                            str(i) + '.png')
        
        print("Images written. ")

with open('class2count.json', 'w') as outfile:
    json.dump(class2count, outfile)
# Out:
# Batch: 1 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 2 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 3 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 4 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 5 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 6 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 7 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 8 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 9 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 10 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 11 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 12 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 13 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 14 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 15 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 16 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 17 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 18 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 19 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 20 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 21 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 22 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 23 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 24 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 25 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 26 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 27 , Image: 0
# Getting all object_ids in image....
# (900L, 1440L, 4L)
# Images written.
# Batch: 28 , Image: 0
# Getting all object_ids in image....
