# %% [markdown]
# Load some python libraries
# The dependencies for this tutorials are
# PIL, Numpy, Matplotlib

# %%
from __future__ import division, absolute_import, print_function
import os, sys, time, re, json
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

imread = plt.imread
def imread8(im_file):
    ''' Read image as a 8-bit numpy array '''
    im = np.asarray(Image.open(im_file))
    return im

def read_png(res):
    img = Image.open(res)
    return np.array(img)

def read_npy(res):
    return np.load(res)

# %% [markdown]
# Connect to the game
# ===================
# Load unrealcv python client, do :code:`pip install unrealcv` first.

# %%
from unrealcv import client
client.connect()
if not client.isconnected():
    print('UnrealCV server is not running. Run the game downloaded from http://unrealcv.github.io first.')
    sys.exit(-1)

# %% [markdown]
# Make sure the connection works well

# %%
res = client.request('vget /unrealcv/status')
# The image resolution and port is configured in the config file.
print(res)
# Out:
# Is Listening
# Client Connected
# 9000

# %% [markdown]
# Ground truth generation
# =======================
# Generate ground truth from this virtual scene

# %%
res = client.request('vget /camera/0/object_mask png')
object_mask = read_png(res)
res = client.request('vget /camera/0/normal png')
normal = read_png(res)

# Visualize the captured ground truth
"""
plt.imshow(object_mask)
plt.figure()
plt.imshow(normal)
"""
# Out:
# '\nplt.imshow(object_mask)\nplt.figure()\nplt.imshow(normal)\n'

# %%
# Swap colors method
def swap_colors(imgarray, source, dest):
    
    red, green, blue, alpha = imgarray.T
    
    source_areas = (red == source.R) & (blue == source.B) & \
        (green == source.G)
    
    newarray = imgarray
    newarray[..., :-1][source_areas.T] = (dest.R, dest.B, dest.G)
    return newarray

# %% [markdown]
# Get objects
# ======================
# Write a json file with the object and their corresponding classes.

# %%
scene_objects = client.request('vget /objects').split(' ')
print('Number of objects in this scene:', len(scene_objects))

data = {}

for obj_id in scene_objects:
    obj_id_parts = obj_id.split('_')
    class_name = obj_id_parts[0]    
    data[obj_id] = class_name

# Write JSON file
import json
with open('neighborhood_classes.json', 'w') as outfile:
    json.dump(data, outfile)
# Out:
# Number of objects in this scene: 3762

# %% [markdown]
# Get object colors
# ======================
# Map the objects to their labeling colors

# %%
# TODO: replace this with a better implementation
class Color(object):
    ''' A utility class to parse color value '''
    regexp = re.compile('\(R=(.*),G=(.*),B=(.*),A=(.*)\)')
    def __init__(self, color_str):
        self.color_str = color_str
        match = self.regexp.match(color_str)
        (self.R, self.G, self.B, self.A) = [int(match.group(i)) for i in range(1,5)]

    def __repr__(self):
        return self.color_str

id2color = {} # Map from object id to the labeling color
for i, obj_id in enumerate(scene_objects):
    color = Color(client.request('vget /object/%s/color' % obj_id))
    id2color[obj_id] = color
    print('%d. %s : %s' % (i, obj_id, str(color)))
# Out:
# 0. WorldSettings_1 : (R=0,G=0,B=0,A=255)
# 1. InstancedFoliageActor_0 : (R=0,G=0,B=255,A=255)
# 2. SkySphere : (R=0,G=255,B=0,A=255)
# 3. Landscape_0 : (R=0,G=255,B=255,A=255)
# 4. Road_2 : (R=255,G=0,B=0,A=255)
# 5. Road_3 : (R=255,G=0,B=255,A=255)
# 6. Road_5 : (R=255,G=255,B=0,A=255)
# 7. Road_7 : (R=255,G=255,B=255,A=255)
# 8. Road_9 : (R=0,G=0,B=127,A=255)
# 9. Road_10 : (R=0,G=255,B=127,A=255)
# 10. Road_11 : (R=255,G=0,B=127,A=255)
# 11. Road_12 : (R=255,G=255,B=127,A=255)
# 12. Road_13 : (R=0,G=127,B=0,A=255)
# 13. Road_14 : (R=0,G=127,B=255,A=255)
# 14. Road_15 : (R=255,G=127,B=0,A=255)
# 15. Road_17 : (R=255,G=127,B=255,A=255)
# 16. Road_18 : (R=0,G=127,B=127,A=255)
# 17. Road_19 : (R=255,G=127,B=127,A=255)
# 18. Road_20 : (R=127,G=0,B=0,A=255)
# 19. Road_21 : (R=127,G=0,B=255,A=255)
# 20. Road_22 : (R=127,G=255,B=0,A=255)
# 21. Road_23 : (R=127,G=255,B=255,A=255)
# 22. Road_24 : (R=127,G=0,B=127,A=255)
# 23. Road_25 : (R=127,G=255,B=127,A=255)
# 24. Road_26 : (R=127,G=127,B=0,A=255)
# 25. Road_27 : (R=127,G=127,B=255,A=255)
# 26. Road_28 : (R=127,G=127,B=127,A=255)
# 27. Road_29 : (R=0,G=0,B=63,A=255)
# 28. Road_30 : (R=0,G=255,B=63,A=255)
# 29. Road_31 : (R=0,G=127,B=63,A=255)
# 30. Road_32 : (R=255,G=0,B=63,A=255)
# 31. Road_33 : (R=255,G=255,B=63,A=255)
# 32. Road_34 : (R=255,G=127,B=63,A=255)
# 33. Road_35 : (R=127,G=0,B=63,A=255)
# 34. Road_36 : (R=127,G=255,B=63,A=255)
# 35. Road_37 : (R=127,G=127,B=63,A=255)
# 36. Road_38 : (R=0,G=63,B=0,A=255)
# 37. Road_39 : (R=0,G=63,B=255,A=255)
# 38. Road_40 : (R=0,G=63,B=127,A=255)
# 39. Road_41 : (R=255,G=63,B=0,A=255)
# 40. Road_42 : (R=255,G=63,B=255,A=255)
# 41. Road_43 : (R=255,G=63,B=127,A=255)
# 42. Road_44 : (R=127,G=63,B=0,A=255)
# 43. Road_45 : (R=127,G=63,B=255,A=255)
# 44. Road_46 : (R=127,G=63,B=127,A=255)
# 45. Road_47 : (R=0,G=63,B=63,A=255)
# 46. Road_49 : (R=255,G=63,B=63,A=255)
# 47. Road_50 : (R=127,G=63,B=63,A=255)
# 48. Road_51 : (R=63,G=0,B=0,A=255)
# 49. Road_52 : (R=63,G=0,B=255,A=255)
# 50. Road_53 : (R=63,G=0,B=127,A=255)
# 51. Road_54 : (R=63,G=255,B=0,A=255)
# 52. Road_55 : (R=63,G=255,B=255,A=255)
# 53. Road_56 : (R=63,G=255,B=127,A=255)
# 54. Road_57 : (R=63,G=127,B=0,A=255)
# 55. Road_58 : (R=63,G=127,B=255,A=255)
# 56. Road_59 : (R=63,G=127,B=127,A=255)
# 57. Road_60 : (R=63,G=0,B=63,A=255)
# 58. Road_61 : (R=63,G=255,B=63,A=255)
# 59. Road_62 : (R=63,G=127,B=63,A=255)
# 60. Road_63 : (R=63,G=63,B=0,A=255)
# 61. Road_65 : (R=63,G=63,B=255,A=255)
# 62. Road_86 : (R=63,G=63,B=127,A=255)
# 63. Road_87 : (R=63,G=63,B=63,A=255)
# 64. Road_66 : (R=0,G=0,B=191,A=255)
# 65. Road_67 : (R=0,G=255,B=191,A=255)
# 66. Road_68 : (R=0,G=127,B=191,A=255)
# 67. Road_69 : (R=0,G=63,B=191,A=255)
# 68. Road_70 : (R=255,G=0,B=191,A=255)
# 69. Road_71 : (R=255,G=255,B=191,A=255)
# 70. Road_72 : (R=255,G=127,B=191,A=255)
# 71. Road_73 : (R=255,G=63,B=191,A=255)
# 72. Road_74 : (R=127,G=0,B=191,A=255)
# 73. Road_75 : (R=127,G=255,B=191,A=255)
# 74. Road_76 : (R=127,G=127,B=191,A=255)
# 75. Road_77 : (R=127,G=63,B=191,A=255)
# 76. Road_78 : (R=63,G=0,B=191,A=255)
# 77. Road_79 : (R=63,G=255,B=191,A=255)
# 78. Road_80 : (R=63,G=127,B=191,A=255)
# 79. Road_82 : (R=63,G=63,B=191,A=255)
# 80. Road_83 : (R=0,G=191,B=0,A=255)
# 81. Road_84 : (R=0,G=191,B=255,A=255)
# 82. Road_85 : (R=0,G=191,B=127,A=255)
# 83. Road_105 : (R=0,G=191,B=63,A=255)
# 84. Road_106 : (R=255,G=191,B=0,A=255)
# 85. Road_88 : (R=255,G=191,B=255,A=255)
# 86. Road_89 : (R=255,G=191,B=127,A=255)
# 87. Road_90 : (R=255,G=191,B=63,A=255)
# 88. Road_91 : (R=127,G=191,B=0,A=255)
# 89. Road_93 : (R=127,G=191,B=255,A=255)
# 90. Road_94 : (R=127,G=191,B=127,A=255)
# 91. Road_95 : (R=127,G=191,B=63,A=255)
# 92. Road_96 : (R=63,G=191,B=0,A=255)
# 93. Floor_01_Basic_109 : (R=63,G=191,B=255,A=255)
# 94. Floor_01_Basic2 : (R=63,G=191,B=127,A=255)
# 95. Floor_01_Basic3 : (R=63,G=191,B=63,A=255)
# 96. Floor_01_Basic4 : (R=0,G=191,B=191,A=255)
# 97. Floor_01_Basic5 : (R=255,G=191,B=191,A=255)
# 98. Floor_01_Basic6 : (R=127,G=191,B=191,A=255)
# 99. Floor_01_Basic7 : (R=63,G=191,B=191,A=255)
# 100. Floor_01_Basic8 : (R=191,G=0,B=0,A=255)
# 101. Floor_01_Basic9 : (R=191,G=0,B=255,A=255)
# 102. Floor_01_Basic10 : (R=191,G=0,B=127,A=255)
# 103. Floor_01_Basic11 : (R=191,G=0,B=63,A=255)
# 104. Floor_01_Basic12 : (R=191,G=255,B=0,A=255)
# 105. Floor_01_Basic13 : (R=191,G=255,B=255,A=255)
# 106. Floor_01_Basic25 : (R=191,G=255,B=127,A=255)
# 107. Floor_01_Basic27 : (R=191,G=255,B=63,A=255)
# 108. Outer_Wall_Half_Win_01_8 : (R=191,G=127,B=0,A=255)
# 109. Outer_Wall_Half_Win_2 : (R=191,G=127,B=255,A=255)
# 110. Outer_Wall_Half_Win_3 : (R=191,G=127,B=127,A=255)
# 111. Outer_Wall_Half_Win_4 : (R=191,G=127,B=63,A=255)
# 112. Outer_Wall_Half_Win_5 : (R=191,G=63,B=0,A=255)
# 113. Outer_Wall_Half_Win_6 : (R=191,G=63,B=255,A=255)
# 114. Outer_Wall_Half_01_16 : (R=191,G=63,B=127,A=255)
# 115. Outer_Wall_Half_Win_7 : (R=191,G=63,B=63,A=255)
# 116. Outer_Wall_Half_Win_8 : (R=191,G=0,B=191,A=255)
# 117. Inner_Wall_Half_Door_01_21 : (R=191,G=255,B=191,A=255)
# 118. Inner_Wall_Half_Arch_01_24 : (R=191,G=127,B=191,A=255)
# 119. Floor_01_Basic28 : (R=191,G=63,B=191,A=255)
# 120. Floor_01_Basic29 : (R=191,G=191,B=0,A=255)
# 121. Outer_Wall_Half_Win_9 : (R=191,G=191,B=255,A=255)
# 122. Outer_Wall_Half_Win_10 : (R=191,G=191,B=127,A=255)
# 123. Outer_Wall_Half_Win_11 : (R=191,G=191,B=63,A=255)
# 124. Outer_Wall_Half_Win_12 : (R=191,G=191,B=191,A=255)
# 125. Outer_Wall_Half_Win_13 : (R=0,G=0,B=31,A=255)
# 126. Outer_Wall_Half_2 : (R=0,G=255,B=31,A=255)
# 127. Outer_Wall_Half_Win_14 : (R=0,G=127,B=31,A=255)
# 128. Outer_Wall_Half_Win_15 : (R=0,G=63,B=31,A=255)
# 129. Roof_Apex_2 : (R=0,G=191,B=31,A=255)
# 130. Roof_Corner_01_56 : (R=255,G=0,B=31,A=255)
# 131. Floor_01_Basic31 : (R=255,G=255,B=31,A=255)
# 132. Outer_Wall_Half_3 : (R=255,G=127,B=31,A=255)
# 133. Outer_Wall_Half_4 : (R=255,G=63,B=31,A=255)
# 134. Outer_Wall_Quart_01_68 : (R=255,G=191,B=31,A=255)
# 135. Roof_Half_01_71 : (R=127,G=0,B=31,A=255)
# 136. Driveway_Edge_3 : (R=127,G=255,B=31,A=255)
# 137. Driveway_Edge_4 : (R=127,G=127,B=31,A=255)
# 138. Driveway_Edge_5 : (R=127,G=63,B=31,A=255)
# 139. Driveway_Edge_6 : (R=127,G=191,B=31,A=255)
# 140. Driveway_Edge_89 : (R=63,G=0,B=31,A=255)
# 141. Driveway_Edge_8 : (R=63,G=255,B=31,A=255)
# 142. Driveway_Edge_9 : (R=63,G=127,B=31,A=255)
# 143. Floor_01_Basic33_99 : (R=63,G=63,B=31,A=255)
# 144. Inner_Wall_Half_Door_103 : (R=63,G=191,B=31,A=255)
# 145. Inner_Wall_Half_Door_3 : (R=191,G=0,B=31,A=255)
# 146. Floor_01_Basic35 : (R=191,G=255,B=31,A=255)
# 147. Floor_01_Basic36 : (R=191,G=127,B=31,A=255)
# 148. Floor_01_Basic37 : (R=191,G=63,B=31,A=255)
# 149. Outer_Wall_Half_Win_114 : (R=191,G=191,B=31,A=255)
# 150. Outer_Wall_Half_Win_17 : (R=0,G=31,B=0,A=255)
# 151. Outer_Wall_Half_Win_18 : (R=0,G=31,B=255,A=255)
# 152. Outer_Wall_Half_Win_19 : (R=0,G=31,B=127,A=255)
# 153. Outer_Wall_Half_Win_20 : (R=0,G=31,B=63,A=255)
# 154. Outer_Wall_Half_Win_21 : (R=0,G=31,B=191,A=255)
# 155. Outer_Wall_Half_Garage_01_122 : (R=255,G=31,B=0,A=255)
# 156. Outer_Wall_Half_Win_22 : (R=255,G=31,B=255,A=255)
# 157. Floor_01_Basic38 : (R=255,G=31,B=127,A=255)
# 158. Floor_01_Basic39 : (R=255,G=31,B=63,A=255)
# 159. Outer_Wall_Half_Win_23 : (R=255,G=31,B=191,A=255)
# 160. Outer_Wall_Half_Win_24 : (R=127,G=31,B=0,A=255)
# 161. Outer_Wall_Half_Win_25 : (R=127,G=31,B=255,A=255)
# 162. Outer_Wall_Half_Win_26 : (R=127,G=31,B=127,A=255)
# 163. Floor_01_Basic41 : (R=127,G=31,B=63,A=255)
# 164. Outer_Wall_Half_Win_28 : (R=127,G=31,B=191,A=255)
# 165. Outer_Wall_Half_Win_29 : (R=63,G=31,B=0,A=255)
# 166. Outer_Wall_Half_Apex_01_143 : (R=63,G=31,B=255,A=255)
# 167. Outer_Wall_Half_Win_30 : (R=63,G=31,B=127,A=255)
# 168. Hedge_01_154 : (R=63,G=31,B=63,A=255)
# 169. Hedge_2 : (R=63,G=31,B=191,A=255)
# 170. Hedge_3 : (R=191,G=31,B=0,A=255)
# 171. Outer_Wall_Quart_Floor_01_159 : (R=191,G=31,B=255,A=255)
# 172. Outer_Wall_Quart_Win_02_162 : (R=191,G=31,B=127,A=255)
# 173. Outer_Wall_Quart_Win_3 : (R=191,G=31,B=63,A=255)
# 174. Outer_Wall_Half_Win_166 : (R=191,G=31,B=191,A=255)
# 175. Outer_Wall_Half_Win_32 : (R=0,G=31,B=31,A=255)
# 176. Outer_Wall_Half_Win_33 : (R=255,G=31,B=31,A=255)
# 177. Outer_Wall_Half_Win_34 : (R=127,G=31,B=31,A=255)
# 178. Outer_Wall_Half_Win_35 : (R=63,G=31,B=31,A=255)
# 179. Outer_Wall_Half_Win_36 : (R=191,G=31,B=31,A=255)
# 180. Outer_Wall_Half_Win_37 : (R=31,G=0,B=0,A=255)
# 181. Outer_Wall_Quart_Win_4 : (R=31,G=0,B=255,A=255)
# 182. Outer_Wall_Quart_Win_5 : (R=31,G=0,B=127,A=255)
# 183. Outer_Wall_Half_Win_38 : (R=31,G=0,B=63,A=255)
# 184. Outer_Wall_Half_Win_39 : (R=31,G=0,B=191,A=255)
# 185. Outer_Wall_Half_Win_40 : (R=31,G=255,B=0,A=255)
# 186. Outer_Wall_Half_Win_41 : (R=31,G=255,B=255,A=255)
# 187. Outer_Wall_Half_Win_42 : (R=31,G=255,B=127,A=255)
# 188. Outer_Wall_Half_Win_43 : (R=31,G=255,B=63,A=255)
# 189. Outer_Wall_Half_Win_44 : (R=31,G=255,B=191,A=255)
# 190. Floor_01_Basic44 : (R=31,G=127,B=0,A=255)
# 191. Floor_01_Basic45 : (R=31,G=127,B=255,A=255)
# 192. Outer_Wall_Quart_Floor_187 : (R=31,G=127,B=127,A=255)
# 193. Outer_Wall_Quart_Floor_3 : (R=31,G=127,B=63,A=255)
# 194. Outer_Wall_Quart_Floor_4 : (R=31,G=127,B=191,A=255)
# 195. Outer_Wall_Quart_Floor_5 : (R=31,G=63,B=0,A=255)
# 196. Outer_Wall_Quart_Win_6 : (R=31,G=63,B=255,A=255)
# 197. Outer_Wall_Quart_Win_7 : (R=31,G=63,B=127,A=255)
# 198. Roof_Corner_199 : (R=31,G=63,B=63,A=255)
# 199. Hedge_02_202 : (R=31,G=63,B=191,A=255)
# 200. Hedge_4 : (R=31,G=191,B=0,A=255)
# 201. Hedge_5 : (R=31,G=191,B=255,A=255)
# 202. Hedge_207 : (R=31,G=191,B=127,A=255)
# 203. Hedge_7 : (R=31,G=191,B=63,A=255)
# 204. Hedge_8 : (R=31,G=191,B=191,A=255)
# 205. Hedge_9 : (R=31,G=0,B=31,A=255)
# 206. Hedge_10 : (R=31,G=255,B=31,A=255)
# 207. Hedge_11 : (R=31,G=127,B=31,A=255)
# 208. Hedge_12 : (R=31,G=63,B=31,A=255)
# 209. Hedge_13 : (R=31,G=191,B=31,A=255)
# 210. Hedge_14 : (R=31,G=31,B=0,A=255)
# 211. Hedge_15 : (R=31,G=31,B=255,A=255)
# 212. Hedge_219 : (R=31,G=31,B=127,A=255)
# 213. Hedge_17 : (R=31,G=31,B=63,A=255)
# 214. Hedge_18 : (R=31,G=31,B=191,A=255)
# 215. Hedge_19 : (R=31,G=31,B=31,A=255)
# 216. Hedge_20 : (R=0,G=0,B=95,A=255)
# 217. Hedge_21 : (R=0,G=255,B=95,A=255)
# 218. Swimming_Pool_Edge_01_228 : (R=0,G=127,B=95,A=255)
# 219. Swimming_Pool_Edge_2 : (R=0,G=63,B=95,A=255)
# 220. Swimming_Pool_Edge_3 : (R=0,G=191,B=95,A=255)
# 221. Swimming_Pool_Edge_4 : (R=0,G=31,B=95,A=255)
# 222. Swimming_Pool_Curve_01_234 : (R=255,G=0,B=95,A=255)
# 223. Swimming_Pool_Edge_5 : (R=255,G=255,B=95,A=255)
# 224. Swimming_Pool_Curve_2 : (R=255,G=127,B=95,A=255)
# 225. Swimming_Pool_Edge_6 : (R=255,G=63,B=95,A=255)
# 226. Swimming_Pool_Curve_3 : (R=255,G=191,B=95,A=255)
# 227. Swimming_Pool_Curve_4 : (R=255,G=31,B=95,A=255)
# 228. Swimming_Pool_Curve_5 : (R=127,G=0,B=95,A=255)
# 229. Swimming_Pool_Edge_7 : (R=127,G=255,B=95,A=255)
# 230. Swimming_Pool_Edge_8 : (R=127,G=127,B=95,A=255)
# 231. Swimming_Pool_Curve_6 : (R=127,G=63,B=95,A=255)
# 232. Swimming_Pool_Floor_01_251 : (R=127,G=191,B=95,A=255)
# 233. driveway_16th_Curve_02_254 : (R=127,G=31,B=95,A=255)
# 234. driveway_16th_Curve_3 : (R=63,G=0,B=95,A=255)
# 235. driveway_16th_Curve_4 : (R=63,G=255,B=95,A=255)
# 236. driveway_16th_Curve_5 : (R=63,G=127,B=95,A=255)
# 237. driveway_16th_Curve_6 : (R=63,G=63,B=95,A=255)
# 238. driveway_16th_Curve_01_261 : (R=63,G=191,B=95,A=255)
# 239. Driveway_8th_5 : (R=63,G=31,B=95,A=255)
# 240. Driveway_8th_7 : (R=191,G=0,B=95,A=255)
# 241. Driveway_Quart_01_273 : (R=191,G=255,B=95,A=255)
# 242. Driveway_16th_01_277 : (R=191,G=127,B=95,A=255)
# 243. Driveway_16th_2 : (R=191,G=63,B=95,A=255)
# 244. Driveway_Half_01_281 : (R=191,G=191,B=95,A=255)
# 245. Driveway_Half_2 : (R=191,G=31,B=95,A=255)
# 246. Driveway_Half_3 : (R=31,G=0,B=95,A=255)
# 247. Driveway_Half_4 : (R=31,G=255,B=95,A=255)
# 248. Driveway_Quart_2 : (R=31,G=127,B=95,A=255)
# 249. Driveway_8th_8 : (R=31,G=63,B=95,A=255)
# 250. Driveway_8th_9 : (R=31,G=191,B=95,A=255)
# 251. Driveway_8th_10 : (R=31,G=31,B=95,A=255)
# 252. Driveway_8th_11 : (R=0,G=95,B=0,A=255)
# 253. Driveway_8th_12 : (R=0,G=95,B=255,A=255)
# 254. Driveway_8th_01_293 : (R=0,G=95,B=127,A=255)
# 255. Driveway_8th_295 : (R=0,G=95,B=63,A=255)
# 256. Driveway_8th_297 : (R=0,G=95,B=191,A=255)
# 257. Driveway_01_306 : (R=0,G=95,B=31,A=255)
# 258. Floor_01_Basic46_309 : (R=255,G=95,B=0,A=255)
# 259. Floor_01_Basic47 : (R=255,G=95,B=255,A=255)
# 260. Outer_Wall_Half_Win_313 : (R=255,G=95,B=127,A=255)
# 261. Outer_Wall_Quart_Win_316 : (R=255,G=95,B=63,A=255)
# 262. Outer_Wall_Half_Win_46 : (R=255,G=95,B=191,A=255)
# 263. Floor_01_Basic48 : (R=255,G=95,B=31,A=255)
# 264. Outer_Wall_Half_Win_47 : (R=127,G=95,B=0,A=255)
# 265. Outer_Wall_Half_Win_48 : (R=127,G=95,B=255,A=255)
# 266. Outer_Wall_Half_Door_01_324 : (R=127,G=95,B=127,A=255)
# 267. Outer_Wall_Half_Win_49 : (R=127,G=95,B=63,A=255)
# 268. Outer_Wall_Half_Win_50 : (R=127,G=95,B=191,A=255)
# 269. Floor_01_Basic49 : (R=127,G=95,B=31,A=255)
# 270. Floor_01_Basic50 : (R=63,G=95,B=0,A=255)
# 271. Floor_01_Basic51 : (R=63,G=95,B=255,A=255)
# 272. Roof_Apex_332 : (R=63,G=95,B=127,A=255)
# 273. Roof_Apex_9 : (R=63,G=95,B=63,A=255)
# 274. Roof_Corner_336 : (R=63,G=95,B=191,A=255)
# 275. Outer_Wall_Quart_Roof_01_339 : (R=63,G=95,B=31,A=255)
# 276. Driveway_350 : (R=191,G=95,B=0,A=255)
# 277. Driveway_Half_353 : (R=191,G=95,B=255,A=255)
# 278. driveway_16th_Curve_356 : (R=191,G=95,B=127,A=255)
# 279. Driveway_16th_5 : (R=191,G=95,B=63,A=255)
# 280. driveway_16th_Curve_368 : (R=191,G=95,B=191,A=255)
# 281. driveway_16th_Curve_371 : (R=191,G=95,B=31,A=255)
# 282. Driveway_8th_374 : (R=31,G=95,B=0,A=255)
# 283. Driveway_8th_6 : (R=31,G=95,B=255,A=255)
# 284. Driveway_8th_13 : (R=31,G=95,B=127,A=255)
# 285. Driveway_8th_14 : (R=31,G=95,B=63,A=255)
# 286. Driveway_16th_380 : (R=31,G=95,B=191,A=255)
# 287. driveway_16th_Curve_383 : (R=31,G=95,B=31,A=255)
# 288. Driveway_8th_388 : (R=0,G=95,B=95,A=255)
# 289. Driveway_8th_16 : (R=255,G=95,B=95,A=255)
# 290. Driveway_8th_17 : (R=127,G=95,B=95,A=255)
# 291. Driveway_8th_18 : (R=63,G=95,B=95,A=255)
# 292. Driveway_8th_19 : (R=191,G=95,B=95,A=255)
# 293. Driveway_8th_20 : (R=31,G=95,B=95,A=255)
# 294. driveway_16th_Curve_396 : (R=95,G=0,B=0,A=255)
# 295. Outer_Wall_Half_Win_51 : (R=95,G=0,B=255,A=255)
# 296. Roof_Half_407 : (R=95,G=0,B=127,A=255)
# 297. Outer_Wall_Half_Win_52 : (R=95,G=0,B=63,A=255)
# 298. Outer_Wall_Quart_411 : (R=95,G=0,B=191,A=255)
# 299. Floor_Half_02_414 : (R=95,G=0,B=31,A=255)
# 300. Driveway_Half_416 : (R=95,G=255,B=0,A=255)
# 301. driveway_16th_Curve_419 : (R=95,G=255,B=255,A=255)
# 302. driveway_16th_Curve_422 : (R=95,G=255,B=127,A=255)
# 303. Driveway_8th_425 : (R=95,G=255,B=63,A=255)
# 304. Driveway_16th_429 : (R=95,G=255,B=191,A=255)
# 305. driveway_16th_Curve_432 : (R=95,G=255,B=31,A=255)
# 306. Inner_Wall_Half_Arch_435 : (R=95,G=127,B=0,A=255)
# 307. Hedge_438 : (R=95,G=127,B=255,A=255)
# 308. Hedge_23 : (R=95,G=127,B=127,A=255)
# 309. Hedge_24 : (R=95,G=127,B=63,A=255)
# 310. Hedge_25 : (R=95,G=127,B=191,A=255)
# 311. Hedge_26 : (R=95,G=127,B=31,A=255)
# 312. Hedge_27 : (R=95,G=63,B=0,A=255)
# 313. Hedge_28 : (R=95,G=63,B=255,A=255)
# 314. Hedge_29 : (R=95,G=63,B=127,A=255)
# 315. Hedge_30 : (R=95,G=63,B=63,A=255)
# 316. Hedge_31 : (R=95,G=63,B=191,A=255)
# 317. Hedge_32 : (R=95,G=63,B=31,A=255)
# 318. Hedge_33 : (R=95,G=191,B=0,A=255)
# 319. Hedge_34 : (R=95,G=191,B=255,A=255)
# 320. Hedge_35 : (R=95,G=191,B=127,A=255)
# 321. Hedge_36 : (R=95,G=191,B=63,A=255)
# 322. Hedge_37 : (R=95,G=191,B=191,A=255)
# 323. Hedge_38 : (R=95,G=191,B=31,A=255)
# 324. Hedge_39 : (R=95,G=31,B=0,A=255)
# 325. Hedge_40 : (R=95,G=31,B=255,A=255)
# 326. Hedge_41 : (R=95,G=31,B=127,A=255)
# 327. Hedge_42 : (R=95,G=31,B=63,A=255)
# 328. Hedge_43 : (R=95,G=31,B=191,A=255)
# 329. Hedge_44 : (R=95,G=31,B=31,A=255)
# 330. Hedge_45 : (R=95,G=0,B=95,A=255)
# 331. Hedge_46 : (R=95,G=255,B=95,A=255)
# 332. Hedge_47 : (R=95,G=127,B=95,A=255)
# 333. Hedge_48 : (R=95,G=63,B=95,A=255)
# 334. Hedge_49 : (R=95,G=191,B=95,A=255)
# 335. Fir_01_476 : (R=95,G=31,B=95,A=255)
# 336. Fir_2 : (R=95,G=95,B=0,A=255)
# 337. Fir_3 : (R=95,G=95,B=255,A=255)
# 338. Fir_4 : (R=95,G=95,B=127,A=255)
# 339. Fir_482 : (R=95,G=95,B=63,A=255)
# 340. Fir_6 : (R=95,G=95,B=191,A=255)
# 341. Fir_7 : (R=95,G=95,B=31,A=255)
# 342. Fir_8 : (R=95,G=95,B=95,A=255)
# 343. Fir_9 : (R=0,G=0,B=159,A=255)
# 344. Fir_10 : (R=0,G=255,B=159,A=255)
# 345. Fir_11 : (R=0,G=127,B=159,A=255)
# 346. Fir_12 : (R=0,G=63,B=159,A=255)
# 347. Fir_492 : (R=0,G=191,B=159,A=255)
# 348. Hedge_495 : (R=0,G=31,B=159,A=255)
# 349. Hedge_51 : (R=0,G=95,B=159,A=255)
# 350. Hedge_52 : (R=255,G=0,B=159,A=255)
# 351. Driveway_502 : (R=255,G=255,B=159,A=255)
# 352. Driveway_509 : (R=255,G=127,B=159,A=255)
# 353. Floor_01_Basic53 : (R=255,G=63,B=159,A=255)
# 354. Outer_Wall_Half_Door_516 : (R=255,G=191,B=159,A=255)
# 355. Outer_Wall_Half_Win_54 : (R=255,G=31,B=159,A=255)
# 356. Outer_Wall_Half_Win_55 : (R=255,G=95,B=159,A=255)
# 357. Outer_Wall_Half_Win_56 : (R=127,G=0,B=159,A=255)
# 358. Outer_Wall_Half_Win_525 : (R=127,G=255,B=159,A=255)
# 359. Outer_Wall_Half_Win_58 : (R=127,G=127,B=159,A=255)
# 360. Outer_Wall_Half_Win_59 : (R=127,G=63,B=159,A=255)
# 361. Outer_Wall_Half_Win_60 : (R=127,G=191,B=159,A=255)
# 362. Outer_Wall_Half_Win_61 : (R=127,G=31,B=159,A=255)
# 363. Outer_Wall_Half_Win_62 : (R=127,G=95,B=159,A=255)
# 364. Floor_01_Basic54 : (R=63,G=0,B=159,A=255)
# 365. Floor_Quart_01_537 : (R=63,G=255,B=159,A=255)
# 366. Outer_Wall_Half_Door_3 : (R=63,G=127,B=159,A=255)
# 367. Outer_Wall_Half_Win_64 : (R=63,G=63,B=159,A=255)
# 368. Outer_Wall_Half_Win_65 : (R=63,G=191,B=159,A=255)
# 369. Outer_Wall_Half_Win_66 : (R=63,G=31,B=159,A=255)
# 370. Outer_Wall_Half_Win_67 : (R=63,G=95,B=159,A=255)
# 371. Outer_Wall_Half_Win_69 : (R=191,G=0,B=159,A=255)
# 372. Outer_Wall_Half_Win_70 : (R=191,G=255,B=159,A=255)
# 373. Roof_Quart_Open_01_555 : (R=191,G=127,B=159,A=255)
# 374. Roof_Corner_558 : (R=191,G=63,B=159,A=255)
# 375. Outer_Wall_Half_Apex_566 : (R=191,G=191,B=159,A=255)
# 376. Outer_Wall_Half_Win_568 : (R=191,G=31,B=159,A=255)
# 377. Driveway_5 : (R=191,G=95,B=159,A=255)
# 378. Hedge_53 : (R=31,G=0,B=159,A=255)
# 379. Hedge_54 : (R=31,G=255,B=159,A=255)
# 380. Hedge_55 : (R=31,G=127,B=159,A=255)
# 381. Driveway_Edge_575 : (R=31,G=63,B=159,A=255)
# 382. Driveway_Edge_11 : (R=31,G=191,B=159,A=255)
# 383. Driveway_Edge_12 : (R=31,G=31,B=159,A=255)
# 384. Driveway_Edge_13 : (R=31,G=95,B=159,A=255)
# 385. Driveway_Edge_14 : (R=95,G=0,B=159,A=255)
# 386. Driveway_Edge_15 : (R=95,G=255,B=159,A=255)
# 387. Driveway_Edge_16 : (R=95,G=127,B=159,A=255)
# 388. Driveway_Edge_17 : (R=95,G=63,B=159,A=255)
# 389. Driveway_Edge_18 : (R=95,G=191,B=159,A=255)
# 390. Driveway_Edge_19 : (R=95,G=31,B=159,A=255)
# 391. Driveway_Edge_20 : (R=95,G=95,B=159,A=255)
# 392. Driveway_Edge_21 : (R=0,G=159,B=0,A=255)
# 393. Driveway_Edge_22 : (R=0,G=159,B=255,A=255)
# 394. Driveway_Edge_23 : (R=0,G=159,B=127,A=255)
# 395. Floor_01_Basic55 : (R=0,G=159,B=63,A=255)
# 396. Floor_01_Basic56 : (R=0,G=159,B=191,A=255)
# 397. Floor_01_Basic57 : (R=0,G=159,B=31,A=255)
# 398. Floor_01_Basic59 : (R=0,G=159,B=95,A=255)
# 399. Floor_Quart_3 : (R=255,G=159,B=0,A=255)
# 400. Outer_Wall_Quart_Floor_598 : (R=255,G=159,B=255,A=255)
# 401. Outer_Wall_Quart_Floor_7 : (R=255,G=159,B=127,A=255)
# 402. Banister_01_602 : (R=255,G=159,B=63,A=255)
# 403. Banister_2 : (R=255,G=159,B=191,A=255)
# 404. Banister_End_01_606 : (R=255,G=159,B=31,A=255)
# 405. Inner_Wall_Close_Gap_01_609 : (R=255,G=159,B=95,A=255)
# 406. Swimming_Pool_Curve_618 : (R=127,G=159,B=0,A=255)
# 407. Swimming_Pool_Curve_8 : (R=127,G=159,B=255,A=255)
# 408. Swimming_Pool_Edge_622 : (R=127,G=159,B=127,A=255)
# 409. Swimming_Pool_Edge_10 : (R=127,G=159,B=63,A=255)
# 410. Swimming_Pool_Edge_11 : (R=127,G=159,B=191,A=255)
# 411. Swimming_Pool_Edge_12 : (R=127,G=159,B=31,A=255)
# 412. Swimming_Pool_Edge_13 : (R=127,G=159,B=95,A=255)
# 413. Swimming_Pool_Edge_14 : (R=63,G=159,B=0,A=255)
# 414. Swimming_Pool_Edge_15 : (R=63,G=159,B=255,A=255)
# 415. Swimming_Pool_Edge_16 : (R=63,G=159,B=127,A=255)
# 416. Swimming_Pool_Curve_9 : (R=63,G=159,B=63,A=255)
# 417. Swimming_Pool_Curve_10 : (R=63,G=159,B=191,A=255)
# 418. Swimming_Pool_Edge_19 : (R=63,G=159,B=31,A=255)
# 419. Swimming_Pool_Edge_20 : (R=63,G=159,B=95,A=255)
# 420. Swimming_Pool_Edge_642 : (R=191,G=159,B=0,A=255)
# 421. Swimming_Pool_Edge_643 : (R=191,G=159,B=255,A=255)
# 422. Swimming_Pool_Edge_21 : (R=191,G=159,B=127,A=255)
# 423. Swimming_Pool_Edge_22 : (R=191,G=159,B=63,A=255)
# 424. Swimming_Pool_Edge_23 : (R=191,G=159,B=191,A=255)
# 425. Swimming_Pool_Edge_24 : (R=191,G=159,B=31,A=255)
# 426. Swimming_Pool_Floor_4 : (R=191,G=159,B=95,A=255)
# 427. Driveway_8th_15 : (R=31,G=159,B=0,A=255)
# 428. Driveway_8th_23 : (R=31,G=159,B=255,A=255)
# 429. Driveway_8th_24 : (R=31,G=159,B=127,A=255)
# 430. driveway_16th_Curve_27 : (R=31,G=159,B=63,A=255)
# 431. driveway_16th_Curve_30 : (R=31,G=159,B=191,A=255)
# 432. Driveway_8th_25 : (R=31,G=159,B=31,A=255)
# 433. driveway_16th_Curve_34 : (R=31,G=159,B=95,A=255)
# 434. driveway_16th_Curve_37 : (R=95,G=159,B=0,A=255)
# 435. Driveway_8th_26 : (R=95,G=159,B=255,A=255)
# 436. Driveway_8th_27 : (R=95,G=159,B=127,A=255)
# 437. Driveway_8th_28 : (R=95,G=159,B=63,A=255)
# 438. Driveway_8th_29 : (R=95,G=159,B=191,A=255)
# 439. Driveway_8th_30 : (R=95,G=159,B=31,A=255)
# 440. driveway_16th_Curve_18 : (R=95,G=159,B=95,A=255)
# 441. driveway_16th_Curve_19 : (R=0,G=159,B=159,A=255)
# 442. Driveway_8th_31 : (R=255,G=159,B=159,A=255)
# 443. driveway_16th_Curve_20 : (R=127,G=159,B=159,A=255)
# 444. driveway_16th_Curve_21 : (R=63,G=159,B=159,A=255)
# 445. Driveway_8th_32 : (R=191,G=159,B=159,A=255)
# 446. Driveway_8th_33 : (R=31,G=159,B=159,A=255)
# 447. Driveway_6 : (R=95,G=159,B=159,A=255)
# 448. Driveway_7 : (R=159,G=0,B=0,A=255)
# 449. Driveway_8 : (R=159,G=0,B=255,A=255)
# 450. Hedge_57 : (R=159,G=0,B=127,A=255)
# 451. Hedge_59 : (R=159,G=0,B=63,A=255)
# 452. Hedge_58 : (R=159,G=0,B=191,A=255)
# 453. Hedge_62 : (R=159,G=0,B=31,A=255)
# 454. Hedge_60 : (R=159,G=0,B=95,A=255)
# 455. Hedge_61 : (R=159,G=255,B=0,A=255)
# 456. Hedge_68 : (R=159,G=255,B=255,A=255)
# 457. Hedge_63 : (R=159,G=255,B=127,A=255)
# 458. Hedge_64 : (R=159,G=255,B=63,A=255)
# 459. Hedge_65 : (R=159,G=255,B=191,A=255)
# 460. Driveway_74 : (R=159,G=255,B=31,A=255)
# 461. Driveway_8th_77 : (R=159,G=255,B=95,A=255)
# 462. Driveway_8th_35 : (R=159,G=127,B=0,A=255)
# 463. Driveway_8th_36 : (R=159,G=127,B=255,A=255)
# 464. Driveway_16th_82 : (R=159,G=127,B=127,A=255)
# 465. driveway_16th_Curve_85 : (R=159,G=127,B=63,A=255)
# 466. Outer_Wall_Half_Win_88 : (R=159,G=127,B=191,A=255)
# 467. Outer_Wall_Half_Win_72 : (R=159,G=127,B=31,A=255)
# 468. Outer_Wall_Half_Door_92 : (R=159,G=127,B=95,A=255)
# 469. Outer_Wall_Half_Door_5 : (R=159,G=63,B=0,A=255)
# 470. Outer_Wall_Half_Win_73 : (R=159,G=63,B=255,A=255)
# 471. Outer_Wall_Half_Win_74 : (R=159,G=63,B=127,A=255)
# 472. Outer_Wall_Half_Door_98 : (R=159,G=63,B=63,A=255)
# 473. Outer_Wall_Half_Door_7 : (R=159,G=63,B=191,A=255)
# 474. Floor_01_Basic60 : (R=159,G=63,B=31,A=255)
# 475. Floor_01_Basic61 : (R=159,G=63,B=95,A=255)
# 476. Outer_Wall_Half_Win_75 : (R=159,G=191,B=0,A=255)
# 477. Outer_Wall_Half_Door_8 : (R=159,G=191,B=255,A=255)
# 478. Outer_Wall_Half_Win_78 : (R=159,G=191,B=127,A=255)
# 479. Outer_Wall_Half_Door_10 : (R=159,G=191,B=63,A=255)
# 480. Roof_Half_113 : (R=159,G=191,B=191,A=255)
# 481. Roof_Corner_116 : (R=159,G=191,B=31,A=255)
# 482. Roof_End_Thin_119 : (R=159,G=191,B=95,A=255)
# 483. Roof_End_Thin_3 : (R=159,G=31,B=0,A=255)
# 484. Outer_Wall_Half_Door_125 : (R=159,G=31,B=255,A=255)
# 485. Floor_01_Basic64 : (R=159,G=31,B=127,A=255)
# 486. Outer_Wall_Half_Win_139 : (R=159,G=31,B=63,A=255)
# 487. Outer_Wall_Half_Win_79 : (R=159,G=31,B=191,A=255)
# 488. Outer_Wall_Half_Win_80 : (R=159,G=31,B=31,A=255)
# 489. Roof_Apex_13 : (R=159,G=31,B=95,A=255)
# 490. Outer_Wall_Half_Garage_02_142 : (R=159,G=95,B=0,A=255)
# 491. Driveway_10 : (R=159,G=95,B=255,A=255)
# 492. Driveway_8th_150 : (R=159,G=95,B=127,A=255)
# 493. Hedge_66 : (R=159,G=95,B=63,A=255)
# 494. Hedge_67 : (R=159,G=95,B=191,A=255)
# 495. Flor_01_156 : (R=159,G=95,B=31,A=255)
# 496. Driveway_11 : (R=159,G=95,B=95,A=255)
# 497. CameraActor_0 : (R=159,G=0,B=159,A=255)
# 498. Birch_01_160 : (R=159,G=255,B=159,A=255)
# 499. Birch_2 : (R=159,G=127,B=159,A=255)
# 500. Birch_3 : (R=159,G=63,B=159,A=255)
# 501. Birch_4 : (R=159,G=191,B=159,A=255)
# 502. Birch_5 : (R=159,G=31,B=159,A=255)
# 503. Birch_6 : (R=159,G=95,B=159,A=255)
# 504. Birch_7 : (R=159,G=159,B=0,A=255)
# 505. Birch_8 : (R=159,G=159,B=255,A=255)
# 506. Birch_9 : (R=159,G=159,B=127,A=255)
# 507. Birch_10 : (R=159,G=159,B=63,A=255)
# 508. Birch_11 : (R=159,G=159,B=191,A=255)
# 509. Birch_12 : (R=159,G=159,B=31,A=255)
# 510. Birch_13 : (R=159,G=159,B=95,A=255)
# 511. Birch_14 : (R=159,G=159,B=159,A=255)
# 512. Birch_15 : (R=0,G=0,B=223,A=255)
# 513. Birch_16 : (R=0,G=255,B=223,A=255)
# 514. Birch_17 : (R=0,G=127,B=223,A=255)
# 515. Birch_18 : (R=0,G=63,B=223,A=255)
# 516. Birch_19 : (R=0,G=191,B=223,A=255)
# 517. Birch_20 : (R=0,G=31,B=223,A=255)
# 518. Birch_21 : (R=0,G=95,B=223,A=255)
# 519. Fir_183 : (R=0,G=159,B=223,A=255)
# 520. Fir_15 : (R=255,G=0,B=223,A=255)
# 521. Fir_16 : (R=255,G=255,B=223,A=255)
# 522. Fir_17 : (R=255,G=127,B=223,A=255)
# 523. Fir_18 : (R=255,G=63,B=223,A=255)
# 524. Fir_19 : (R=255,G=191,B=223,A=255)
# 525. Fir_20 : (R=255,G=31,B=223,A=255)
# 526. Fir_21 : (R=255,G=95,B=223,A=255)
# 527. Fir_22 : (R=255,G=159,B=223,A=255)
# 528. Fir_23 : (R=127,G=0,B=223,A=255)
# 529. Fir_24 : (R=127,G=255,B=223,A=255)
# 530. Fir_25 : (R=127,G=127,B=223,A=255)
# 531. Fir_26 : (R=127,G=63,B=223,A=255)
# 532. Inner_Wall_Half_Door_5 : (R=127,G=191,B=223,A=255)
# 533. Kitchen_Unit_02_11 : (R=127,G=31,B=223,A=255)
# 534. Kitchen_Unit_3 : (R=127,G=95,B=223,A=255)
# 535. Kitchen_Unit_Sink_01_15 : (R=127,G=159,B=223,A=255)
# 536. Kitchen_Unit_4 : (R=63,G=0,B=223,A=255)
# 537. Kitchen_Cupboard_02_22 : (R=63,G=255,B=223,A=255)
# 538. Kitchen_Cupboard_3 : (R=63,G=127,B=223,A=255)
# 539. Kitchen_Cupboard_4 : (R=63,G=63,B=223,A=255)
# 540. Kitchen_Unit_27 : (R=63,G=191,B=223,A=255)
# 541. Kitchen_Unit_6 : (R=63,G=31,B=223,A=255)
# 542. Kitchen_Splash_Tile_01_31 : (R=63,G=95,B=223,A=255)
# 543. Kitchen_Splash_Tile_2 : (R=63,G=159,B=223,A=255)
# 544. Kitchen_Splash_Tile_36 : (R=191,G=0,B=223,A=255)
# 545. Kitchen_Splash_Tile_4 : (R=191,G=255,B=223,A=255)
# 546. Kitchen_Splash_Tile_5 : (R=191,G=127,B=223,A=255)
# 547. Kitchen_Unit_7 : (R=191,G=63,B=223,A=255)
# 548. Fridge_01_43 : (R=191,G=191,B=223,A=255)
# 549. Lamp_01_46 : (R=191,G=31,B=223,A=255)
# 550. extractor_01_55 : (R=191,G=95,B=223,A=255)
# 551. Light_Switch_01_61 : (R=191,G=159,B=223,A=255)
# 552. Light_Switch_2 : (R=31,G=0,B=223,A=255)
# 553. Light_Switch_65 : (R=31,G=255,B=223,A=255)
# 554. Light_Switch_68 : (R=31,G=127,B=223,A=255)
# 555. Light_Switch_5 : (R=31,G=63,B=223,A=255)
# 556. Light_Switch_6 : (R=31,G=191,B=223,A=255)
# 557. Plug_Socket_01_73 : (R=31,G=31,B=223,A=255)
# 558. Plug_Socket_2 : (R=31,G=95,B=223,A=255)
# 559. Plug_Socket_77 : (R=31,G=159,B=223,A=255)
# 560. Plug_Socket_4 : (R=95,G=0,B=223,A=255)
# 561. Inner_Wall_Close_Gap_83 : (R=95,G=255,B=223,A=255)
# 562. Floor_01_Basic65 : (R=95,G=127,B=223,A=255)
# 563. small_table_03_87 : (R=95,G=63,B=223,A=255)
# 564. Lamp_93 : (R=95,G=191,B=223,A=255)
# 565. BRPlayer_01_96 : (R=95,G=31,B=223,A=255)
# 566. sofa_long_01_99 : (R=95,G=95,B=223,A=255)
# 567. Kitchen_Unit_8 : (R=95,G=159,B=223,A=255)
# 568. Roof_End_Thin_111 : (R=159,G=0,B=223,A=255)
# 569. Roof_End_Thin_117 : (R=159,G=255,B=223,A=255)
# 570. Roof_End_Thin_125 : (R=159,G=127,B=223,A=255)
# 571. Roof_End_Thin_129 : (R=159,G=63,B=223,A=255)
# 572. Outer_Wall_Quart_Win_01_133 : (R=159,G=191,B=223,A=255)
# 573. Outer_Wall_Quart_Win_2 : (R=159,G=31,B=223,A=255)
# 574. Veranda_01_137 : (R=159,G=95,B=223,A=255)
# 575. Veranda_140 : (R=159,G=159,B=223,A=255)
# 576. Veranda_143 : (R=0,G=223,B=0,A=255)
# 577. Veranda_4 : (R=0,G=223,B=255,A=255)
# 578. Garden_Tressel_02_148 : (R=0,G=223,B=127,A=255)
# 579. Garden_Tressel_01_151 : (R=0,G=223,B=63,A=255)
# 580. Garden_Tressel_154 : (R=0,G=223,B=191,A=255)
# 581. Garden_Tressel_157 : (R=0,G=223,B=31,A=255)
# 582. Garden_Tressel_4 : (R=0,G=223,B=95,A=255)
# 583. Garden_Tressel_5 : (R=0,G=223,B=159,A=255)
# 584. Garden_Tressel_162 : (R=255,G=223,B=0,A=255)
# 585. Garden_Tressel_7 : (R=255,G=223,B=255,A=255)
# 586. Garden_Tressel_8 : (R=255,G=223,B=127,A=255)
# 587. Garden_Tressel_171 : (R=255,G=223,B=63,A=255)
# 588. Garden_Tressel_174 : (R=255,G=223,B=191,A=255)
# 589. Cube_178 : (R=255,G=223,B=31,A=255)
# 590. Swimming_Pool_Steps_01_185 : (R=255,G=223,B=95,A=255)
# 591. Swimming_Pool_Steps_188 : (R=255,G=223,B=159,A=255)
# 592. Swimming_Pool_Steps_02_191 : (R=127,G=223,B=0,A=255)
# 593. Swimming_Pool_Steps_194 : (R=127,G=223,B=255,A=255)
# 594. Roof_Open_01_198 : (R=127,G=223,B=127,A=255)
# 595. Roof_Open_2 : (R=127,G=223,B=63,A=255)
# 596. Roof_Open_203 : (R=127,G=223,B=191,A=255)
# 597. Roof_Open_206 : (R=127,G=223,B=31,A=255)
# 598. Roof_Open_209 : (R=127,G=223,B=95,A=255)
# 599. Roof_Open_212 : (R=127,G=223,B=159,A=255)
# 600. Roof_Open_8 : (R=63,G=223,B=0,A=255)
# 601. Wall_Low_01_219 : (R=63,G=223,B=255,A=255)
# 602. Wall_Low_2 : (R=63,G=223,B=127,A=255)
# 603. Wall_Low_223 : (R=63,G=223,B=63,A=255)
# 604. Wall_Low_4 : (R=63,G=223,B=191,A=255)
# 605. Wall_Low_227 : (R=63,G=223,B=31,A=255)
# 606. Wall_Low_6 : (R=63,G=223,B=95,A=255)
# 607. Wall_Low_7 : (R=63,G=223,B=159,A=255)
# 608. Wall_Low_8 : (R=191,G=223,B=0,A=255)
# 609. Wall_Low_9 : (R=191,G=223,B=255,A=255)
# 610. Wall_Low_10 : (R=191,G=223,B=127,A=255)
# 611. Wall_Low_Half_01_237 : (R=191,G=223,B=63,A=255)
# 612. Wall_Low_End_01_243 : (R=191,G=223,B=191,A=255)
# 613. Wall_Low_End_2 : (R=191,G=223,B=31,A=255)
# 614. Wall_Low_8th_01_277 : (R=191,G=223,B=95,A=255)
# 615. Wall_Low_End_284 : (R=191,G=223,B=159,A=255)
# 616. Wall_Low_End_287 : (R=31,G=223,B=0,A=255)
# 617. Wall_Low_290 : (R=31,G=223,B=255,A=255)
# 618. Wall_Low_Half_293 : (R=31,G=223,B=127,A=255)
# 619. Wall_Low_8th_296 : (R=31,G=223,B=63,A=255)
# 620. Wall_Low_End_299 : (R=31,G=223,B=191,A=255)
# 621. Wall_Low_End_6 : (R=31,G=223,B=31,A=255)
# 622. Wall_Low_End_7 : (R=31,G=223,B=95,A=255)
# 623. Wall_Low_End_306 : (R=31,G=223,B=159,A=255)
# 624. Wall_Low_End_309 : (R=95,G=223,B=0,A=255)
# 625. Wall_Low_End_312 : (R=95,G=223,B=255,A=255)
# 626. Driveway_316 : (R=95,G=223,B=127,A=255)
# 627. Driveway_Half_319 : (R=95,G=223,B=63,A=255)
# 628. Wall_Low_322 : (R=95,G=223,B=191,A=255)
# 629. Wall_Low_13 : (R=95,G=223,B=31,A=255)
# 630. Wall_Low_End_326 : (R=95,G=223,B=95,A=255)
# 631. Wall_Low_End_12 : (R=95,G=223,B=159,A=255)
# 632. Wall_Low_End_13 : (R=159,G=223,B=0,A=255)
# 633. Wall_Low_331 : (R=159,G=223,B=255,A=255)
# 634. Wall_Low_15 : (R=159,G=223,B=127,A=255)
# 635. Wall_Low_End_335 : (R=159,G=223,B=63,A=255)
# 636. Wall_Low_End_15 : (R=159,G=223,B=191,A=255)
# 637. Wall_Low_339 : (R=159,G=223,B=31,A=255)
# 638. Wall_Low_17 : (R=159,G=223,B=95,A=255)
# 639. Wall_Low_End_343 : (R=159,G=223,B=159,A=255)
# 640. Wall_Low_End_346 : (R=0,G=223,B=223,A=255)
# 641. Wall_Low_349 : (R=255,G=223,B=223,A=255)
# 642. Wall_Low_Half_352 : (R=127,G=223,B=223,A=255)
# 643. Wall_Low_End_18 : (R=63,G=223,B=223,A=255)
# 644. Wall_Low_End_19 : (R=191,G=223,B=223,A=255)
# 645. Wall_Low_End_20 : (R=31,G=223,B=223,A=255)
# 646. Wall_Low_Half_358 : (R=95,G=223,B=223,A=255)
# 647. Wall_Low_Half_5 : (R=159,G=223,B=223,A=255)
# 648. Wall_Low_Quart_01_366 : (R=223,G=0,B=0,A=255)
# 649. Wall_Low_8th_368 : (R=223,G=0,B=255,A=255)
# 650. Wall_Low_Quart_372 : (R=223,G=0,B=127,A=255)
# 651. Wall_Low_End_375 : (R=223,G=0,B=63,A=255)
# 652. Wall_Low_End_22 : (R=223,G=0,B=191,A=255)
# 653. Wall_Low_End_23 : (R=223,G=0,B=31,A=255)
# 654. Wall_Low_Quart_384 : (R=223,G=0,B=95,A=255)
# 655. Wall_Low_End_387 : (R=223,G=0,B=159,A=255)
# 656. Wall_Low_End_25 : (R=223,G=255,B=0,A=255)
# 657. Driveway_393 : (R=223,G=255,B=255,A=255)
# 658. Wall_Low_396 : (R=223,G=255,B=127,A=255)
# 659. Wall_Low_20 : (R=223,G=255,B=63,A=255)
# 660. Wall_Low_21 : (R=223,G=255,B=191,A=255)
# 661. Wall_Low_22 : (R=223,G=255,B=31,A=255)
# 662. Wall_Low_23 : (R=223,G=255,B=95,A=255)
# 663. Driveway_14 : (R=223,G=255,B=159,A=255)
# 664. Wall_Low_24 : (R=223,G=127,B=0,A=255)
# 665. Wall_Low_End_405 : (R=223,G=127,B=255,A=255)
# 666. Wall_Low_End_27 : (R=223,G=127,B=127,A=255)
# 667. Wall_Low_End_28 : (R=223,G=127,B=63,A=255)
# 668. Wall_Low_End_29 : (R=223,G=127,B=191,A=255)
# 669. Wall_Low_End_30 : (R=223,G=127,B=31,A=255)
# 670. Wall_Low_End_31 : (R=223,G=127,B=95,A=255)
# 671. Veranda_421 : (R=223,G=127,B=159,A=255)
# 672. Basketball_Hoop_01_424 : (R=223,G=63,B=0,A=255)
# 673. Roof_End_Thin_01_4 : (R=223,G=63,B=255,A=255)
# 674. Roof_Middle_Apex_01_7 : (R=223,G=63,B=127,A=255)
# 675. Roof_Middle_Apex_2 : (R=223,G=63,B=63,A=255)
# 676. Roof_Middle_Apex_3 : (R=223,G=63,B=191,A=255)
# 677. Roof_Middle_Apex_13 : (R=223,G=63,B=31,A=255)
# 678. Roof_Middle_Apex_6 : (R=223,G=63,B=95,A=255)
# 679. Roof_Middle_Apex_7 : (R=223,G=63,B=159,A=255)
# 680. Roof_Middle_Apex_8 : (R=223,G=191,B=0,A=255)
# 681. Roof_Open_9 : (R=223,G=191,B=255,A=255)
# 682. Roof_Middle_Apex_9 : (R=223,G=191,B=127,A=255)
# 683. Roof_Middle_Apex_10 : (R=223,G=191,B=63,A=255)
# 684. Roof_Middle_Apex_11 : (R=223,G=191,B=191,A=255)
# 685. Roof_Middle_Apex_23 : (R=223,G=191,B=31,A=255)
# 686. Staircase_02_27 : (R=223,G=191,B=95,A=255)
# 687. Outer_Wall_Quart_Floor_30 : (R=223,G=191,B=159,A=255)
# 688. Inner_Wall_Half_Door_39 : (R=223,G=31,B=0,A=255)
# 689. Inner_Wall_Half_Door_6 : (R=223,G=31,B=255,A=255)
# 690. Inner_Wall_Half_Door_53 : (R=223,G=31,B=127,A=255)
# 691. Inner_Wall_Half_Door_56 : (R=223,G=31,B=63,A=255)
# 692. Inner_Wall_Quart_59 : (R=223,G=31,B=191,A=255)
# 693. Inner_Wall_8th_Door_01_62 : (R=223,G=31,B=31,A=255)
# 694. Inner_Wall_Quart_6 : (R=223,G=31,B=95,A=255)
# 695. Inner_Wall_Half_Door_9 : (R=223,G=31,B=159,A=255)
# 696. Inner_Wall_Close_Gap_67 : (R=223,G=95,B=0,A=255)
# 697. Roof_Open_3 : (R=223,G=95,B=255,A=255)
# 698. Roof_Open_11 : (R=223,G=95,B=127,A=255)
# 699. Roof_Open_12 : (R=223,G=95,B=63,A=255)
# 700. Roof_Open_13 : (R=223,G=95,B=191,A=255)
# 701. Roof_Open_14 : (R=223,G=95,B=31,A=255)
# 702. Roof_Open_15 : (R=223,G=95,B=95,A=255)
# 703. Roof_Open_16 : (R=223,G=95,B=159,A=255)
# 704. Roof_Open_77 : (R=223,G=159,B=0,A=255)
# 705. Staircase_3 : (R=223,G=159,B=255,A=255)
# 706. Floor_01_Basic42_81 : (R=223,G=159,B=127,A=255)
# 707. Floor_01_Basic67 : (R=223,G=159,B=63,A=255)
# 708. Outer_Wall_Half_Win_53 : (R=223,G=159,B=191,A=255)
# 709. Outer_Wall_Half_Win_63 : (R=223,G=159,B=31,A=255)
# 710. Inner_Wall_Close_Gap_86 : (R=223,G=159,B=95,A=255)
# 711. Outer_Wall_Quart_Win_10 : (R=223,G=159,B=159,A=255)
# 712. Outer_Wall_Quart_Win_11 : (R=223,G=0,B=223,A=255)
# 713. Outer_Wall_Half_Win_82 : (R=223,G=255,B=223,A=255)
# 714. Outer_Wall_Half_Win_83 : (R=223,G=127,B=223,A=255)
# 715. Outer_Wall_Half_Win_84 : (R=223,G=63,B=223,A=255)
# 716. Roof_Apex_10 : (R=223,G=191,B=223,A=255)
# 717. Roof_Corner_6 : (R=223,G=31,B=223,A=255)
# 718. Outer_Wall_Quart_Roof_3 : (R=223,G=95,B=223,A=255)
# 719. Outer_Wall_Quart_Roof_4 : (R=223,G=159,B=223,A=255)
# 720. Roof_End_Thin_8 : (R=223,G=223,B=0,A=255)
# 721. Driveway_15 : (R=223,G=223,B=255,A=255)
# 722. Roof_End_Thin_9 : (R=223,G=223,B=127,A=255)
# 723. Roof_Middle_Apex_106 : (R=223,G=223,B=63,A=255)
# 724. Outer_Wall_Quart_Win_136 : (R=223,G=223,B=191,A=255)
# 725. Inner_Wall_Close_Gap_139 : (R=223,G=223,B=31,A=255)
# 726. Roof_Middle_Half_01_143 : (R=223,G=223,B=95,A=255)
# 727. Outer_Wall_Half_Win_85 : (R=223,G=223,B=159,A=255)
# 728. Outer_Wall_Quart_Door_01_147 : (R=223,G=223,B=223,A=255)
# 729. Floor_01_Basic68_150 : (R=0,G=0,B=15,A=255)
# 730. Floor_01_Basic69 : (R=0,G=255,B=15,A=255)
# 731. Floor_01_Basic70 : (R=0,G=127,B=15,A=255)
# 732. Outer_Wall_Quart_Floor_155 : (R=0,G=63,B=15,A=255)
# 733. Outer_Wall_Quart_Floor_10 : (R=0,G=191,B=15,A=255)
# 734. Wall_Low_161 : (R=0,G=31,B=15,A=255)
# 735. Wall_Low_26 : (R=0,G=95,B=15,A=255)
# 736. Wall_Low_27 : (R=0,G=159,B=15,A=255)
# 737. Wall_Low_28 : (R=0,G=223,B=15,A=255)
# 738. Wall_Low_Quart_167 : (R=255,G=0,B=15,A=255)
# 739. Wall_Low_End_170 : (R=255,G=255,B=15,A=255)
# 740. Wall_Low_End_173 : (R=255,G=127,B=15,A=255)
# 741. Wall_Low_End_177 : (R=255,G=63,B=15,A=255)
# 742. Wall_Low_29 : (R=255,G=191,B=15,A=255)
# 743. Wall_Low_30 : (R=255,G=31,B=15,A=255)
# 744. Wall_Low_End_36 : (R=255,G=95,B=15,A=255)
# 745. Wall_Low_31 : (R=255,G=159,B=15,A=255)
# 746. Wall_Low_32 : (R=255,G=223,B=15,A=255)
# 747. Wall_Low_End_37 : (R=127,G=0,B=15,A=255)
# 748. Wall_Low_33 : (R=127,G=255,B=15,A=255)
# 749. Wall_Low_34 : (R=127,G=127,B=15,A=255)
# 750. Wall_Low_End_38 : (R=127,G=63,B=15,A=255)
# 751. Wall_Low_35 : (R=127,G=191,B=15,A=255)
# 752. Wall_Low_36 : (R=127,G=31,B=15,A=255)
# 753. Wall_Low_End_39 : (R=127,G=95,B=15,A=255)
# 754. Wall_Low_End_40 : (R=127,G=159,B=15,A=255)
# 755. Wall_Low_37 : (R=127,G=223,B=15,A=255)
# 756. Wall_Low_38 : (R=63,G=0,B=15,A=255)
# 757. Wall_Low_End_194 : (R=63,G=255,B=15,A=255)
# 758. Birch_197 : (R=63,G=127,B=15,A=255)
# 759. Birch_23 : (R=63,G=63,B=15,A=255)
# 760. Birch_24 : (R=63,G=191,B=15,A=255)
# 761. Birch_25 : (R=63,G=31,B=15,A=255)
# 762. Birch_26 : (R=63,G=95,B=15,A=255)
# 763. Birch_27 : (R=63,G=159,B=15,A=255)
# 764. Birch_28 : (R=63,G=223,B=15,A=255)
# 765. Driveway_16 : (R=191,G=0,B=15,A=255)
# 766. Driveway_17 : (R=191,G=255,B=15,A=255)
# 767. Driveway_18 : (R=191,G=127,B=15,A=255)
# 768. Hedge_210 : (R=191,G=63,B=15,A=255)
# 769. Hedge_69 : (R=191,G=191,B=15,A=255)
# 770. Hedge_70 : (R=191,G=31,B=15,A=255)
# 771. Hedge_215 : (R=191,G=95,B=15,A=255)
# 772. Hedge_72 : (R=191,G=159,B=15,A=255)
# 773. Hedge_73 : (R=191,G=223,B=15,A=255)
# 774. Hedge_74 : (R=31,G=0,B=15,A=255)
# 775. Hedge_75 : (R=31,G=255,B=15,A=255)
# 776. Hedge_76 : (R=31,G=127,B=15,A=255)
# 777. Floor_01_Basic71 : (R=31,G=63,B=15,A=255)
# 778. Floor_01_Basic72 : (R=31,G=191,B=15,A=255)
# 779. Outer_Wall_Quart_Floor_11 : (R=31,G=31,B=15,A=255)
# 780. Floor_01_Basic73 : (R=31,G=95,B=15,A=255)
# 781. Staircase_01_228 : (R=31,G=159,B=15,A=255)
# 782. Inner_Wall_Half_Arch_231 : (R=31,G=223,B=15,A=255)
# 783. Banister_234 : (R=95,G=0,B=15,A=255)
# 784. Banister_4 : (R=95,G=255,B=15,A=255)
# 785. Banister_241 : (R=95,G=127,B=15,A=255)
# 786. Banister_6 : (R=95,G=63,B=15,A=255)
# 787. Banister_7 : (R=95,G=191,B=15,A=255)
# 788. Banister_8 : (R=95,G=31,B=15,A=255)
# 789. Banister_9 : (R=95,G=95,B=15,A=255)
# 790. Outer_Wall_Quart_Garage_01_248 : (R=95,G=159,B=15,A=255)
# 791. Outer_Wall_Quart_Garage_257 : (R=95,G=223,B=15,A=255)
# 792. Outer_Wall_Quart_Garage_260 : (R=159,G=0,B=15,A=255)
# 793. Inner_Wall_Half_Door_263 : (R=159,G=255,B=15,A=255)
# 794. Floor_01_Basic74 : (R=159,G=127,B=15,A=255)
# 795. Floor_01_Basic75 : (R=159,G=63,B=15,A=255)
# 796. Inner_Wall_Half_Arch_268 : (R=159,G=191,B=15,A=255)
# 797. Roof_Middle_Apex_14 : (R=159,G=31,B=15,A=255)
# 798. Outer_Wall_Half_Win_86 : (R=159,G=95,B=15,A=255)
# 799. Roof_Quart_Open_277 : (R=159,G=159,B=15,A=255)
# 800. Staircase_284 : (R=159,G=223,B=15,A=255)
# 801. Floor_01_Basic76 : (R=223,G=0,B=15,A=255)
# 802. Banister_288 : (R=223,G=255,B=15,A=255)
# 803. Banister_291 : (R=223,G=127,B=15,A=255)
# 804. Banister_12 : (R=223,G=63,B=15,A=255)
# 805. Banister_298 : (R=223,G=191,B=15,A=255)
# 806. Banister_14 : (R=223,G=31,B=15,A=255)
# 807. Banister_End_302 : (R=223,G=95,B=15,A=255)
# 808. Staircase_305 : (R=223,G=159,B=15,A=255)
# 809. Floor_01_Basic77 : (R=223,G=223,B=15,A=255)
# 810. Floor_01_Basic78_309 : (R=0,G=15,B=0,A=255)
# 811. Floor_01_Basic79 : (R=0,G=15,B=255,A=255)
# 812. Floor_01_Basic80 : (R=0,G=15,B=127,A=255)
# 813. Banister_314 : (R=0,G=15,B=63,A=255)
# 814. Banister_16 : (R=0,G=15,B=191,A=255)
# 815. Banister_17 : (R=0,G=15,B=31,A=255)
# 816. Banister_18 : (R=0,G=15,B=95,A=255)
# 817. Banister_19 : (R=0,G=15,B=159,A=255)
# 818. Floor_Quart_2 : (R=0,G=15,B=223,A=255)
# 819. Shutters_01_323 : (R=255,G=15,B=0,A=255)
# 820. Shutters_2 : (R=255,G=15,B=255,A=255)
# 821. Shutters_3 : (R=255,G=15,B=127,A=255)
# 822. Shutters_4 : (R=255,G=15,B=63,A=255)
# 823. Shutters_5 : (R=255,G=15,B=191,A=255)
# 824. Shutters_6 : (R=255,G=15,B=31,A=255)
# 825. Shutters_7 : (R=255,G=15,B=95,A=255)
# 826. Shutters_8 : (R=255,G=15,B=159,A=255)
# 827. Shutters_9 : (R=255,G=15,B=223,A=255)
# 828. Shutters_10 : (R=127,G=15,B=0,A=255)
# 829. Shutters_11 : (R=127,G=15,B=255,A=255)
# 830. Shutters_12 : (R=127,G=15,B=127,A=255)
# 831. Shutters_13 : (R=127,G=15,B=63,A=255)
# 832. Shutters_14 : (R=127,G=15,B=191,A=255)
# 833. Shutters_340 : (R=127,G=15,B=31,A=255)
# 834. Shutters_16 : (R=127,G=15,B=95,A=255)
# 835. Shutters_17 : (R=127,G=15,B=159,A=255)
# 836. Shutters_18 : (R=127,G=15,B=223,A=255)
# 837. Shutters_19 : (R=63,G=15,B=0,A=255)
# 838. Shutters_20 : (R=63,G=15,B=255,A=255)
# 839. Shutters_21 : (R=63,G=15,B=127,A=255)
# 840. Shutters_22 : (R=63,G=15,B=63,A=255)
# 841. Outer_Wall_Half_Win_87 : (R=63,G=15,B=191,A=255)
# 842. Inner_Wall_Close_Gap_351 : (R=63,G=15,B=31,A=255)
# 843. Shutters_354 : (R=63,G=15,B=95,A=255)
# 844. Shutters_24 : (R=63,G=15,B=159,A=255)
# 845. Shutters_25 : (R=63,G=15,B=223,A=255)
# 846. Shutters_26 : (R=191,G=15,B=0,A=255)
# 847. Shutters_27 : (R=191,G=15,B=255,A=255)
# 848. Shutters_28 : (R=191,G=15,B=127,A=255)
# 849. Shutters_29 : (R=191,G=15,B=63,A=255)
# 850. Shutters_30 : (R=191,G=15,B=191,A=255)
# 851. Shutters_31 : (R=191,G=15,B=31,A=255)
# 852. Shutters_32 : (R=191,G=15,B=95,A=255)
# 853. Shutters_33 : (R=191,G=15,B=159,A=255)
# 854. Shutters_34 : (R=191,G=15,B=223,A=255)
# 855. Cube2 : (R=31,G=15,B=0,A=255)
# 856. Roof_Edge_Half_Middle_01_5 : (R=31,G=15,B=255,A=255)
# 857. Roof_Edge_Half_Middle_3 : (R=31,G=15,B=127,A=255)
# 858. Roof_Edge_Half_Middle_4 : (R=31,G=15,B=63,A=255)
# 859. Roof_Edge_Half_Middle_7 : (R=31,G=15,B=191,A=255)
# 860. Roof_Edge_Half_Middle_8 : (R=31,G=15,B=31,A=255)
# 861. Roof_Edge_Half_Middle_9 : (R=31,G=15,B=95,A=255)
# 862. Roof_Edge_Half_Middle_20 : (R=31,G=15,B=159,A=255)
# 863. Roof_Edge_End_01_23 : (R=31,G=15,B=223,A=255)
# 864. Roof_Edge_Half_Middle_27 : (R=95,G=15,B=0,A=255)
# 865. Roof_Edge_Half_Middle_12 : (R=95,G=15,B=255,A=255)
# 866. Roof_Edge_End_31 : (R=95,G=15,B=127,A=255)
# 867. Roof_Edge_End_3 : (R=95,G=15,B=63,A=255)
# 868. Roof_Edge_End_38 : (R=95,G=15,B=191,A=255)
# 869. Roof_Edge_End_41 : (R=95,G=15,B=31,A=255)
# 870. Roof_Edge_Half_Middle_50 : (R=95,G=15,B=95,A=255)
# 871. Roof_Edge_End_53 : (R=95,G=15,B=159,A=255)
# 872. Roof_Edge_End_56 : (R=95,G=15,B=223,A=255)
# 873. Power_Line_01_59 : (R=159,G=15,B=0,A=255)
# 874. Power_Line_2 : (R=159,G=15,B=255,A=255)
# 875. Power_Line_3 : (R=159,G=15,B=127,A=255)
# 876. Pool_Table_7 : (R=159,G=15,B=63,A=255)
# 877. Sofa_10 : (R=159,G=15,B=191,A=255)
# 878. Sofa_4 : (R=159,G=15,B=31,A=255)
# 879. small_table_14 : (R=159,G=15,B=95,A=255)
# 880. Bookcase_01_21 : (R=159,G=15,B=159,A=255)
# 881. Lcd_02_29 : (R=159,G=15,B=223,A=255)
# 882. Lamp_32 : (R=223,G=15,B=0,A=255)
# 883. BRPlayer_36 : (R=223,G=15,B=255,A=255)
# 884. fan_39 : (R=223,G=15,B=127,A=255)
# 885. Kitchen_Unit_10 : (R=223,G=15,B=63,A=255)
# 886. Kitchen_Unit_Sink_53 : (R=223,G=15,B=191,A=255)
# 887. Kitchen_Unit_56 : (R=223,G=15,B=31,A=255)
# 888. Kitchen_Unit_12 : (R=223,G=15,B=95,A=255)
# 889. Fridge_60 : (R=223,G=15,B=159,A=255)
# 890. Oven_01_66 : (R=223,G=15,B=223,A=255)
# 891. Kitchen_Cupboard_72 : (R=0,G=15,B=15,A=255)
# 892. Kitchen_Unit_13 : (R=255,G=15,B=15,A=255)
# 893. Kitchen_Cupboard_6 : (R=127,G=15,B=15,A=255)
# 894. Pool_Table_77 : (R=63,G=15,B=15,A=255)
# 895. Shelf_01_80 : (R=191,G=15,B=15,A=255)
# 896. Shelf_2 : (R=31,G=15,B=15,A=255)
# 897. Fridge_Alphabet_01_84 : (R=95,G=15,B=15,A=255)
# 898. Sofa_87 : (R=159,G=15,B=15,A=255)
# 899. Lamp_90 : (R=223,G=15,B=15,A=255)
# 900. fan_93 : (R=15,G=0,B=0,A=255)
# 901. Inner_Wall_Close_Gap_99 : (R=15,G=0,B=255,A=255)
# 902. Inner_Wall_Half_Arch_102 : (R=15,G=0,B=127,A=255)
# 903. fan_4 : (R=15,G=0,B=63,A=255)
# 904. coffee_table_02_106 : (R=15,G=0,B=191,A=255)
# 905. Bed_Double_01_116 : (R=15,G=0,B=31,A=255)
# 906. Bed_Double_119 : (R=15,G=0,B=95,A=255)
# 907. Toilet_01_124 : (R=15,G=0,B=159,A=255)
# 908. Sink_01_127 : (R=15,G=0,B=223,A=255)
# 909. Inner_Wall_Half_Door_11 : (R=15,G=255,B=0,A=255)
# 910. Inner_Wall_Close_Gap_134 : (R=15,G=255,B=255,A=255)
# 911. Inner_Wall_Close_Gap_137 : (R=15,G=255,B=127,A=255)
# 912. Drain_Pipe_01_140 : (R=15,G=255,B=63,A=255)
# 913. Drain_Pipe_2 : (R=15,G=255,B=191,A=255)
# 914. Drain_Pipe_3 : (R=15,G=255,B=31,A=255)
# 915. Drain_Pipe_145 : (R=15,G=255,B=95,A=255)
# 916. Drain_Pipe_148 : (R=15,G=255,B=159,A=255)
# 917. Drain_Pipe_02_151 : (R=15,G=255,B=223,A=255)
# 918. Drain_Pipe_6 : (R=15,G=127,B=0,A=255)
# 919. Drain_Pipe_7 : (R=15,G=127,B=255,A=255)
# 920. Drain_Pipe_156 : (R=15,G=127,B=127,A=255)
# 921. Drain_Pipe_9 : (R=15,G=127,B=63,A=255)
# 922. Drain_Pipe_10 : (R=15,G=127,B=191,A=255)
# 923. Drain_Pipe_11 : (R=15,G=127,B=31,A=255)
# 924. Drain_Pipe_12 : (R=15,G=127,B=95,A=255)
# 925. Drain_Pipe_13 : (R=15,G=127,B=159,A=255)
# 926. Drain_Pipe_14 : (R=15,G=127,B=223,A=255)
# 927. Drain_Pipe_15 : (R=15,G=63,B=0,A=255)
# 928. Drain_Pipe_16 : (R=15,G=63,B=255,A=255)
# 929. Drain_Pipe_17 : (R=15,G=63,B=127,A=255)
# 930. Drain_Pipe_18 : (R=15,G=63,B=63,A=255)
# 931. Drain_Pipe_19 : (R=15,G=63,B=191,A=255)
# 932. Drain_Pipe_170 : (R=15,G=63,B=31,A=255)
# 933. Drain_Pipe_21 : (R=15,G=63,B=95,A=255)
# 934. Drain_Pipe_22 : (R=15,G=63,B=159,A=255)
# 935. Drain_Pipe_23 : (R=15,G=63,B=223,A=255)
# 936. Drain_Pipe_24 : (R=15,G=191,B=0,A=255)
# 937. Drain_Pipe_25 : (R=15,G=191,B=255,A=255)
# 938. Drain_Pipe_26 : (R=15,G=191,B=127,A=255)
# 939. Drain_Pipe_27 : (R=15,G=191,B=63,A=255)
# 940. Drain_Pipe_28 : (R=15,G=191,B=191,A=255)
# 941. Drain_Pipe_29 : (R=15,G=191,B=31,A=255)
# 942. Drain_Pipe_30 : (R=15,G=191,B=95,A=255)
# 943. Drain_Pipe_31 : (R=15,G=191,B=159,A=255)
# 944. Drain_Pipe_32 : (R=15,G=191,B=223,A=255)
# 945. Drain_Pipe_33 : (R=15,G=31,B=0,A=255)
# 946. Drain_Pipe_34 : (R=15,G=31,B=255,A=255)
# 947. Drain_Pipe_35 : (R=15,G=31,B=127,A=255)
# 948. Drain_Pipe_36 : (R=15,G=31,B=63,A=255)
# 949. Drain_Pipe_37 : (R=15,G=31,B=191,A=255)
# 950. Drain_Pipe_38 : (R=15,G=31,B=31,A=255)
# 951. Drain_Pipe_39 : (R=15,G=31,B=95,A=255)
# 952. Drain_Pipe_40 : (R=15,G=31,B=159,A=255)
# 953. Drain_Pipe_41 : (R=15,G=31,B=223,A=255)
# 954. Drain_Pipe_42 : (R=15,G=95,B=0,A=255)
# 955. Drain_Pipe_43 : (R=15,G=95,B=255,A=255)
# 956. Drain_Pipe_44 : (R=15,G=95,B=127,A=255)
# 957. Drain_Pipe_197 : (R=15,G=95,B=63,A=255)
# 958. Drain_Pipe_46 : (R=15,G=95,B=191,A=255)
# 959. Drain_Pipe_201 : (R=15,G=95,B=31,A=255)
# 960. Drain_Pipe_48 : (R=15,G=95,B=95,A=255)
# 961. Drain_Pipe_49 : (R=15,G=95,B=159,A=255)
# 962. Drain_Pipe_50 : (R=15,G=95,B=223,A=255)
# 963. Drain_Pipe_207 : (R=15,G=159,B=0,A=255)
# 964. Drain_Pipe_52 : (R=15,G=159,B=255,A=255)
# 965. Drain_Pipe_53 : (R=15,G=159,B=127,A=255)
# 966. Drain_Pipe_54 : (R=15,G=159,B=63,A=255)
# 967. Drain_Pipe_55 : (R=15,G=159,B=191,A=255)
# 968. Drain_Pipe_56 : (R=15,G=159,B=31,A=255)
# 969. Drain_Pipe_57 : (R=15,G=159,B=95,A=255)
# 970. Drain_Pipe_216 : (R=15,G=159,B=159,A=255)
# 971. Power_Line_4 : (R=15,G=159,B=223,A=255)
# 972. Power_Line_5 : (R=15,G=223,B=0,A=255)
# 973. Outer_Wall_Half_Win_71 : (R=15,G=223,B=255,A=255)
# 974. Outer_Wall_Quart_Win_13 : (R=15,G=223,B=127,A=255)
# 975. Outer_Wall_Quart_Win_14 : (R=15,G=223,B=63,A=255)
# 976. Outer_Wall_Half_Win_89 : (R=15,G=223,B=191,A=255)
# 977. Outer_Wall_Half_Win_90 : (R=15,G=223,B=31,A=255)
# 978. Outer_Wall_Half_Win_91 : (R=15,G=223,B=95,A=255)
# 979. Roof_Apex_11 : (R=15,G=223,B=159,A=255)
# 980. Roof_Corner_7 : (R=15,G=223,B=223,A=255)
# 981. Outer_Wall_Quart_Roof_5 : (R=15,G=0,B=15,A=255)
# 982. Outer_Wall_Quart_Roof_6 : (R=15,G=255,B=15,A=255)
# 983. Roof_End_Thin_10 : (R=15,G=127,B=15,A=255)
# 984. Driveway_19 : (R=15,G=63,B=15,A=255)
# 985. Roof_End_Thin_11 : (R=15,G=191,B=15,A=255)
# 986. Roof_Middle_Apex_15 : (R=15,G=31,B=15,A=255)
# 987. Outer_Wall_Quart_Win_15 : (R=15,G=95,B=15,A=255)
# 988. Roof_Middle_Half_2 : (R=15,G=159,B=15,A=255)
# 989. Outer_Wall_Half_Win_92 : (R=15,G=223,B=15,A=255)
# 990. Outer_Wall_Quart_Door_2 : (R=15,G=15,B=0,A=255)
# 991. Wall_Low_74 : (R=15,G=15,B=255,A=255)
# 992. Wall_Low_40 : (R=15,G=15,B=127,A=255)
# 993. Wall_Low_41 : (R=15,G=15,B=63,A=255)
# 994. Wall_Low_42 : (R=15,G=15,B=191,A=255)
# 995. Wall_Low_End_82 : (R=15,G=15,B=31,A=255)
# 996. Wall_Low_End_42 : (R=15,G=15,B=95,A=255)
# 997. Wall_Low_43 : (R=15,G=15,B=159,A=255)
# 998. Wall_Low_44 : (R=15,G=15,B=223,A=255)
# 999. Wall_Low_End_43 : (R=15,G=15,B=15,A=255)
# 1000. Hedge_77 : (R=0,G=0,B=47,A=255)
# 1001. Hedge_78 : (R=0,G=255,B=47,A=255)
# 1002. Hedge_79 : (R=0,G=127,B=47,A=255)
# 1003. Hedge_80 : (R=0,G=63,B=47,A=255)
# 1004. Hedge_81 : (R=0,G=191,B=47,A=255)
# 1005. Hedge_82 : (R=0,G=31,B=47,A=255)
# 1006. Fir_95 : (R=0,G=95,B=47,A=255)
# 1007. Fir_28 : (R=0,G=159,B=47,A=255)
# 1008. Fir_29 : (R=0,G=223,B=47,A=255)
# 1009. Fir_30 : (R=0,G=15,B=47,A=255)
# 1010. Outer_Wall_Quart_Win_16 : (R=255,G=0,B=47,A=255)
# 1011. Outer_Wall_Quart_Roof_7 : (R=255,G=255,B=47,A=255)
# 1012. Inner_Wall_Close_Gap_103 : (R=255,G=127,B=47,A=255)
# 1013. Outer_Wall_Quart_Floor_108 : (R=255,G=63,B=47,A=255)
# 1014. Outer_Wall_Quart_Floor_13 : (R=255,G=191,B=47,A=255)
# 1015. Outer_Wall_Quart_Floor_14 : (R=255,G=31,B=47,A=255)
# 1016. Floor_01_Basic52_113 : (R=255,G=95,B=47,A=255)
# 1017. Floor_01_Basic58 : (R=255,G=159,B=47,A=255)
# 1018. Floor_01_Basic81 : (R=255,G=223,B=47,A=255)
# 1019. Outer_Wall_Quart_Floor_15 : (R=255,G=15,B=47,A=255)
# 1020. Outer_Wall_Quart_Floor_16 : (R=127,G=0,B=47,A=255)
# 1021. Outer_Wall_Quart_Floor_17 : (R=127,G=255,B=47,A=255)
# 1022. Roof_Edge_Half_Middle_5 : (R=127,G=127,B=47,A=255)
# ...
# 3440. Wall_Low_53 : (R=191,G=31,B=207,A=255)
# 3441. Wall_Low_54 : (R=191,G=95,B=207,A=255)
# 3442. Wall_Low_55 : (R=191,G=159,B=207,A=255)
# 3443. Floor_01_Basic103 : (R=191,G=223,B=207,A=255)
# 3444. Driveway_Half_27 : (R=191,G=15,B=207,A=255)
# 3445. Driveway_Half_28 : (R=191,G=47,B=207,A=255)
# 3446. Driveway_Half_29 : (R=191,G=79,B=207,A=255)
# 3447. Wall_Low_Half_174 : (R=191,G=111,B=207,A=255)
# 3448. Wall_Low_End_178 : (R=191,G=143,B=207,A=255)
# 3449. Wall_Low_Quart_182 : (R=191,G=175,B=207,A=255)
# 3450. Wall_Low_End_185 : (R=31,G=0,B=207,A=255)
# 3451. Wall_Low_End_56 : (R=31,G=255,B=207,A=255)
# 3452. Wall_Low_Half_8 : (R=31,G=127,B=207,A=255)
# 3453. Wall_Low_Quart_190 : (R=31,G=63,B=207,A=255)
# 3454. Wall_Low_End_193 : (R=31,G=191,B=207,A=255)
# 3455. Driveway_Half_30 : (R=31,G=31,B=207,A=255)
# 3456. Bench_197 : (R=31,G=95,B=207,A=255)
# 3457. Bench_25 : (R=31,G=159,B=207,A=255)
# 3458. Veranda_201 : (R=31,G=223,B=207,A=255)
# 3459. Basketball_Hoop_204 : (R=31,G=15,B=207,A=255)
# 3460. Garden_Chair_207 : (R=31,G=47,B=207,A=255)
# 3461. Garden_Chair_210 : (R=31,G=79,B=207,A=255)
# 3462. Garden_Tressel_216 : (R=31,G=111,B=207,A=255)
# 3463. Garden_Tressel_35 : (R=31,G=143,B=207,A=255)
# 3464. Rock_220 : (R=31,G=175,B=207,A=255)
# 3465. Rock_20 : (R=95,G=0,B=207,A=255)
# 3466. Rock_21 : (R=95,G=255,B=207,A=255)
# 3467. Rock_22 : (R=95,G=127,B=207,A=255)
# 3468. Rock_24 : (R=95,G=63,B=207,A=255)
# 3469. Rock_229 : (R=95,G=191,B=207,A=255)
# 3470. Outer_Door_Swing_294 : (R=95,G=31,B=207,A=255)
# 3471. Stairs_Prefab_149 : (R=95,G=95,B=207,A=255)
# 3472. Inner_Wall_Half_Arch_232 : (R=95,G=159,B=207,A=255)
# 3473. Inner_Wall_Close_Gap_235 : (R=95,G=223,B=207,A=255)
# 3474. Inner_Wall_Close_Gap_42 : (R=95,G=15,B=207,A=255)
# 3475. Inner_Wall_Close_Gap_239 : (R=95,G=47,B=207,A=255)
# 3476. Inner_Wall_Close_Gap_242 : (R=95,G=79,B=207,A=255)
# 3477. Floor_Half_17 : (R=95,G=111,B=207,A=255)
# 3478. Floor_Half_18 : (R=95,G=143,B=207,A=255)
# 3479. Floor_Half_19 : (R=95,G=175,B=207,A=255)
# 3480. Floor_Half_20 : (R=159,G=0,B=207,A=255)
# 3481. Floor_8th_2 : (R=159,G=255,B=207,A=255)
# 3482. Outer_Wall_Quart_Floor_250 : (R=159,G=127,B=207,A=255)
# 3483. Outer_Wall_Quart_Floor_29 : (R=159,G=63,B=207,A=255)
# 3484. Inner_Wall_Close_Gap_254 : (R=159,G=191,B=207,A=255)
# 3485. Inner_Wall_Close_Gap_257 : (R=159,G=31,B=207,A=255)
# 3486. Inner_Wall_Close_Gap_260 : (R=159,G=95,B=207,A=255)
# 3487. Inner_Wall_Close_Gap_263 : (R=159,G=159,B=207,A=255)
# 3488. Inner_Wall_Close_Gap_266 : (R=159,G=223,B=207,A=255)
# 3489. Inner_Wall_Close_Gap_269 : (R=159,G=15,B=207,A=255)
# 3490. Stairs_Prefab_1341 : (R=159,G=47,B=207,A=255)
# 3491. Roof_End_Thin_43 : (R=159,G=79,B=207,A=255)
# 3492. Roof_End_Thin_24 : (R=159,G=111,B=207,A=255)
# 3493. Roof_Edge_Half_Middle_52 : (R=159,G=143,B=207,A=255)
# 3494. Roof_Edge_End_57 : (R=159,G=175,B=207,A=255)
# 3495. Outer_Wall_Quart_Base_01_63 : (R=223,G=0,B=207,A=255)
# 3496. Outer_Wall_Quart_Base_2 : (R=223,G=255,B=207,A=255)
# 3497. Outer_Wall_Quart_Base_67 : (R=223,G=127,B=207,A=255)
# 3498. Curtain_70 : (R=223,G=63,B=207,A=255)
# 3499. Curtain_73 : (R=223,G=191,B=207,A=255)
# 3500. Curtain_40 : (R=223,G=31,B=207,A=255)
# 3501. Curtain_77 : (R=223,G=95,B=207,A=255)
# 3502. Curtain_42 : (R=223,G=159,B=207,A=255)
# 3503. Curtain_81 : (R=223,G=223,B=207,A=255)
# 3504. Curtain_84 : (R=223,G=15,B=207,A=255)
# 3505. Curtain_87 : (R=223,G=47,B=207,A=255)
# 3506. Curtain_90 : (R=223,G=79,B=207,A=255)
# 3507. Curtain_93 : (R=223,G=111,B=207,A=255)
# 3508. Curtain_98 : (R=223,G=143,B=207,A=255)
# 3509. Curtain_101 : (R=223,G=175,B=207,A=255)
# 3510. Curtain_106 : (R=15,G=0,B=207,A=255)
# 3511. Curtain_51 : (R=15,G=255,B=207,A=255)
# 3512. Curtain_111 : (R=15,G=127,B=207,A=255)
# 3513. Curtain_114 : (R=15,G=63,B=207,A=255)
# 3514. Curtain_117 : (R=15,G=191,B=207,A=255)
# 3515. Curtain_121 : (R=15,G=31,B=207,A=255)
# 3516. Curtain_56 : (R=15,G=95,B=207,A=255)
# 3517. Curtain_57 : (R=15,G=159,B=207,A=255)
# 3518. Curtain_125 : (R=15,G=223,B=207,A=255)
# 3519. Curtain_59 : (R=15,G=15,B=207,A=255)
# 3520. Roof_Middle_129 : (R=15,G=47,B=207,A=255)
# 3521. Roof_End_Thin_132 : (R=15,G=79,B=207,A=255)
# 3522. Curtain_135 : (R=15,G=111,B=207,A=255)
# 3523. Curtain_138 : (R=15,G=143,B=207,A=255)
# 3524. Curtain_142 : (R=15,G=175,B=207,A=255)
# 3525. Curtain_145 : (R=47,G=0,B=207,A=255)
# 3526. Curtain_64 : (R=47,G=255,B=207,A=255)
# 3527. Inner_Wall_Half_Door_149 : (R=47,G=127,B=207,A=255)
# 3528. Inner_Wall_Close_Gap_152 : (R=47,G=63,B=207,A=255)
# 3529. Inner_Wall_Roof_01_156 : (R=47,G=191,B=207,A=255)
# 3530. Stairs_Prefab_471 : (R=47,G=31,B=207,A=255)
# 3531. Inner_Wall_Half_Door_34 : (R=47,G=95,B=207,A=255)
# 3532. Inner_Wall_Close_Gap_160 : (R=47,G=159,B=207,A=255)
# 3533. Stairs_Beam_Quart_163 : (R=47,G=223,B=207,A=255)
# 3534. Stairs_Beam_Quart_8 : (R=47,G=15,B=207,A=255)
# 3535. Stairs_Beam_Quart_9 : (R=47,G=47,B=207,A=255)
# 3536. Curtain_167 : (R=47,G=79,B=207,A=255)
# 3537. Curtain_66 : (R=47,G=111,B=207,A=255)
# 3538. Garden_Chair_171 : (R=47,G=143,B=207,A=255)
# 3539. Garden_Tressel_176 : (R=47,G=175,B=207,A=255)
# 3540. Garden_Tressel_182 : (R=79,G=0,B=207,A=255)
# 3541. Garden_Tressel_38 : (R=79,G=255,B=207,A=255)
# 3542. Outer_Wall_Half_Win_108 : (R=79,G=127,B=207,A=255)
# 3543. Porch_Middle_16 : (R=79,G=63,B=207,A=255)
# 3544. Inner_Wall_Half_Door_24 : (R=79,G=191,B=207,A=255)
# 3545. Inner_Wall_Half_Door_36 : (R=79,G=31,B=207,A=255)
# 3546. Roof_End_Thin_28 : (R=79,G=95,B=207,A=255)
# 3547. Roof_End_Thin_26 : (R=79,G=159,B=207,A=255)
# 3548. Wall_Low_Half_9 : (R=79,G=223,B=207,A=255)
# 3549. Wall_Low_Quart_33 : (R=79,G=15,B=207,A=255)
# 3550. Driveway_16th_43 : (R=79,G=47,B=207,A=255)
# 3551. Driveway_16th_8 : (R=79,G=79,B=207,A=255)
# 3552. Drinks_Can_51 : (R=79,G=111,B=207,A=255)
# 3553. Drinks_Can_55 : (R=79,G=143,B=207,A=255)
# 3554. Drinks_Can_58 : (R=79,G=175,B=207,A=255)
# 3555. Drinks_Can_42 : (R=111,G=0,B=207,A=255)
# 3556. Drinks_Can_62 : (R=111,G=255,B=207,A=255)
# 3557. Wall_Low_67 : (R=111,G=127,B=207,A=255)
# 3558. Wall_Low_57 : (R=111,G=63,B=207,A=255)
# 3559. Wall_Low_58 : (R=111,G=191,B=207,A=255)
# 3560. Wall_Low_59 : (R=111,G=31,B=207,A=255)
# 3561. Wall_Low_60 : (R=111,G=95,B=207,A=255)
# 3562. Wall_Low_End_74 : (R=111,G=159,B=207,A=255)
# 3563. Wall_Low_End_59 : (R=111,G=223,B=207,A=255)
# 3564. Wall_Low_End_60 : (R=111,G=15,B=207,A=255)
# 3565. Wall_Low_61 : (R=111,G=47,B=207,A=255)
# 3566. Wall_Low_End_61 : (R=111,G=79,B=207,A=255)
# 3567. Wall_Low_End_62 : (R=111,G=111,B=207,A=255)
# 3568. Wall_Low_Quart_82 : (R=111,G=143,B=207,A=255)
# 3569. Wall_Low_62 : (R=111,G=175,B=207,A=255)
# 3570. Wall_Low_End_64 : (R=143,G=0,B=207,A=255)
# 3571. Wall_Low_63 : (R=143,G=255,B=207,A=255)
# 3572. Wall_Low_End_65 : (R=143,G=127,B=207,A=255)
# 3573. Floor_Half_22 : (R=143,G=63,B=207,A=255)
# 3574. Stairs_Prefab_429 : (R=143,G=191,B=207,A=255)
# 3575. Inner_Wall_Quart_94 : (R=143,G=31,B=207,A=255)
# 3576. Inner_Wall_Quart_7 : (R=143,G=95,B=207,A=255)
# 3577. Inner_Wall_Quart_8 : (R=143,G=159,B=207,A=255)
# 3578. Inner_Wall_Close_Gap_101 : (R=143,G=223,B=207,A=255)
# 3579. Inner_Wall_Quart_104 : (R=143,G=15,B=207,A=255)
# 3580. Outer_Wall_Half_Win_132 : (R=143,G=47,B=207,A=255)
# 3581. Inner_Wall_Close_Gap_135 : (R=143,G=79,B=207,A=255)
# 3582. Inner_Wall_Quart_16 : (R=143,G=111,B=207,A=255)
# 3583. Inner_Wall_8th_139 : (R=143,G=143,B=207,A=255)
# 3584. Inner_Wall_16th_142 : (R=143,G=175,B=207,A=255)
# 3585. Inner_Wall_Close_Gap_145 : (R=175,G=0,B=207,A=255)
# 3586. Inner_Wall_Half_Arch_148 : (R=175,G=255,B=207,A=255)
# 3587. Inner_Wall_Half_Arch_151 : (R=175,G=127,B=207,A=255)
# 3588. Inner_Wall_Close_Gap_154 : (R=175,G=63,B=207,A=255)
# 3589. Inner_Wall_Quart_Arch_157 : (R=175,G=191,B=207,A=255)
# 3590. Inner_Wall_Quart_Arch_160 : (R=175,G=31,B=207,A=255)
# 3591. Driveway_164 : (R=175,G=95,B=207,A=255)
# 3592. Roof_End_Thin_27 : (R=175,G=159,B=207,A=255)
# 3593. Outdoor_Steps_15 : (R=175,G=223,B=207,A=255)
# 3594. Outdoor_Steps_18 : (R=175,G=15,B=207,A=255)
# 3595. Outdoor_Steps_7 : (R=175,G=47,B=207,A=255)
# 3596. Outdoor_Steps_11 : (R=175,G=79,B=207,A=255)
# 3597. Outdoor_Steps_12 : (R=175,G=111,B=207,A=255)
# 3598. Outdoor_Steps_13 : (R=175,G=143,B=207,A=255)
# 3599. Outdoor_Steps_14 : (R=175,G=175,B=207,A=255)
# 3600. Porch_Banister_8th_01_31 : (R=0,G=207,B=0,A=255)
# 3601. Porch_Banister_8th_2 : (R=0,G=207,B=255,A=255)
# 3602. Banister_End_6 : (R=0,G=207,B=127,A=255)
# 3603. Floor_8th__01_39 : (R=0,G=207,B=63,A=255)
# 3604. Stairs_Beam_Quart_51 : (R=0,G=207,B=191,A=255)
# 3605. Curtain_54 : (R=0,G=207,B=31,A=255)
# 3606. Curtain_60 : (R=0,G=207,B=95,A=255)
# 3607. Curtain_63 : (R=0,G=207,B=159,A=255)
# 3608. Curtain_74 : (R=0,G=207,B=223,A=255)
# 3609. Curtain_79 : (R=0,G=207,B=15,A=255)
# 3610. Curtain_85 : (R=0,G=207,B=47,A=255)
# 3611. Curtain_89 : (R=0,G=207,B=79,A=255)
# 3612. Outer_Wall_Quart_Floor_93 : (R=0,G=207,B=111,A=255)
# 3613. Curtain_97 : (R=0,G=207,B=143,A=255)
# 3614. Outer_Door_Swing_482 : (R=0,G=207,B=175,A=255)
# 3615. Outer_Door_Swing_1615 : (R=255,G=207,B=0,A=255)
# 3616. Outer_Door_Swing_2182 : (R=255,G=207,B=255,A=255)
# 3617. Outer_Door_Swing_2469 : (R=255,G=207,B=127,A=255)
# 3618. Outer_Door_Swing_3080 : (R=255,G=207,B=63,A=255)
# 3619. Outer_Door_Swing_3723 : (R=255,G=207,B=191,A=255)
# 3620. Outer_Door_Swing_4302 : (R=255,G=207,B=31,A=255)
# 3621. Outer_Door_Swing_4661 : (R=255,G=207,B=95,A=255)
# 3622. Outer_Door_Swing_5168 : (R=255,G=207,B=159,A=255)
# 3623. Outer_Door_Swing_5815 : (R=255,G=207,B=223,A=255)
# 3624. Outer_Door_Swing_6370 : (R=255,G=207,B=15,A=255)
# 3625. Outer_Door_Swing_6605 : (R=255,G=207,B=47,A=255)
# 3626. Inner_Wall_Close_Gap_102 : (R=255,G=207,B=79,A=255)
# 3627. Inner_Wall_Close_Gap_105 : (R=255,G=207,B=111,A=255)
# 3628. Wall_Low_End_108 : (R=255,G=207,B=143,A=255)
# 3629. Wall_Low_End_111 : (R=255,G=207,B=175,A=255)
# 3630. Outer_Door_Swing_7084 : (R=127,G=207,B=0,A=255)
# 3631. Outer_Door_Swing_7299 : (R=127,G=207,B=255,A=255)
# 3632. Outer_Door_Swing_7510 : (R=127,G=207,B=127,A=255)
# 3633. Outer_Door_Swing_7805 : (R=127,G=207,B=63,A=255)
# 3634. Outer_Door_Swing_8160 : (R=127,G=207,B=191,A=255)
# 3635. Outer_Door_Swing_8435 : (R=127,G=207,B=31,A=255)
# 3636. Outer_Door_Swing_8690 : (R=127,G=207,B=95,A=255)
# 3637. Outer_Door_Swing_8929 : (R=127,G=207,B=159,A=255)
# 3638. Outer_Door_Swing_9320 : (R=127,G=207,B=223,A=255)
# 3639. Outer_Door_Swing_9663 : (R=127,G=207,B=15,A=255)
# 3640. Outer_Door_Swing_9946 : (R=127,G=207,B=47,A=255)
# 3641. Outer_Door_Swing_10169 : (R=127,G=207,B=79,A=255)
# 3642. Outer_Door_Swing_10352 : (R=127,G=207,B=111,A=255)
# 3643. Outer_Door_Swing_10555 : (R=127,G=207,B=143,A=255)
# 3644. Outer_Door_Swing_10838 : (R=127,G=207,B=175,A=255)
# 3645. Outer_Door_Swing_10945 : (R=63,G=207,B=0,A=255)
# 3646. Porch_Pillar_44 : (R=63,G=207,B=255,A=255)
# 3647. Porch_Pillar_45 : (R=63,G=207,B=127,A=255)
# 3648. Porch_Pillar_46 : (R=63,G=207,B=63,A=255)
# 3649. Outer_Door_Swing_11560 : (R=63,G=207,B=191,A=255)
# 3650. Roof_End_Thin_120 : (R=63,G=207,B=31,A=255)
# 3651. Bed_Double_6 : (R=63,G=207,B=95,A=255)
# 3652. Outer_Door_Swing_710 : (R=63,G=207,B=159,A=255)
# 3653. Stairs_Prefab_688 : (R=63,G=207,B=223,A=255)
# 3654. Inner_Wall_Roof_5 : (R=63,G=207,B=15,A=255)
# 3655. Curtain_8 : (R=63,G=207,B=47,A=255)
# 3656. Curtain_76 : (R=63,G=207,B=79,A=255)
# 3657. Curtain_18 : (R=63,G=207,B=111,A=255)
# 3658. Curtain_22 : (R=63,G=207,B=143,A=255)
# 3659. Curtain_29 : (R=63,G=207,B=175,A=255)
# 3660. Inner_Wall_Close_Gap_32 : (R=191,G=207,B=0,A=255)
# 3661. Toilet_54 : (R=191,G=207,B=255,A=255)
# 3662. Sink_57 : (R=191,G=207,B=127,A=255)
# 3663. Curtain_75 : (R=191,G=207,B=63,A=255)
# 3664. Inner_Wall_Close_Gap_89 : (R=191,G=207,B=191,A=255)
# 3665. Curtain_100 : (R=191,G=207,B=31,A=255)
# 3666. Curtain_104 : (R=191,G=207,B=95,A=255)
# 3667. Flor_4 : (R=191,G=207,B=159,A=255)
# 3668. Pool_Table_01_109 : (R=191,G=207,B=223,A=255)
# 3669. Sofa_112 : (R=191,G=207,B=15,A=255)
# 3670. table_01_115 : (R=191,G=207,B=47,A=255)
# 3671. Chair_118 : (R=191,G=207,B=79,A=255)
# 3672. Sofa_121 : (R=191,G=207,B=111,A=255)
# 3673. Driveway_114 : (R=191,G=207,B=143,A=255)
# 3674. Curtain_126 : (R=191,G=207,B=175,A=255)
# 3675. Curtain_130 : (R=31,G=207,B=0,A=255)
# 3676. Curtain_132 : (R=31,G=207,B=255,A=255)
# 3677. Curtain_136 : (R=31,G=207,B=127,A=255)
# 3678. Curtain_141 : (R=31,G=207,B=63,A=255)
# 3679. Curtain_92 : (R=31,G=207,B=191,A=255)
# 3680. Curtain_148 : (R=31,G=207,B=31,A=255)
# 3681. Curtain_149 : (R=31,G=207,B=95,A=255)
# 3682. Curtain_95 : (R=31,G=207,B=159,A=255)
# 3683. Curtain_152 : (R=31,G=207,B=223,A=255)
# 3684. Curtain_154 : (R=31,G=207,B=15,A=255)
# 3685. Outer_Wall_Half_Apex_159 : (R=31,G=207,B=47,A=255)
# 3686. Banister_23 : (R=31,G=207,B=79,A=255)
# 3687. Banister_26 : (R=31,G=207,B=111,A=255)
# 3688. Banister_163 : (R=31,G=207,B=143,A=255)
# 3689. Stairs_Beam_Quart_166 : (R=31,G=207,B=175,A=255)
# 3690. Stairs_Beam_Quart_14 : (R=95,G=207,B=0,A=255)
# 3691. Curtain_171 : (R=95,G=207,B=255,A=255)
# 3692. Veranda_174 : (R=95,G=207,B=127,A=255)
# 3693. Garden_Chair_178 : (R=95,G=207,B=63,A=255)
# 3694. Garden_Chair_181 : (R=95,G=207,B=191,A=255)
# 3695. Bench_184 : (R=95,G=207,B=31,A=255)
# 3696. Small_House_01 : (R=95,G=207,B=95,A=255)
# 3697. Small_House_10 : (R=95,G=207,B=159,A=255)
# 3698. Small_House_11 : (R=95,G=207,B=223,A=255)
# 3699. Small_House_11630 : (R=95,G=207,B=15,A=255)
# 3700. Small_House_13 : (R=95,G=207,B=47,A=255)
# 3701. Small_House_15 : (R=95,G=207,B=79,A=255)
# 3702. Small_House_17128 : (R=95,G=207,B=111,A=255)
# 3703. Small_House_18 : (R=95,G=207,B=143,A=255)
# 3704. Small_House_19 : (R=95,G=207,B=175,A=255)
# 3705. Small_House_20 : (R=159,G=207,B=0,A=255)
# 3706. Small_House_22 : (R=159,G=207,B=255,A=255)
# 3707. Small_House_23 : (R=159,G=207,B=127,A=255)
# 3708. Small_House_24 : (R=159,G=207,B=63,A=255)
# 3709. Small_House_25 : (R=159,G=207,B=191,A=255)
# 3710. Small_House_26 : (R=159,G=207,B=31,A=255)
# 3711. Small_House_27 : (R=159,G=207,B=95,A=255)
# 3712. Small_House_28 : (R=159,G=207,B=159,A=255)
# 3713. Small_House_29 : (R=159,G=207,B=223,A=255)
# 3714. Small_House_3 : (R=159,G=207,B=15,A=255)
# 3715. Small_House_30 : (R=159,G=207,B=47,A=255)
# 3716. Small_House_31 : (R=159,G=207,B=79,A=255)
# 3717. Small_House_33 : (R=159,G=207,B=111,A=255)
# 3718. Small_House_34 : (R=159,G=207,B=143,A=255)
# 3719. Small_House_36 : (R=159,G=207,B=175,A=255)
# 3720. Small_House_37 : (R=223,G=207,B=0,A=255)
# 3721. Small_House_38 : (R=223,G=207,B=255,A=255)
# 3722. Small_House_39 : (R=223,G=207,B=127,A=255)
# 3723. Small_House_40 : (R=223,G=207,B=63,A=255)
# 3724. Small_House_41 : (R=223,G=207,B=191,A=255)
# 3725. Small_House_42 : (R=223,G=207,B=31,A=255)
# 3726. Small_House_43 : (R=223,G=207,B=95,A=255)
# 3727. Small_House_44 : (R=223,G=207,B=159,A=255)
# 3728. Small_House_45 : (R=223,G=207,B=223,A=255)
# 3729. Small_House_46 : (R=223,G=207,B=15,A=255)
# 3730. Small_House_4661 : (R=223,G=207,B=47,A=255)
# 3731. Small_House_47 : (R=223,G=207,B=79,A=255)
# 3732. Small_House_7 : (R=223,G=207,B=111,A=255)
# 3733. Small_House_8 : (R=223,G=207,B=143,A=255)
# 3734. Small_House_48 : (R=223,G=207,B=175,A=255)
# 3735. Outer_Door_Swing_346 : (R=15,G=207,B=0,A=255)
# 3736. Basketball_Hoop_5 : (R=15,G=207,B=255,A=255)
# 3737. Basketball_Hoop_9 : (R=15,G=207,B=127,A=255)
# 3738. Basketball_Hoop_12 : (R=15,G=207,B=63,A=255)
# 3739. Bench_15 : (R=15,G=207,B=191,A=255)
# 3740. Garden_Chair_39 : (R=15,G=207,B=31,A=255)
# 3741. Outer_Wall_Quart_Floor_31 : (R=15,G=207,B=95,A=255)
# 3742. Porch_Middle_5_Blueprint : (R=15,G=207,B=159,A=255)
# 3743. Medium_House_Prefab_01_23176 : (R=15,G=207,B=223,A=255)
# 3744. Medium_House_Prefab_40975 : (R=15,G=207,B=15,A=255)
# 3745. Medium_House_Prefab_49874 : (R=15,G=207,B=47,A=255)
# 3746. Outer_Door_Swing_1370 : (R=15,G=207,B=79,A=255)
# 3747. Medium_House_Prefab_63253 : (R=15,G=207,B=111,A=255)
# 3748. Medium_House_Prefab_80664 : (R=15,G=207,B=143,A=255)
# 3749. Medium_House_Prefab_95387 : (R=15,G=207,B=175,A=255)
# 3750. Outer_Door_Swing_2713 : (R=47,G=207,B=0,A=255)
# 3751. Drain_Pipe_20 : (R=47,G=207,B=255,A=255)
# 3752. Drain_Pipe_45 : (R=47,G=207,B=127,A=255)
# 3753. Drain_Pipe_65 : (R=47,G=207,B=63,A=255)
# 3754. BP_Fan_238 : (R=47,G=207,B=191,A=255)
# 3755. Rock_57 : (R=47,G=207,B=31,A=255)
# 3756. Rock_26 : (R=47,G=207,B=95,A=255)
# 3757. BP_Fan_633 : (R=47,G=207,B=159,A=255)
# 3758. Banister_End_13 : (R=47,G=207,B=223,A=255)
# 3759. Paint_Can_16 : (R=47,G=207,B=15,A=255)
# 3760. CameraActor_1 : (R=47,G=207,B=47,A=255)
# 3761. 256 : (R=47,G=207,B=79,A=255)

# %%
# Convert to serializable json dictionary

# Write to JSON
with open('id2color.json', 'w') as outfile:
    json.dump(id2color, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d1e8591ac25a> in <module>()
#       1 # Write to JSON
#       2 with open('id2color.json', 'w') as outfile:
# ----> 3     json.dump(id2color, outfile)
#
# D:\Anaconda3\envs\unrealcv\lib\json\__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     187     # could accelerate with writelines in some versions of Python, at
#     188     # a debuggability cost
# --> 189     for chunk in iterable:
#     190         fp.write(chunk)
#     191
#
# D:\Anaconda3\envs\unrealcv\lib\json\encoder.pyc in _iterencode(o, _current_indent_level)
#     432                 yield chunk
#     433         elif isinstance(o, dict):
# --> 434             for chunk in _iterencode_dict(o, _current_indent_level):
#     435                 yield chunk
#     436         else:
#
# D:\Anaconda3\envs\unrealcv\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# D:\Anaconda3\envs\unrealcv\lib\json\encoder.pyc in _iterencode(o, _current_indent_level)
#     440                     raise ValueError("Circular reference detected")
#     441                 markers[markerid] = o
# --> 442             o = _default(o)
#     443             for chunk in _iterencode(o, _current_indent_level):
#     444                 yield chunk
#
# D:\Anaconda3\envs\unrealcv\lib\json\encoder.pyc in default(self, o)
#     182
#     183         """
# --> 184         raise TypeError(repr(o) + " is not JSON serializable")
#     185
#     186     def encode(self, o):
#
# TypeError: (R=175,G=111,B=223,A=255) is not JSON serializable

# %% [markdown]
# Parse the segmentation mask

# %%
# Matches a color from the object_mask and then returns that region color
def match_color(object_mask, target_color, tolerance=3):
    match_region = np.ones(object_mask.shape[0:2], dtype=bool)
    for c in range(3): # r,g,b
        min_val = target_color[c] - tolerance
        max_val = target_color[c] + tolerance
        channel_region = (object_mask[:,:,c] >= min_val) & (object_mask[:,:,c] <= max_val)
        match_region &= channel_region

    if match_region.sum() != 0:
        return match_region
    else:
        return None

id2mask = {}
for obj_id in scene_objects:
    print(obj_id)
    color = id2color[obj_id]
    mask = match_color(object_mask, [color.R, color.G, color.B], tolerance = 3)
    if mask is not None:
        id2mask[obj_id] = mask

# id2mask.keys() are all the matched objects
for idmask in id2mask.keys():
    print(idmask)

# This may take a while
# TODO: Need to find a faster implementation for this
# Out:
# WorldInfo_0
# Carpet_5
# SM_CoffeeTable_14
# Couch_13
# SM_Room_7
# SM_Room_OuterShell_14
# SM_Couch_1seat_5
# Mug_22
# EditorPlane_23
# EditorPlane_24
# EditorPlane_25
# EditorPlane_26
# EditorPlane_27
# Mug_30
# EditorPlane_31
# EditorPlane_32
# EditorPlane_33
# EditorPlane_34
# SlidingDoors_5
# S_Trim_Floor_10
# SM_Frame_15
# SM_RoundCeilingLight_9
# SM_RoundCeilingLight_10
# SM_RoundCeilingLight_11
# SM_RoundCeilingLight_12
# SM_RoundCeilingLight_13
# SM_RoundCeilingLight_14
# SM_RoundCeilingLight_16
# SM_RoundCeilingLight_17
# SM_Railing_20
# SM_Railing_21
# SM_Railing_23
# SM_Railing_24
# SM_Railing_25
# SM_Railing_26
# SM_Railing_27
# SM_Railing_28
# SM_Railing_29
# SM_Balcony_34
# SM_Balcony_35
# SM_Balcony_36
# SM_Balcony_37
# SM_Frame_38
# SM_Frame_39
# SM_Curtain_42
# SM_Curtain_43
# SM_Curtain_45
# Statue_48
# SM_FloorLamp_5
# SM_FloorLamp_7
# SM_FloorLamp_8
# SM_TV_5
# SM_DeskLamp_5
# SM_Background_8
# WallPiece1_22
# WallPiece2_24
# WallPiece3_26
# WallPiece4_28
# WallPiece5_30
# WallPiece6_32
# SM_Door_37
# SM_Door_39
# SM_Door_41
# SM_Shelving_6
# SM_Shelving_7
# SM_Shelving_8
# SM_Shelving_9
# SM_Shelving_10
# SM_Shelving_12
# SM_Frame_3
# SM_Frame_4
# SM_Frame_5
# SM_BlackBox_Hole_16
# SM_BlackBox_23
# SM_BlackBox_24
# SM_BlackBox_25
# SM_BlackBox_26
# SM_BlackBox_27
# SM_Railing_30
# SM_Railing_31
# SM_Railing_32
# SM_Railing_33
# SM_Railing_34
# SM_Railing_35
# SM_Railing_36
# SM_Railing_37
# SM_Railing_38
# Switch_7
# Switch_8
# Switch_10
# SM_Socket_15
# SM_Socket_22
# SM_Socket_24
# SM_Socket_25
# SM_Socket_26
# SM_Socket_27
# Switch_29
# Switch_2
# SM_RoundCeilingLight_4
# Carpet_7
# Plug_12
# Wire1_23
# SM_Plant_7
# SM_Plant_8
# SM_Vase_13
# SM_Vase_14
# SM_Vase_15
# SM_Vase_16
# SM_Vase_17
# SM_Vase_18
# SM_Vase_19
# SM_Vase_20
# SM_Vase_21
# SM_Vase_22
# SM_Bowl_27
# SM_Bowl_28
# SM_Bowl_29
# SM_Vase_30
# SM_Vase_31
# SM_Socket_11
# Plug_24
# Wire1_25
# Wire1_27
# Plug_28
# Wire1_30
# Wire1_20
# Plug_21
# SM_Socket_12
# Plug_13
# Wire1_14
# Wire1_15
# Plug_16
# Wire1_17
# CoatHookBacking_7
# CoatHook_16
# CoatHook_17
# CoatHook_18
# CoatHook_19
# Wire1_18
# Plug_19
# BookLP_5
# BookLP_11
# BookLP_12
# BookLP_13
# BookLP_14
# BookLP_15
# BookLP_16
# BookLP_29
# BookLP_30
# BookLP_31
# BookLP_32
# BookLP_33
# BookLP_34
# BookLP_35
# BookLP_36
# BookLP_37
# BookLP_38
# BookLP_39
# BookLP_40
# BookLP_41
# BookLP_42
# BookLP_43
# BookLP_44
# BookLP_45
# BookLP_46
# BookLP_47
# BookLP_48
# BookLP_49
# BookLP_50
# BookLP_51
# BookLP_52
# BookLP_53
# BookLP_54
# BookLP_55
# BookLP_56
# BookLP_57
# BookLP_58
# BookLP_59
# BookLP_60
# BookLP_61
# BookLP_62
# BookLP_63
# BookLP_64
# BookLP_65
# BookLP_66
# BookLP_67
# BookLP_68
# BookLP_69
# BookLP_70
# BookLP_71
# BookLP_72
# BookLP_73
# BookLP_74
# BookLP_75
# BookLP_81
# BookLP_82
# BookLP_83
# BookLP_84
# BookLP_85
# BookLP_86
# BookLP_87
# BookLP_88
# BookLP_89
# BookLP_90
# BookLP_91
# BookLP_92
# BookLP_93
# BookLP_94
# BookLP_95
# BookLP_96
# BookLP_97
# BookLP_98
# BookLP_99
# BookLP_100
# BookLP_101
# BookLP_102
# BookLP_103
# BookLP_104
# BookLP_105
# BookLP_106
# BookLP_107
# BookLP_108
# BookLP_109
# BookLP_110
# BookLP_111
# BookLP_112
# BookLP_113
# BookLP_114
# BookLP_115
# BookLP_116
# BookLP_117
# BookLP_118
# BookLP_119
# BookLP_120
# BookLP_121
# BookLP_122
# BookLP_123
# BookLP_124
# BookLP_125
# BookLP_126
# BookLP_127
# BookLP_128
# BookLP_129
# BookLP_130
# BookLP_131
# BookLP_132
# BookLP_133
# BookLP_134
# BookLP_135
# BookLP_136
# BookLP_137
# BookLP_138
# BookLP_139
# BookLP_140
# BookLP_141
# BookLP_142
# BookLP_143
# BookLP_144
# BookLP_145
# BookLP_146
# BookLP_147
# BookLP_148
# BookLP_149
# BookLP_150
# BookLP_151
# BookLP_152
# BookLP_153
# BookLP_154
# BookLP_155
# BookLP_156
# BookLP_157
# BookLP_158
# BookLP_159
# BookLP_160
# BookLP_161
# BookLP_162
# BookLP_163
# BookLP_164
# BookLP_165
# BookLP_166
# BookLP_167
# BookLP_168
# BookLP_169
# BookLP_170
# BookLP_171
# BookLP_172
# BookLP_173
# BookLP_174
# BookLP_175
# BookLP_176
# BookLP_177
# BookLP_178
# BookLP_179
# BookLP_181
# BookLP_182
# CameraActor_0
# CameraActor_1
# EditorSkySphere_4
# CameraActor_2
# 256

# %% [markdown]
# Group the matched objects
# ===============

# %%
class_groups = {}

# Go through the matched objects
for idmask in id2mask.keys():
    
    # Get the class from the data object we had earlier for json file
    curr_class = data[idmask]
    
    # If the class is not in the class_groups map, add it
    if curr_class not in class_groups:
        class_groups[curr_class] = [] 
        
    # Add the idmask to it's corresponding class
    class_groups[curr_class].append(idmask)

# %% [markdown]
# Begin normalization by class
# =======

# %%
# create copy of object_mask
other_mask = object_mask

# Normalize by class
for cls in class_groups.keys():
    
    class_base = class_groups[cls][0]
    class_color = id2color[class_base]
    
    for class_id in class_groups[cls]:
        current_color = id2color[class_id]
        swap_color(object_mask, current_color, class_color)

# %%
# Show before
before = Image.fromarray(other_mask)
before.show()

# %%
# Show after
after = Image.fromarray(object_mask)
after.show()

# %% [markdown]
# Clean up resources
# ==================

# %%
client.disconnect()
